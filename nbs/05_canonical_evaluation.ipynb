# %% [markdown]
# ## Canonical evaluation notebook

# %% [markdown]
# __Accuracy__ is the proportion of correct predictions among the total number of cases processed. It can be computed with: __Accuracy = (TP + TN) / (TP + TN + FP + FN)__ Where: TP: True positive TN: True negative FP: False positive FN: False negative

# %%
import pandas as pd
from transformers import AutoTokenizer
import numpy as np
import os

# %% [markdown]
# ### Calculating Accuracy

# %% [markdown]
# __Calculating the accuracy need to be reviwed fromthe logits__ this step is in stand by

# %%
CASE = 'c17'

# %%
#Available Datasets

def params(): 
    ## Models are describe in the following spreadsheet: https://docs.google.com/spreadsheets/d/1lJG0M3-WCR-oV5OSMlKsMIN6ERAFrfrVn7iX3Dz6_nY/edit#gid=883975699
    code_models = {
        'c1':('EleutherAI/gpt-neo-125M','EleutherAI-gpt-neo-125M'),
        'c2':('EleutherAI/gpt-neo-1.3B','EleutherAI-gpt-neo-1.3B'),    
        'c3':('EleutherAI/gpt-neo-2.7B','EleutherAI-gpt-neo-2.7B'),
        'c4':(),
        'c5':('Salesforce/codegen-350M-nl','Salesforce-codegen-350M-nl'),
        'c6':('Salesforce/codegen-2B-nl', 'Salesforce-codegen-2B-nl'),
        'c7':(),
        'c8':(),
        'c9':('codeparrot/codeparrot-small-multi','codeparrot-codeparrot-small-multi'),
        'c10':('Salesforce/codegen-350M-multi','Salesforce-codegen-350M-multi'),
        'c11':('Salesforce/codegen-2B-multi','Salesforce-codegen-2B-multi'),
        'c14':('codeparrot/codeparrot-small','codeparrot-codeparrot-small'),
        'c15':('codeparrot/codeparrot','codeparrot-codeparrot'),
        'c16':('Salesforce/codegen-350M-mono','Salesforce-codegen-350M-mono'),
        'c17':('Salesforce/codegen-2B-mono','Salesforce-codegen-2B-mono')
    }
    current_case = CASE
        
    return {
            'hf_model' :  code_models[current_case][0],
            'model_name': code_models[current_case][1],
            'input_vector_df': '../data/ds_raw_logits/'+'out_astevalverticalfiltered_{}.csv'.format(CASE),
            'cache_dir':'../data/hugginface/cache/models' ## <- use this path to save model checkpoints and avoid to use container disk!
    }

# %%
#pwd
parameters = params()

# %% [markdown]
# ## Loading data <- skip this secction if you alreade have a subset and jump to the model load section

# %% [markdown]
# Loading datasets from previous raw outputs

# %%
path = parameters['input_vector_df']

# %%
df = pd.read_csv(path)

# %%
df.head()

# %%
df.shape

# %%
df['code'][0]

# %% [markdown]
# ### Sampling dataset

# %% [markdown]
# According to the population size $N=50971$ we can use a sample size of $382$ with a confidence level $z=95%$ and margin error $e=5%$

# %%
SAMPLE_SIZE = 382

# %%
indexes = np.random.randint(low=0.0, high=len(df), size=SAMPLE_SIZE)
df_subset = df.iloc[indexes]

# %%
df['size'].describe()

# %%
df_subset=df_subset.reset_index(drop=True)
df_subset.head()

# %% [markdown]
# ### Create prompt: SMethod signature only

# %%
df_subset['prompts'] = df_subset['code'].apply(lambda x: x.split(":")[0])

# %% [markdown]
# ## Model load <- Run this script from this point if you already have a subset

# %%
#This code works for CodeGPT, Salesforce and GPTNeoX
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

if 'gpt' not in parameters['hf_model']:
    tokenizer = AutoTokenizer.from_pretrained(parameters['hf_model'], cache_dir=parameters['cache_dir'])
    model = AutoModelForCausalLM.from_pretrained(parameters['hf_model'],device_map="auto", torch_dtype=torch.float16, cache_dir = parameters['cache_dir'])
    print("model loaded as CausalLM")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/997 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/5.69G [00:00<?, ?B/s]
# model loaded as CausalLM

# %%
#This code works for GPT-Neo
from transformers import GPTNeoForCausalLM, GPT2Tokenizer
if 'gpt' in parameters['hf_model'] or '':
    model = GPTNeoForCausalLM.from_pretrained( parameters['hf_model'], ignore_mismatched_sizes=True,cache_dir = parameters['cache_dir'] )
    tokenizer = GPT2Tokenizer.from_pretrained( parameters['hf_model'],cache_dir = parameters['cache_dir'] )
    print("model loaded as GPT-Neo")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model.to( device )
# Out:
# CodeGenForCausalLM(
#   (transformer): CodeGenModel(
#     (wte): Embedding(51200, 2560)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (6): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (7): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (8): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (9): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (10): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (11): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (12): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (13): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (14): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (15): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (16): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (17): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (18): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (19): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (20): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (21): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (22): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (23): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (24): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (25): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (26): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (27): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (28): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (29): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (30): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (31): CodeGenBlock(
#         (ln_1): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (attn): CodeGenAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (qkv_proj): Linear(in_features=2560, out_features=7680, bias=False)
#           (out_proj): Linear(in_features=2560, out_features=2560, bias=False)
#         )
#         (mlp): CodeGenMLP(
#           (fc_in): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc_out): Linear(in_features=10240, out_features=2560, bias=True)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=2560, out_features=51200, bias=True)
# )

# %% [markdown]
# ### Load sub dataset from checkpoint

# %%
SAMPLE_SIZE = 382

# %%
path = "../datax/pandas/evaluation/subset_canonical_evaluation_prompt_" + str(SAMPLE_SIZE) + ".json"

# %%
df_subset = pd.read_json(path)

# %% [markdown]
# Create the tensor vector from the given prompt for each data point

# %%
input_ids_list = [torch.tensor(  [tokenizer.encode(input_ids)], dtype = torch.int, device=device ) for input_ids in df_subset.prompts.values]

# %%
#encoding_ids_list = tokenizer.batch_encode_plus( list( df_subset.prompts.values ) )

# %%
input_ids_list
# Out:
# [tensor([[ 4299,  4808, 39014,    62, 14421,    62,  1370,    62,  8929,  2971,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 28665,    62,  7645, 16354,    62,    83, 29291,
#              62, 35636,   364,    62, 17143,  2357,  3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  4774,    62, 12102,   341,    62,   259,    62,
#           24442,    62, 14171,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 17752,    62,   354,   945,   316,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1069,  4516,    62, 13116,    62,  2664,    62,
#           28961,    62, 10379, 20212,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8094,  1525,    62, 48101,    62,  2539,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 7783,   62, 1462,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2610,   540,    62, 10134,    62, 46911,  1096,    62,  1462,
#              62,    83, 22854,     7, 26801,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  6650,    62,  9060,    62,    83, 22854,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4566,    62,  2539,     7,    66,    11,  4277,    28, 14202,
#              11,  3108,    28, 17821,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299,  651,   62,   83,  482,  641, 3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2213, 19524,    62,  2435,    62,   785,  1845,
#            1653,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1057,    7,  944,    8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 41684,    62, 28665,    62,    67,  4906,    62,
#             562, 16747,  3419]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 48101,    62, 28665,    82,    62,  4480,    62,
#            1169,    62, 31642,    62,  3672,    62, 48369,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12501,  4402,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 11284,    62,  1640,    62, 10378, 31023,    62,
#             354,  3762,    62, 16129,    62, 40148,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 26571,    62, 17143,  2357,    62,  1102,  2536,  6003,     7,
#           17143,  2357,    62,  1102,  2536,  6003,    11, 42287,    11, 24955,
#              62,  3672,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 14681,    62,  7753,    62,   259, 12102,    62,
#           17143,    62,  9122,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  7753,    62,  1662,    62,  2777, 20837,    62,
#            4480,    62,  2502,    81,  2530,    62,  3672,    62,  2777, 20837,
#            3419]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 19608,  8079,    62,  2701,    62,  2435,    62,
#           25410,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 20751,    62,   259,    62, 47653,    62, 18090,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 10414,  2533,    62,   445,  1060,    62, 23144,
#              62, 13190,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 19119,    62, 19608,   292,   316,     7,   944,
#              11, 15290,    62, 19119,    62, 19608,   292,   316,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62,  647,  469,   62, 8841,   62,   67, 4906,    7,  944,
#             11,  703,   11, 2938,   62, 7890,   11,  597,   62, 8841,   62,   67,
#           4906,    8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  6371,     7,   439,    62,    79,   945,   364,
#              11,   269, 21370,    62, 15908,    62,  6978,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  2617,    62, 11299,    62,  4906,    62, 37266,     7,
#             944,    11, 13634,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 24011,  1389,    62,  1236, 14221,    62,  9503,
#             315,   876,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808,   403,  3524,     7,   944,    11,   584,     8,  4613,
#           45941,    13,   600,  2414,   930, 45941,    13, 19608,  8079,  2414,
#             930, 45941,    13, 16514,   276, 12514,  2414,   930, 45941,    13,
#             358, 18747]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1370,    62,   437,   654,     7,  5225, 10223,
#              11,   649,  1370,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   751,    62,   853,  2886,     7,   944,    11, 30751,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   355,    62, 25410,     7,   944,    11, 17050,    11,  4637,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 22179,  2919,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   787,    62, 19608,   499,  1563,    82,     7,   944,    11,
#             351,    62, 27932,    28, 17821,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1477, 18137,    62,  2539,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 28920,    62, 12683,  1300,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 11498,  5551,    62,   445,  1060,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  4550, 23595,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2245,    62, 24442,  2667,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11,  1438,    28, 14202,
#              11, 13877,    28, 14202,    11,  2560,    28, 14202,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    67, 20259,    62,  4475,    62,   448,    62,
#            1659,    62,  9521,     7,   944,    11,  1366,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9122,    62, 45986,    62,  9641,    62, 46503,
#               7,    76,   735,    62, 41947,    11, 15290,    62,  5143,    62,
#           21812,    11, 15290,    62,  9122,    62, 45986,    62,   525,  3411,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   651,  3351,  3021, 10699,     7,   944,    11, 35971,    11,
#            2659,    11, 10548,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 45688,    62, 27160,     7,   944,    11,  4838,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 20786,    62,  9630,    62,    77,   623,  2357,
#           49228,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 12854,    62, 21928,    62,   392,    62,  2118,   382,     7,
#           26801,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  6291,    62, 15414,    82,    62,  9630,     7,   404,    62,
#           10951,    11,  3335,    11,   288,  4906,    11,  4433,    62,  9744,
#              11, 12429, 46265, 22046,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 18224,    62, 11925,    62,    76,  1042,   963,
#               7,  7890,    11,   477,    62,   283, 29848,    62,  3575,  2024,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,   834, 35636,     7,   944,    11,   279,    11,   287,
#             457,    62,  4906,    11,   285, 12721,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   744,    62,    67,   301,    62, 20192,    62,
#            4131, 29709,     7,   944,    11,  2446,    11,  4326,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 2721,    7,  944,   11, 1628,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299, 4259,   62,  521,  298,  341,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  2220,    62, 16302,    62,  4906,    62,  4871,     7,
#             944,    11,  3108,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   489, 13396,    62,    82,    89,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299,  479, 1313,    7,   64,   11,  275,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  5412,    62, 33885,    62, 13376,     7,   944,    11,  3722,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1281,    62, 23504,    62, 40406,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  3919,    62, 26209,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 13287,    62,   421,  5191,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12501,   320,  1604,  1164,    62, 11284,    62,
#           12501,  4402,    62, 25512,  1352,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    75, 21118,    62, 29289,    62,  3672,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 4197,    7,  944,   11, 1395,   11,  331,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 23108,    62,   292,    62,  8423,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   900,    62, 23569,     7,   944,    11,  2106,    11,   537,
#              72,    62,  1818, 15908,    28, 14202,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    82, 24707,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1069,  9152,    62,  4480,    62, 21170,   934,
#              62,    69,    74,    62, 49501,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 17953,    62,  4798,    62, 35352,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2617,  9186,    62, 14894,    62,  3866, 16005,
#               7,   944,    11,   597,    62,    77, 39223,    62, 18213,    62,
#              67,  4906,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593, 19545,   834,     7,   944,     8,  4613,  6060, 19778,
#             930,  7171]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9631,    62, 43337,    62, 28405,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 26571,    62,   559,  5154,   276,    62, 34960,    62,  1177,
#               7,   559,  5154,   276,    62, 34960,    62,  1177,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   279,  2645,   600,    62, 33803,     7,    76, 12721,    11,
#           10662,    83, 13645,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1102,  1851,    62, 18302,  3760,    62,   439,
#              62, 30388,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  3551,    62,   439,    62,    66, 13533,    62,  5354,    62,
#           16624,     7, 11249,    62, 38993,    62,  4868,    11,  9483,    62,
#            6978,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 12109,     7,    86,    11, 12429, 46265, 22046,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   651,    62, 25747,  1039,     7,   944,    11,  2581,    11,
#           26181,    28, 14202,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 34087,  1127,    62, 27363,    62,   392,    62, 17831,     7,
#            5661,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4296,    62, 29412,    62,  6978,     7,   944,    11,   649,
#              62,  6978,    62, 11600,    28, 14202,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299, 1332,   62, 3245,   62,  354, 1397,   62,  396,  433, 2032,  342,
#              7,  944,    8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299,  900, 4933,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 28803,  2304,   590,    62, 28665,    82,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   459,  2981,    62, 22163,   444,     7,   944,
#              11,   288,  4906,    11,   584,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 19119,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 40972,   576,    62, 41684,    62, 28920,     7,
#             944,    11,   987,    79,    62, 24396,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  3815,    62,  1640,    62, 17752,     7,   944,     8,  4613,
#           45941,    13,   358, 18747]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 31943,    62,  1462,    62,  9288,    62,  7220,     7,
#             944,    11, 10007,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   279,  9945,    62, 15414,     7,   944,    11,  6152,    11,
#            9206,    28, 14202,    11,  1181,    28, 14202,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 27363,    62, 20786,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    85,    21,    62,   403, 46764,    62, 15255,
#            3213,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 30619,    62, 27160,    62, 12647,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299,  900, 4933, 9487,    7,  565,   82,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 15952,  2611,     7,   944,    11, 44161,   578,
#              62, 11249,   259,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4876,    62, 47904,    62, 10378,    82,     7, 22046,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   651,    62, 39754,    62,   265,     7, 10459,    62,  8189,
#              11, 11677,    11,  1005,   563,    28, 17821,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  3802,    62, 29149,     7,  1174, 46265, 22046,     8,  4613,
#            5660, 21575, 23004]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,   853,  1084,    62,   445,  7234,     7, 17080,    11,
#             923,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 35636,     7, 20541,    62,    67,  4906,    11,
#             299,    62,   710,   394, 32289,    11, 16874,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 11265,  1096,    62,  3605,  6615,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4941,    62, 15414,    82,    62, 19276,   806,   425,    62,
#            9060,    62,    83, 22854,  3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,   503, 13414, 16886,     7,   944,    11,   264,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  6978,    62, 37153,    62,   929, 19581,    62,
#             565,  2334,     7, 39568, 13645,    11,  1388,    62, 17497,    11,
#           45218, 15908,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1487, 9237,    7,  944,   11, 1785,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  8398,     7,  8000,    62, 26495, 11639,  3256,  4852,    62,
#            6978,    28, 14202,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8443,   540,    62, 21949,    62, 20688,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 2860, 2713,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  3298,    62, 11250,    62, 38969,   519,     7, 39568, 13645,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 12233,    62, 19849,     7,   944,    11,  2581,    11, 26181,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 35487,    62,   687,  2617,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11,  1635, 22046,    11,
#           12429, 46265, 22046,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2198,    62,    79,   541,  4470,    62,  5936,   396,  1387,
#               7,  3672,    11,  3959,  1352,    62, 11612,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  2860,    62,  9122,  4122,    62, 27160,    62,  9122,
#               7, 11659,   540,    62, 48205,    11,  2134,    62, 34960,    62,
#            1676,  1462,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 22570,    62,  6477,    62, 13159, 22570,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 15560,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808, 11201,   392,    62,    68,  3639,     7,  2618,     8,
#            4613,  6045]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2938,     7,   944,    11, 26181,    11,  1188,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 29572,    62,  6494,    62,   259,    62, 12048,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2393,    62,    76,  2668,     7,   944,    11, 12351,    62,
#            7753,    11,  2244,    62,  7753,    11,   318,    62, 15908,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 23108,    62, 48678,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 38947,  1326,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 20500,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2875,    62,  1525,    62,   944,    62,  5420,
#           33369,    62,    69,    74,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   259,   372, 42942,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 40223,    62,  1102,  2536,  2913,    62, 41004,
#              62, 32165,   495,    62,  6381, 40845,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1527,  500,   62, 7784,  278,   62, 3524, 3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 24184,     7,   944,    11,  1233,   796,  6045,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 25981, 15526,    62, 19052,    62,  7266, 16302,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   411,  6442,    62,  1462,    62,    70, 19472,
#               7,   944,    11,   285, 12721,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808, 46012,   533,    62,  1640,    62,    65, 12171,    62,
#           17953,     7,   944,    11,   909,  8457,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 37023,    62, 17190,    62,  3919,    62,  3605,
#            1370,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2435, 15878,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 20500,    62,  1078,  3808,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   900,  4933, 14402,  6601,     7,   565,    82,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2198,    62,  4871,    62,  6551,    62,  4871, 13350,     7,
#            3672,    11,  1398,  7483,    62, 11612,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,  4550, 39687,    53,    17, 30815,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 16302,    62,  9630,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   298, 28338,  3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2617,    62,  7753,    62,  6978,    82,    62,
#           12518,    62, 41341,    62,  7753,    62,  6978,    62,  1662,    62,
#             259,    62,  3605,    62,  7753,    62,  6978,    82,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 25652,   263,    62,  3919,    62, 12286,    62,
#            3919,    62,  7220,    62, 13000,     7,   944,    11, 15290,    62,
#           15414,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4296,    62, 10331,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    74,  1313,    62, 43358,     7,   944,    11,
#            5485,    62,    64,    11,  5485,    62,    65,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   445,  1060,    62, 15952,  1326,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62,   81,   79,  322,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8625,   415,  9386,    62,  1818, 11125,    62,
#           28243,     7,   944,    11, 15290,    62, 16366,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 24592,    62, 24011,  1389,    62, 48369,    62,
#            5589,   633,    62, 28920,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 13291,     7,   944,    11, 13291,    11,  7505,    62,  3672,
#              28, 14202,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62,  377,  506,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12286,    62,  1671,  3702,    62,  2617,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  9720,    62,  2118, 19112,    62, 20500,     7,   944,    11,
#           31456,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 19282,   448,    62, 30393,     7,   541,    88,
#           41947,    11, 10662,    83, 13645,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808,  8340,    62, 15763,     7,   944,    11,  6808,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 15883,    62, 16366,    62,    72,   455,  1476,     7,
#             944,    11,  4637,    11, 12429, 46265, 22046,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12501,  4402,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    82,  9186,  1686,    62, 12957,  4666,    62,
#           20147,  1571,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,   787,    62, 43358,    62,  8818,    62,  4906, 46491, 43358,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 44506,    62,  2902,  9526,    62, 11274,     7,
#             944,    11, 15290,    62,    67,    70,    11, 26498,    11,  2938,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8612,   378,    62,   259, 12102,    62, 17143,
#              62,  2100,    62,   439,    62, 12102,     7,  1102,  2536,  6003,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2364,  1370,    62,   929,  9526,    62, 36460,
#              62,  2875,     7,   944,    11,   422,    62,   260, 10178,    11,
#             284,    62,   260, 10178,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 10784,    62, 29412,  6978,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 10379,  4400,    62,    77,  6975,   605,    62,
#            9460,  2301,   689,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,   468, 14967,   276,  7975,     7,   944,     8,  4613, 20512]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[  292, 13361,   825,  1057,    62,  8189,     7,   944,    11,  2438,
#              62, 26801,    11,  1255,    28, 14202,    11,  1635,    11, 30351,
#              62,    28, 25101,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 37800,    62,   785, 37069,   507,    62, 42655,
#              62, 23504,     7,   785, 37069,   507,    62,  8189, 35352,    11,
#           10662,    83, 13645,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 41433,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 41433,    62, 17201,   874,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   651,    62,   439,    62,    85,    17,    62, 14933,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11, 16628,    11,  1635,
#           22046,    11, 12429, 46265,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299, 1332,   62,   69,   74,   62, 1462,   62,   76,   17,   76,    7,
#            944,    8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2617,    62, 13138,    62,    67,   363,    62,
#            5143,    62,  1462,    62, 20270,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1640,    62, 19119,    62, 25410,    62, 27568,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   651, 19722,     7,   944,     8,  4613, 32233,    58,    51,
#           29291,    60]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8957,  1202,    62, 17080,  1817,     7,  4164,
#            1173,    11, 25439,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1007,  8189,     7,  5239,    11,  5128,    28, 46437, 24302,
#           22083,    62, 24181,  3727,  2751,    11,  5072,    28, 46437, 24302,
#           22083,    62, 24181,  3727,  2751,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1102,  1851,     7,   944,    11, 35847,    11,
#             651,    62, 23893,    62,  6649,  1018,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 16412,    62, 19199,     7,   944,    11,  3113,
#              11,  1366,    11,  2581,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1388,     7, 22046,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  8494,    62,  5460,   929,    62,  4906,     7,   944,    11,
#           35847,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 14976,    62, 36008,    78,    62,    88,  4029,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8423,    62,  8094,    62,  2536,    62,   445,
#           48915,    62, 25076,     7, 25927,    11,  4268,  2616,    11,  7741,
#              62, 20786,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    83, 15970,    62,  1507,  3695,    62,  1959,
#            2670,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 2070,   62, 3672,   62, 2934,  315, 1477,    7,  944,
#              8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   279,  9945,    62, 41049,    62, 21812,     7,   944,    11,
#            3141,    11,  2962,    62,  1462,    62, 35352,    28, 25101,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 15883,    62, 17474,     7, 15763,    11,  1438,    11,
#            1635, 16624,    62,   273,    62, 15908,    82,    11, 21996,    11,
#             751,   263,    11,  4781,    28, 17821,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 16963,   457,    62,    66,  1834,   669,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1005,   563,     7, 22184,    11,  1661,    28,    16,    11,
#            4043,    28,    20,    13,    15,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 48761,    62,  9641,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1939, 47315,    62, 16793,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   259,    16,    67,    62, 25843,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11055,    62, 12001,  2435,     7,  8367,    11,   779,    62,
#           22877,    28, 14202,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62, 15410, 11956,    62, 16663,    62,
#             646,   431,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62, 30053,    62, 14933,    62,   448,
#            3419]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 17143,  7307,  4863,  8979,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 4370,   62, 9186,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  7857,    62, 30619,     7, 30619,    11,   416,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    77,   538,  1120,    62, 41433,    62,  1102,
#            9641,    62, 48277,  3419]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 32165,    62,    66,   578,   742,    62, 39754,
#              62,  2539,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 49585,   395,  1806,    62,   259,    62,  1069,
#            4516,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2302,  1631,    62,  2618,  4871,    62, 28243,
#              62, 33678,    62, 10414, 36241,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   292,    62,  9630,    62, 19738,    62, 28665,
#            3419]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593,    76,   377,   834,     7,   944,    11,   584,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 16302,    62, 11748,    62, 38235,    62, 35827,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 27773,    62,  3846,    62, 22915,     7,  3846,    11,
#            3424,    62,  2340,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 2197, 2713,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    79,   945,   278,    62,   292,   310,   524,
#              62, 13159,   292,   979,    72,    62, 12894,   896,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11507,    62, 24011,  7352,     7,  9288,    62, 17143,  7307,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   651,    62,  3107,  3007,     7,   944,    11, 23493,    11,
#            3084,    62,  3672,    11,  3084,    62, 25747,    28, 28955]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 10651,    62,  1525,    62, 20541,    62, 27237,     7,    83,
#              62,  4868,    11, 10651,    62, 27237,    11,   779,    62, 27237,
#              28, 14202,    11,  1438,    28, 14202,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,   834, 35636,     7,   944,    11,   287,   457,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 22046,    62, 23032,     7,   944,     8,  4613,  6045]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62, 48369,    62,  7784,    62,  4480,
#              62, 45688,    62,  8367,     7,  9630,    62,  3258,    11,  2938,
#              11,  2496,    11,   435,  2188,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808,  8612,   378,    62, 22468,    62, 40319,  3419,  4613,
#            7343,    58,  8053,    58, 22468, 11907]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11, 42287,    11,  2496,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   329,    62,  4480,    62, 50033,    62,  7785,     7,    75,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1177,    62,  7266,  7839,    62,   525,    62,
#           15252,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8423,    62, 22708,    62, 10641,     7,   439,
#              62,    79,   945,   364,    11, 28411,    11,  9577,    62, 10641,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 14225,   469,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 44754,    62, 14933,     7, 48610,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  6818, 24661,  5841,  1431,     7,   944,    11,  3108,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 25120,    62,   411,  1143,    62, 31476,     7,
#             944,    11,  1885,   498,  4448,    11,   287,   457,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 2860,   62, 8499,   62, 3866,   69, 7569,    7,  944,
#              8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 33885,    62,  6098,  1077,     7,   541,    88,
#           41947,    11, 10662,    83, 13645,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    66, 21130,    62, 21858,    62,  5143,     7,
#             944,    11, 15290,    62,  4023,    62,  5143,    11, 15290,    62,
#              79,   363,  4559,    11, 48260,    62,   312,    11,  1848,    62,
#             312,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 40972,   576,    62, 19608,  8079,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   329,    62,  4480,    62, 45286,    62, 43358,    62, 25167,
#              62,  6759,  8609,     7,    75,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 18325,    62,    83, 19944,    62, 10057,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299,  900,   62, 1078, 7657,   62, 6738,   62, 3672,    7,  944,   11,
#           1438,    8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 30814,    62,   272,  6704,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 17953,    62,   565,  5819,    62, 46616,    62,
#           26086,    62, 28751,     7,    67,   363,    62, 10297,    11,  2251,
#              62, 35943,    62, 39098,    62,  1659,    62, 46616,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  7645, 17660,    62,  6371,    62,   315,   879,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    69,  7569,    62,  9654,  4029,    62, 47911,
#              62,    79,   392,   292,    62,   259,    62, 37443,     7, 49572,
#           17147,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9122,    62, 19849,    62, 39098,    62,  6738,
#              62,  7266,  1177,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 21280,    62,  3919,    62, 11250,  1522,    62,
#           12384, 25480,    82,     7,   944,    11,  3758,    62, 12384, 25480,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299,  319,   62, 5143,   62,  660,  446,  593,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1416,  2850,    62, 12647,    62,    82, 24707,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 27932,   834, 20797,    62, 46265,   853,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 42298,    62, 48203,     7,   565,    82,    11,
#             299,    11,   285,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  9058,     7,   944,    11,  1366,    62,    69, 16762,    11,
#             351,    62,  9630,    11,   288,  4906,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299,  651,   62, 4906,   62, 8841,    7, 9186,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 14681,    62, 23893,     7,   944,    11, 13834,    11,
#           23991,    11, 26498,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 1462,   62, 3245,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 31197, 10025,    62,  3245,    62, 27830,    62,
#            2617,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8094,  1525,    62,   411,  1403,    62, 18302,
#           11184,    62,  7266,  4871,     7, 26801,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62,  9900,     7,   944,    11, 15290,
#              62,  8443,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 18250,  1691,    62, 18908,   364,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   256,    89,    62, 12001,  1096,     7,   944,    11,   256,
#              89,    11, 27102,  2625, 40225,  1600, 42601,  2625, 40225,  4943,
#            4613, 16092,  8079, 19182]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9288,    62,   961,    62,  6404,    62,   354,
#           14125,    62, 21754,    62,   961,    62,   505,    62, 28311,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  3424,    62, 19726,   873,     7,  3846,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2860,    62, 19608,   316,   320,   417,   522,
#              62,  1416,   282,   283,     7,   944,    11,   256,  6814,    11,
#             256,    89,    62,  2616,   425,    62,    69,  9602,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62, 35943,    62, 39098,    62,   261,
#              62, 28920,    62,    67,   363,  5143,     7,   944,    11,  6246,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1177,    62, 38568,  7700,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 47653,    62,  3245,    62,  2860,    62,  9630,
#              62,  1462,    62, 10641,  3245,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 30814,     7,   944,    11, 12429, 46265,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2998,    65,    62, 27160,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 48101,    62,   489,   333,   874,    62,   525,
#              62, 16129,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  3903,    62, 33678,    62,    77,   375,  1045,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  7220,    62,  9630,    62, 23108,    62, 27160,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 17953,    62,  9288,    62,  9945,     7,   944,    11,
#           15942, 16579,    11,  1960, 38679,   672,   527,    11,  1394,  9945,
#              28, 25101,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 48610,    62,  5936,   396,  1387,    62,  6371,
#            3419]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   687,  2617,    62, 23350,    62, 18224,    62,
#            9127,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 41049,     7,   944,    11, 15290,    62, 25480,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   787,    62,    67, 28995,    62,    81, 20471,    62, 41989,
#               7, 25811,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   900,    62, 11085,  5143,    62,    78,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  4102,    62,    67,   363,  5143,    62,  5219,    62,
#             292,    62, 13138,     7,   944,    11, 48924,    62,   312,    11,
#           48924,    62,  5143,    62,   312,    11,  4999,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 18982,    62, 16184,   539,    62,  7442,    62,   404,
#              62,  3672,     7,    82,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808, 17497,     7, 15414,    62, 19608,   292,   316,    11,
#            2546,    11,  6482,    11, 33769,    11,  4268,    62,  2787,   391,
#            1082,    11,  1438,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12853, 15699,     7,  1092,    62,  8841,    62,
#              67,  4906,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 19667,  7469,     7,   404,    62,  4906,    11,  1438,
#              11,   708,  3808,    28, 14202,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299, 1332,   62, 9888,   62, 1525,   62,  738,  414,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62,  687, 3245,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12001,    62,  1102, 38669,    62, 25747,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   374, 14655,    62,  2536,  3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8899,   445,    62, 21858,    62,  3672,     7,
#             944,    11, 15290,    62,  1136,    62, 25480,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 33678,    62,    79,   541,  4470,    62, 21858,
#               7,   944,    11, 15290,    62, 16366,     8,  4613,  6045]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2198,     7,   944,    11, 12429, 46265, 22046,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4686,    62,  1640,    62, 18242,     7,   944,    11,  4686,
#              62,    11,  6376,  2625,    15,  4943]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    69,  7569,    62, 13345, 10146,    62,  6738,
#              62, 48806,     7,   944,    11, 45218, 15908,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  4906,    62, 18224,    62, 41684,  9630,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   300,    17,    62,  3617,  6017,     7,   944,    11, 19590,
#              11,   300,    17,    62,  2301,    62, 41402,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2106,    62,  3866,  1442,     7,   944,    11,  3293,  1806,
#           11639,  3256,   355,    62, 40290,    28, 17821,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 34642,    62,  7785,    62, 14933,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2118,    62,    83, 15970,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 21018,    62, 24875,    62, 15596,    62,   261,
#              62, 32165,   495,     7,   944,    11,  1281,    62, 15596,    11,
#             598,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 9058,    7,  944,   11,  288, 4906,   11, 2446,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11,  1635, 22046,    11,
#           12429, 46265, 22046,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    49,  1603, 11522, 29495,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 47653,    62,  3245,    62,    78,    17,    78,
#              62,  1462,    62,    69,    74,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 13255,    62,  1837,   907,     7,   298,  1678,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2198,    62,  6359,    62,   404,     7, 20274,    11, 25439,
#              11,   269, 22046,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    64, 20663,   834,  7784,   278,    62,  2554,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 15883,    62, 43551,     7,   944,    11,  6808,    11,
#            1635,    11,  1438,  2625, 43551,  4943]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 12233,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11, 19016,    11, 26827,
#              11,  6284,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593,  2617,  5219,   834,     7,   944,    11,  1181,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 13345,   540,    62,  4993,  8116,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 13959,    62,  9654,    62,  3849,  2100,    62,
#            4480,    62,   672,  3168,   590,  3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299, 1332,   62,  259, 1851,  834, 2545,   62, 7784, 3166,    7,  944,
#              8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 4808, 2220,   62, 7890,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 11593, 12381,   834,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[4299,  900, 4933,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 11593, 40406,     7,   944,     8,  4613,  6045]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 26295,    62,  1078,  3808,     7,   944,    11, 26295,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 26340,    62, 11299,    62,  2787,  8325,     7, 25927,    11,
#            2882,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2018,    62, 33885,     7,   944,    11,  9720,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 13159,    62,  9122,    62,  1102,  2536,  2913,
#              62,  1662,    62, 15999,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12501,   261, 15019,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62, 30053,    62, 14933,    62,    79,
#             392,   292,    62,  4480,    62, 29503,    62,  3919,    62, 43917,
#               7, 14933,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9630,    62,  3003,     7,   944,    11, 26181,
#              11,  1994,    11,  2938,    11,  1188,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4941,    62, 15414,    82,    62, 23032,    62, 48554,  1108,
#              62,  9060,    62,    83, 22854,  3419]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  5412,     7,   944,    11,  1635,    69,  9602,    62, 23912,
#            1424,    11, 12429, 25811,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 16663,    62,  1236,  8652,   434,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  9122,    62,  2617,  9186,    62,   259, 12102,     7,
#             944,    11,  5240,    11, 12515,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,   284,    62, 29412,     7,   944,    11,   479,    86,    11,
#            1181,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  5078,    62,  1462,    62, 33803,     7,   944,    11,  2700,
#              62, 37635,    28, 25101,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808,   292, 13361,    62,  9122,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2207,     7,   944,    11,  8631,    11,   269,   824,    62,
#           21230,    28, 25101,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  4002,    62,  6371,    62, 45688,    62,  6649,
#            1077,    62,   445,  1060,    82,    62, 38235,    62,   361,    62,
#            1662,    62, 41299,  3474,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  5772,   316,   380,  2736,     7,  7645, 23914,    62,  4480,
#              62, 15414,    82,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   318,    62,  2616,     7,   944,     8,  4613, 20512]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    65, 14796,    62,    69, 31937,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  5143,    62, 35943,     7,   944,    11, 15290,
#              62, 25480,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  6559,    88,    62, 14259,    62, 12154,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12947,    82,  9741,    62,    77, 39223,    62,
#              67, 19199,    62, 31364,     7,   944,    11,   597,    62,  5305,
#              62,    77, 32152,    62,    67,  4906,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4296,    62,    85,  6359,     7,   944,    11,   277,  3672,
#              11,  6376,    11,  2700,    28, 25101,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  2251,    62, 39873,    62,  7890,     7,    77,    62,   457,
#              82,    28,  1495,    11,   751,    62,  3919,   786,    28, 25101,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  5171,    62,   647,   469,    62, 47730,     7,
#             944,    11,   460,    62,   647,   469,    62, 35943,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 35487,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 35312,    62,   738,  7483,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 14976,    62, 26272,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 46911,  1096,    62, 25747,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332, 13715,  6719, 16005,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11,  1635,    11,   264,
#            6058,    28, 14202,    11,  4903,   296,    62,  4906,    28, 14202,
#              11, 12429, 46265, 22046,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 14774,    62, 15414,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 15772,    62, 42895,     7, 42895,    11,  4589,    62, 17831,
#              11, 14601,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1429,    62, 13564,     7, 40539,    62, 19662,    11, 13834,
#              62, 46803,    11,   277,    62,   259,    11,   277,    62,   448,
#              28, 14202,    11,  4596,    28, 25101,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  6291,    62, 15414,    82,    62,  1102,  1851,    62,  8043,
#              62, 13200,    62,  9060,    62,    83, 22854,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 34960,   605,    62,    75, 28372,    62, 33967,
#              62,   282,  5902,    62,   259, 12102,    62, 18747,     7,   282,
#            5902,    11, 11454,    62,  4906,    11, 11454,    62, 19662,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   259,    62,   292,    62,    37,    62, 15252,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  6359, 41871,    62, 44453,    62,   496,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808, 12518,    62, 33885,    62,   271,    62,  1493,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 13287,    62, 35428, 14520,    62, 12647,    62,
#              89,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62, 37043,    62,  2502, 13154,    62,
#           12286,    82,     7,   944,    11, 36253,    62, 16366,    62,    76,
#             735,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 30073,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 12818, 33967,    62, 11265,  1096,    62, 10378,
#           31023,     7, 22362,   320,  1352,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,   961,    62, 13564,    62,   260,   961,    62,
#              67,  8326,  1314,     7,   944,    11,  2393,    11,  4818,   499,
#             776,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9688,    62, 29412,    62,    79,   541,  4470,
#               7,   944,    11, 15290,    62, 16737,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 33295,    62,  6649,  1077,    62,  3919,    62,
#             445,  1060,    62,   261,    62, 32782,    62,   259,    62, 30531,
#              62, 23144,    62,  6371, 10414,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  8899,    62,  4480,    62, 11600,    62,   273,
#              62, 25076,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  6818,    62,   853,    74,  1084,    62, 43420,    62, 48203,
#               7,  5420,    62, 17080,    11,  1233,    11,  1006,    62,   521,
#            1063,    11, 36525,    11,   374,    83,   349,    28,    16,    68,
#              12,    22,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  9122,    62,  7784,   560,    62, 26209,    62, 24396,
#               7,   395,   320,  1352,    11,  2882,    62, 24396,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  2198,    62, 17143,    62, 12102,   341,     7,  3672,    11,
#            3959,  1352,    62, 11612,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 35487,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 11593, 11925,   834,     7,   944,     8,  4613,   493]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2676,   341,    62, 26238,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    81,    79,   322,    62, 20887,     7,  8367,
#              11,   355, 18747,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2787,  8325,    62,  9579,    62, 23599,    62,
#              76,    17,    76,    62,  5363,    62, 37153,     7,   944,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 24455,    62,   261,    62, 30619,    62,  2539,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 6494,   62, 3798, 9269,    7,  944,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  1136,    62,  1324,    62, 11250,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 21048,    62, 37266,    62, 12102,   341,     7,
#            3672,    11, 12200,    11, 42287,    11, 11454,    62,  4906,    11,
#           11454,    62, 19662,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  4808,  7266,    62, 19608,   316,   320,   417,   522,    62,
#            1416,   282,   283,     7,   944,    11,   584,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[4299,  900, 4933, 9487,    7,  565,   82,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332, 26628,   303, 10082, 15748,  6030,   818, 20035,  6030,
#           49925,     7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 10568,    62, 38011,    62, 17143,  2357,     7,   944,    11,
#           17050,    11,  4637,    11, 44161,    11,  5772,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 17953,    62, 11249,     7,   944,    11, 15290,
#              62, 25480,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 25850,   278,    62, 29510,    62,  7753,     7,
#             944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 29412,    62, 13345,   540,    62,   853,  2886,
#              62,   533,    62, 11498,   489,   265,  1143,     7,   944,    11,
#           48924,    62, 10297,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  2306,  3028, 36435,    62,  2364,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 10134,    62, 40985,    62, 31642,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,  9319,    62,   298, 28338,    62, 21078,    62,
#            2539,    62,  7207, 10146,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 24592,    62,  2875,    62,  4480,    62,  8423,
#              62, 11085,    62, 12957,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  5794,  9876,     7,   944,    11, 34537,    11,  8263,    11,
#            1989,    11,   279, 11286,    81,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62,    79,   392,   292,    62,  2616,    62,  1102,
#            2536,  2913,    62,  4480,    62, 30094,    62,  2616,  3419]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 22179,    62,   261,    62, 25076,     7,   944,
#              11,  2496,    62, 10459,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299, 11593, 15003,   834,     7,   944,    11, 26235,    28, 14202,
#              11,  7368,    62, 18211,    28, 14202,    11,  5894,    62,  5143,
#              28, 14202,    11,  6152,    62, 22915,    28, 14202,     8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 22877,    62, 12001,  1096,    62,  4131, 29709,
#              62,  5589,   265,     7,   944,     8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 34574,   378,    62,  5239,  3245,     7,   944,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,   795,    77,   396,     7, 10951,    11,  6808,    11,  4808,
#               8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 17425,     7,   944,    11,   753, 15908,    82,    11,  9195,
#           15908,    82,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299,  1332,    62, 11487,    62,  3672,    62,   600,   305, 31308,
#               7,   944,     8]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 3388, 3682,    7, 9630,  263,   62,  282,    8]],
#         device='cuda:0', dtype=torch.int32),
#  tensor([[ 4299, 16021,    62,  2704,   541,     7,   944,     8,  4613,   347,
#            9969, 14253]], device='cuda:0', dtype=torch.int32),
#  tensor([[4299, 1332,   62, 2220, 2998,    7,  944,    8]], device='cuda:0',
#         dtype=torch.int32),
#  tensor([[ 4299,  4808, 31364,    62,  7146,  2339,    62,   404,     7,   944,
#              11,   584,    11,  1034,     8,  4613, 45941,    13,   358, 18747,
#             930,  5045,   276, 12514, 19182]], device='cuda:0',
#         dtype=torch.int32)]

# %%
input_ids_list[0]
# Out:
# tensor([[ 4299,  4808, 39014,    62, 14421,    62,  1370,    62,  8929,  2971,
#              7,   944,     8]], device='cuda:0', dtype=torch.int32)

# %%
#model( input_ids = input_ids_list[0], labels = input_ids_list[0].to(torch.long).to(device) )

# %%
df_subset['size'].describe()
# Out:
# count     382.000000
# mean      301.971204
# std       224.503796
# min        65.000000
# 25%       132.000000
# 50%       233.500000
# 75%       412.750000
# max      1016.000000
# Name: size, dtype: float64

# %%
df_subset.head()
# Out:
#    Unnamed: 0  size                                                ids m_name
# 0        4710   295  [4299, 4808, 39014, 62, 14421, 62, 1370, 62, 8...     c1  \
# 1       37857   237  [4299, 1332, 62, 28665, 62, 7645, 16354, 62, 8...     c1
# 2       18219   248  [4299, 1332, 62, 4774, 62, 12102, 341, 62, 259...     c1
# 3       12285    89  [4299, 1332, 62, 17752, 62, 354, 945, 316, 7, ...     c1
# 4       13331   188  [4299, 1332, 62, 1069, 4516, 62, 13116, 62, 26...     c1
#
#                                                 code ast_errors  n_ast_errors
# 0  def _apply_current_line_highlight(self):\n    ...         []             0  \
# 1  def test_column_transformer_tuple_transformers...         []             0
# 2  def test_host_validation_in_debug_mode(self):\...         []             0
# 3  def test_json_charset(self):\n        response...         []             0
# 4  def test_exception_report_uses_meta_filtering(...         []             0
#
#    ast_levels  n_whitespaces_  complexity  ...
# 0          11              32           3  ...  \
# 1          11              32           1  ...
# 2          11              37           2  ...
# 3          10              10           1  ...
# 4          10              17           1  ...
#
#                                          outcome_c10
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n        ...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c10
# 0  [[4299, 4808, 39014, 62, 14421, 62, 1370, 62, ...  \
# 1  [[4299, 1332, 62, 28665, 62, 7645, 16354, 62, ...
# 2  [[4299, 1332, 62, 4774, 62, 12102, 341, 62, 25...
# 3  [[4299, 1332, 62, 17752, 62, 354, 945, 316, 7,...
# 4  [[4299, 1332, 62, 1069, 4516, 62, 13116, 62, 2...
#
#                                          outcome_c11
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n    self...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c11
# 0  [[4299, 4808, 39014, 62, 14421, 62, 1370, 62, ...  \
# 1  [[4299, 1332, 62, 28665, 62, 7645, 16354, 62, ...
# 2  [[4299, 1332, 62, 4774, 62, 12102, 341, 62, 25...
# 3  [[4299, 1332, 62, 17752, 62, 354, 945, 316, 7,...
# 4  [[4299, 1332, 62, 1069, 4516, 62, 13116, 62, 2...
#
#                                          outcome_c14
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n    asse...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c14
# 0  [[318, 485, 4998, 63, 1818, 63, 604, 63, 14337...  \
# 1  [[318, 511, 63, 2301, 63, 19754, 63, 2960, 63,...
# 2  [[318, 511, 63, 1102, 63, 6136, 63, 262, 63, 1...
# 3  [[318, 511, 63, 1001, 63, 6043, 8, 277, 9, 103...
# 4  [[318, 511, 63, 1971, 63, 3070, 63, 5589, 63, ...
#
#                                          outcome_c15
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n        ...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c15
# 0  [[318, 485, 4998, 63, 1818, 63, 604, 63, 14337...  \
# 1  [[318, 511, 63, 2301, 63, 19754, 63, 2960, 63,...
# 2  [[318, 511, 63, 1102, 63, 6136, 63, 262, 63, 1...
# 3  [[318, 511, 63, 1001, 63, 6043, 8, 277, 9, 103...
# 4  [[318, 511, 63, 1971, 63, 3070, 63, 5589, 63, ...
#
#                                          outcome_c16
# 0  def _apply_current_line_highlight(self) -> boo...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n        ...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c16
# 0  [[4299, 4808, 39014, 62, 14421, 62, 1370, 62, ...
# 1  [[4299, 1332, 62, 28665, 62, 7645, 16354, 62, ...
# 2  [[4299, 1332, 62, 4774, 62, 12102, 341, 62, 25...
# 3  [[4299, 1332, 62, 17752, 62, 354, 945, 316, 7,...
# 4  [[4299, 1332, 62, 1069, 4516, 62, 13116, 62, 2...
#
# [5 rows x 40 columns]

# %%
max_new_tokens = int(df_subset['size'].mean())

# %%
generated_list=[]
generated_vector=[]
for i in range(SAMPLE_SIZE):
    generated = model.generate(input_ids_list[i],do_sample=True, pad_token_id=tokenizer.eos_token_id, max_new_tokens=max_new_tokens) # <- max_new_tokens is the mean of the ground truth size
    generated_vector.append(generated)
    generated_list.append(tokenizer.batch_decode(generated, skip_special_tokens=True))

# %%
df_subset['outcome_'+CASE] = [tensor[0] for tensor in generated_list]
df_subset['outcome_vector_'+CASE] = [tensor.cpu().numpy() for tensor in generated_vector]

# %%
df_subset.head()
# Out:
#    Unnamed: 0  size                                                ids m_name
# 0        4710   295  [4299, 4808, 39014, 62, 14421, 62, 1370, 62, 8...     c1  \
# 1       37857   237  [4299, 1332, 62, 28665, 62, 7645, 16354, 62, 8...     c1
# 2       18219   248  [4299, 1332, 62, 4774, 62, 12102, 341, 62, 259...     c1
# 3       12285    89  [4299, 1332, 62, 17752, 62, 354, 945, 316, 7, ...     c1
# 4       13331   188  [4299, 1332, 62, 1069, 4516, 62, 13116, 62, 26...     c1
#
#                                                 code ast_errors  n_ast_errors
# 0  def _apply_current_line_highlight(self):\n    ...         []             0  \
# 1  def test_column_transformer_tuple_transformers...         []             0
# 2  def test_host_validation_in_debug_mode(self):\...         []             0
# 3  def test_json_charset(self):\n        response...         []             0
# 4  def test_exception_report_uses_meta_filtering(...         []             0
#
#    ast_levels  n_whitespaces_  complexity  ...
# 0          11              32           3  ...  \
# 1          11              32           1  ...
# 2          11              37           2  ...
# 3          10              10           1  ...
# 4          10              17           1  ...
#
#                                          outcome_c11
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n    self...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c11
# 0  [[4299, 4808, 39014, 62, 14421, 62, 1370, 62, ...  \
# 1  [[4299, 1332, 62, 28665, 62, 7645, 16354, 62, ...
# 2  [[4299, 1332, 62, 4774, 62, 12102, 341, 62, 25...
# 3  [[4299, 1332, 62, 17752, 62, 354, 945, 316, 7,...
# 4  [[4299, 1332, 62, 1069, 4516, 62, 13116, 62, 2...
#
#                                          outcome_c14
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n    asse...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c14
# 0  [[318, 485, 4998, 63, 1818, 63, 604, 63, 14337...  \
# 1  [[318, 511, 63, 2301, 63, 19754, 63, 2960, 63,...
# 2  [[318, 511, 63, 1102, 63, 6136, 63, 262, 63, 1...
# 3  [[318, 511, 63, 1001, 63, 6043, 8, 277, 9, 103...
# 4  [[318, 511, 63, 1971, 63, 3070, 63, 5589, 63, ...
#
#                                          outcome_c15
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n        ...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c15
# 0  [[318, 485, 4998, 63, 1818, 63, 604, 63, 14337...  \
# 1  [[318, 511, 63, 2301, 63, 19754, 63, 2960, 63,...
# 2  [[318, 511, 63, 1102, 63, 6136, 63, 262, 63, 1...
# 3  [[318, 511, 63, 1001, 63, 6043, 8, 277, 9, 103...
# 4  [[318, 511, 63, 1971, 63, 3070, 63, 5589, 63, ...
#
#                                          outcome_c16
# 0  def _apply_current_line_highlight(self) -> boo...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n        ...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c16
# 0  [[4299, 4808, 39014, 62, 14421, 62, 1370, 62, ...  \
# 1  [[4299, 1332, 62, 28665, 62, 7645, 16354, 62, ...
# 2  [[4299, 1332, 62, 4774, 62, 12102, 341, 62, 25...
# 3  [[4299, 1332, 62, 17752, 62, 354, 945, 316, 7,...
# 4  [[4299, 1332, 62, 1069, 4516, 62, 13116, 62, 2...
#
#                                          outcome_c17
# 0  def _apply_current_line_highlight(self) -> Non...  \
# 1  def test_column_transformer_tuple_transformers...
# 2  def test_host_validation_in_debug_mode(self) -...
# 3  def test_json_charset(self) -> None:\n        ...
# 4  def test_exception_report_uses_meta_filtering(...
#
#                                   outcome_vector_c17
# 0  [[4299, 4808, 39014, 62, 14421, 62, 1370, 62, ...
# 1  [[4299, 1332, 62, 28665, 62, 7645, 16354, 62, ...
# 2  [[4299, 1332, 62, 4774, 62, 12102, 341, 62, 25...
# 3  [[4299, 1332, 62, 17752, 62, 354, 945, 316, 7,...
# 4  [[4299, 1332, 62, 1069, 4516, 62, 13116, 62, 2...
#
# [5 rows x 42 columns]

# %% [markdown]
# ### Checkpoint save subset

# %%
df_subset.to_json(path)

# %% [markdown]
# ## BLUE and CodeBLUE score evaluation

# %%
import sys
import logging

# %%
logging.basicConfig(
    filename="../datax/logs/canonical_evaluation_log.txt",
    filemode='a',
    format='%(asctime)s : %(levelname)s : %(message)s', 
    level=logging.INFO
    )

# %%
## Params for codebleu: alpha, beta, gamma, theta
params='0.25,0.25,0.25,0.25'
lang= 'python'

# %%
# This line is needed to load the local CodeBLEU library. Do not use it to export this notebook!!
sys.path.append('/workspaces/CodeSyntaxConcept/scripts')

# %%
## based on microsoft script for calculating codeBLEU in codeSearchNet
import CodeBLEU.bleu as bleu
import CodeBLEU.weighted_ngram_match as weighted_ngram_match
import CodeBLEU.syntax_match as syntax_match
import CodeBLEU.dataflow_match as dataflow_match

# %%
def calculate_bleu_codeBleu(lang,params,df, gt_col, pred_col, keywords):
    alpha,beta,gamma,theta = [float(x) for x in params.split(',')]
    # preprocess inputs
    pre_references = [df[gt_col].to_list()]
    hypothesis = df[pred_col].to_list()
    for i in range(len(pre_references)):
        assert len(hypothesis) == len(pre_references[i])

    references = []
    for i in range(len(hypothesis)):
        ref_for_instance = []
        for j in range(len(pre_references)):
            ref_for_instance.append(pre_references[j][i])
        references.append(ref_for_instance)
    assert len(references) == len(pre_references)*len(hypothesis)


    # calculate ngram match (BLEU)
    tokenized_hyps = [x.split() for x in hypothesis]
    tokenized_refs = [[x.split() for x in reference] for reference in references]

    ngram_match_score = bleu.corpus_bleu(tokenized_refs,tokenized_hyps)
    
    # calculate weighted ngram match
    keywords = [x.strip() for x in open(keywords, 'r', encoding='utf-8').readlines()]
    def make_weights(reference_tokens, key_word_list):
        return {token:1 if token in key_word_list else 0.2 \
                for token in reference_tokens}
    tokenized_refs_with_weights = [[[reference_tokens, make_weights(reference_tokens, keywords)]\
                for reference_tokens in reference] for reference in tokenized_refs]

    weighted_ngram_match_score = weighted_ngram_match.corpus_bleu(tokenized_refs_with_weights,tokenized_hyps)

    # calculate syntax match
    syntax_match_score = syntax_match.corpus_syntax_match(references, hypothesis,lang)

    # calculate dataflow match
    dataflow_match_score = dataflow_match.corpus_dataflow_match(references, hypothesis,lang)

    logging.info('ngram match: {0}, weighted ngram match: {1}, syntax_match: {2}, dataflow_match: {3}'.\
                        format(ngram_match_score, weighted_ngram_match_score, syntax_match_score, dataflow_match_score))

    code_bleu_score = alpha*ngram_match_score\
                    + beta*weighted_ngram_match_score\
                    + gamma*syntax_match_score\
                    + theta*dataflow_match_score

    logging.info('CodeBLEU score: '+ str(code_bleu_score))
    return ngram_match_score, code_bleu_score

# %%
lang='python'
keywords = '/workspaces/CodeSyntaxConcept/scripts/CodeBLEU/keywords/'+lang+'.txt'

# %%
CASE
# Out:
# 'c17'

# %%
bleuScore, codebleuScore = calculate_bleu_codeBleu(lang,params,df_subset,'code','outcome_'+CASE,keywords)

# %%
print('Blue: {} CodeBLEU: {}'.format(bleuScore,codebleuScore) )
logging.info(f"Case: '{CASE}' Blue: '{bleuScore}' CodeBLEU: '{codebleuScore}'")
# Out:
# Blue: 0.01647760506203721 CodeBLEU: 0.1817452442204766

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Clean-up model cache.

# %% [markdown]
# This section is optionl, however, consider to delete any previous model from cache if you wont use it later

# %%
import shutil

# %%
try:
    folder_name= parameters['cache_dir']
    shutil.rmtree(folder_name)
    print(f"The folder '{folder_name}' has been successfully deleted.")
except FileNotFoundError:
    print(f"The folder '{folder_name}' does not exist.")
except OSError as e:
    print(f"Error occurred while deleting the folder '{folder_name}': {e}")
# Out:
# The folder '../data/hugginface/cache/models' has been successfully deleted.
