# %% [markdown]
# # Statistical Module (Bootstrapping)

# %% [markdown]
# >
# > Aggregation Module with Bootstrapping Algorihtms.
# >

# %%
#| default_exp statistics

# %%
#| export
import pandas as pd
import os
import time
import numpy as np
import torch
import gc

# %%
#| export

import logging
logging.basicConfig(
    filename="logger_data_engineering.txt",
    filemode='a',
    format='%(asctime)s : %(levelname)s : %(message)s', 
    level=logging.INFO
    )

# %%
#| export

import seaborn as sns
from scipy import stats
from statistics import NormalDist
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Engineering

# %%
#| export

def c_eleuther( returnModel = False, model_type =  'EleutherAI/gpt-neo-125m'):
    ''' Eleuther and Salesforce and Parrot uses the same importation'''
    from transformers import AutoTokenizer, AutoModelForCausalLM
    tokenizer = AutoTokenizer.from_pretrained(model_type)
    logging.info("Tokenizer Loaded")
    if returnModel:
        model = AutoModelForCausalLM.from_pretrained(model_type)
        logging.info("Model Loaded")
    else:
        model = []
    
    logging.info(model_type)
    return tokenizer, model
    
    

def init_model_args( current_case = 'c1', returnModel = False ): 
    
    code_models = {
        'c1':('EleutherAI/gpt-neo-125m', ), # Basic (on Pile) GPT-3/J
        'c2':('EleutherAI/gpt-neo-1.3B', ),
        'c3':('EleutherAI/gpt-neo-2.7B', ),
        'c4':('EleutherAI/gpt-j-6b', ),
        'c5':('Salesforce/codegen-350M-nl', ), #Basic (on Pile) codegen
        'c6':('Salesforce/codegen-2B-nl', ),
        'c7':('Salesforce/codegen-6B-nl', ),
        'c8':('Salesforce/codegen-16B-nl', ),
        'c9':('codeparrot/codeparrot-small-multi', ), #multi-Language
        'c10':('Salesforce/codegen-350M-multi', ),
        'c11':('Salesforce/codegen-2B-multi', ),
        'c12':('Salesforce/codegen-6B-multi', ),
        'c13':('Salesforce/codegen-16B-multi', ),
        'c14':('codeparrot/codeparrot-small', ), #mono-Language
        'c15':('codeparrot/codeparrot', ),
        'c16':('Salesforce/codegen-350M-mono', ),
        'c17':('Salesforce/codegen-2B-mono', ),
        'c18':('Salesforce/codegen-6B-mono', ),
        'c19':('Salesforce/codegen-16B-mono', ),
    }
    
    model_type = code_models[current_case][0]
    tokenizer, model =  c_eleuther( returnModel = returnModel,  model_type = model_type ) 
    
    
    return model_type, tokenizer, model

# %% [markdown]
# ## Init Parameters

# %%
#| hide
#| eval: false
# [WARNING] Hyperparameters changes, please tune them up
CODEMODEL =  'c17'
params = {
    'codemodel' : CODEMODEL,
    'numpy_files_logits_path': f'../datax/np_files_logits/{CODEMODEL}',
    'testbeds_path' : '../datax/testbeds/AstEvalVerticalFiltered.json',
    'outputs' : f'../data/ds_raw_logits/out_astevalverticalfiltered_{CODEMODEL}.csv'
}

# %%
#| hide
#| eval: false
params['outputs']
# Out:
# '../data/ds_raw_logits/out_astevalverticalfiltered_c17.csv'

# %%
#| hide
#| eval: false
#Uploading Model UnderAnalisys
name, tokenizer, model = init_model_args(
    current_case = params['codemodel'], 
    returnModel = False #[WARNING!] Check the parameters before calling it. 
    )

# %%
#| hide
#| eval: false
#Testing data loads
data_pd = pd.read_json( params['testbeds_path'] )
data_pd.head(1)
# Out:
#    size                                                ids m_name
# 0   280  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...     c1  \
#
#                                                 code ast_errors  n_ast_errors
# 0  def run_python_tests(test_modules, parallelism...         []             0  \
#
#    ast_levels  n_whitespaces_  complexity  nloc  token_counts  n_ast_nodes
# 0          13              67           7    15           120          154

# %% [markdown]
# # Softmax Normalization and Data Engineering

# %%
#| hide
#| eval: false
filtered_prompts_ids = data_pd[data_pd['m_name']==params['codemodel']]['ids'].values

# %%
#| hide
#| eval: false
tf_input_ids = [torch.tensor(  input_ids, dtype = torch.int) for input_ids in filtered_prompts_ids ]

# %% [markdown]
# ### Testing Tokenizer

# %%
#| hide
#| eval: false
#Testung Sample to validate minmax functions
sample_id = 0
data_pd[data_pd['m_name']==params['codemodel']].iloc[sample_id]
# Out:
# size                                                            225
# ids               [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...
# m_name                                                          c17
# code              def run_python_tests(test_modules, parallelism...
# ast_errors                                                       []
# n_ast_errors                                                      0
# ast_levels                                                       13
# n_whitespaces_                                                   67
# complexity                                                        7
# nloc                                                             15
# token_counts                                                    120
# n_ast_nodes                                                     154
# Name: 815536, dtype: object

# %%
#| hide
#| eval: false
tf_input_ids[sample_id]
# Out:
# tensor([ 4299,  1057,    62, 29412,    62, 41989,     7,  9288,    62, 18170,
#            11, 10730,  1042,    11,   351,    62,  1073,  1857,    28, 25101,
#          2599,   198, 50284,  2617,    62,  7839,    62,   392,    62,  9967,
#          7203, 28768,  9485,  4561,   668,  5254,  1600,   366,  9148, 11290,
#            62,    47,    56,  4303, 14175,    62,  4944,  2043,    62,    51,
#          1546,  4694,  4943,   628, 50284,   361,   351,    62,  1073,  1857,
#            25,   198, 50280,     2, 33998,  1838,   262,  9485,  4561,   668,
#          5254,   781, 15492,  2233,   284,  4334, 10730,  1042,    13,   198,
#         50280,     2,  1649,   356,  1057,  9485,  4561,   668,  5254,   351,
#          5197,    11,   340,  3544,   604,   329,   783,   355,   198, 50280,
#             2, 46513,    13,   198, 50280,  1845, 29363,  1042,   796,   604,
#           198, 50280, 12048,   796,   366,  5143,    12, 41989,    12,  4480,
#            12,  1073,  1857,     1,   198, 50284, 17772,    25,   198, 50280,
#         12048,   796,   366,  5143,    12, 41989,     1,   198, 50284, 21812,
#           796,   685,   418,    13,  6978,    13, 22179,     7,  4303, 14175,
#            62, 39069,    11,   366, 29412,  1600,  4226, 15437,   198, 50284,
#           361,  1332,    62, 18170, 14512,   685, 18170,    13, 15763,  5974,
#           198, 50280, 21812,    13, 33295,  7203,   438, 18170,    28,     4,
#            82,     1,  4064,   705,  4032,    13, 22179,     7,    76,    13,
#          3672,   329,   285,   287,  1332,    62, 18170,  4008,   198, 50284,
#         21812,    13, 33295,  7203,   438,  1845, 29363,  1042,    28,     4,
#            72,     1,  4064, 10730,  1042,     8,   198, 50284,  5143,    62,
#         28758,     7, 21812,     8,   628], dtype=torch.int32)

# %%
#| hide
#| eval: false
# Loading Logits From Files
out= np.load( params['numpy_files_logits_path'] +'/' + f'logits_tensor[{sample_id}]_batch[{sample_id}]_model[{CODEMODEL}].npy' )
soft = torch.nn.Softmax( dim = 0 ) #Flattening normalization
first_token_distribution = soft( torch.from_numpy(out[0]) ) #Flattening normalization for fist token
assert round(first_token_distribution.sum().item()) == 1.0

# %%
#| hide
#| eval: false
first_token_distribution[0]
# Out:
# tensor(1.5081e-05)

# %%
#| hide
#| eval: false
tokenizer.decode([7881])
# Out:
# ' register'

# %%
#| hide
#| eval: false
tokenizer.vocab.keys()
# Out:
# dict_keys(['ĠPubMed', 'elvet', 'erential', '41', 'scroll', 'Ġacquiring', 'XT', 'Laughs', 'Ġelectroly', 'Ġsaints', 'ĠLaw', 'steps', '1996', 'Ġheck', 'ĠDot', 'ĠMate', 'ĠToken', 'Pri', 'grounds', 'ĠTrader', '426', 'Ġbiologically', 'Ġpens', 'ube', 'onnaissance', 'ĠFixed', 'wage', 'liber', 'ĠPBS', 'Ġspheres', 'Vo', 'ĠAnd', 'ĠDodgers', 'Ġworkouts', 'ĠNish', 'Ġheats', 'ĠLAT', 'ĠHO', 'Ġmor', 'ĠTrailer', 'Ġconce', 'ands', 'Only', 'Ġmil', 'ichick', 'Ġworkflow', 'Ġdefenders', 'ĠARE', 'retch', 'ĠBrass', 'Ġindu', 'ĠBrist', 'ĠLDL', 'ichen', 'ĠReconstruction', 'ĠMET', 'arkable', '779', '±', 'Marg', 'uce', 'Ġnausea', 'Ġrubbed', 'rier', 'ĠViet', 'ĠConvention', 'ĠAfghanistan', 'Sunday', 'Ġmantra', 'Ġsilhouette', 'çīĪ', 'Ġgenerating', 'water', 'Ġ",', 'ĠSAS', 'ĠAlchemist', 'ĠRelative', 'Ġreused', 'Ġ337', 'priority', 'ĠCascade', 'Ġsymmetry', 'Ġovere', 'Ġcontingent', 'Ġseq', 'ĠKis', 'ÏĦ', 'Ġbatted', 'ĠFew', 'threat', 'Ġlayer', 'reys', 'XX', 'Ġrefining', 'tty', 'Nov', 'âĢ¦]', 'Ġadultery', 'ĠSon', 'Ġarr', 'Ġswitches', 'Ġcompetitors', 'Ġunob', 'Ġoceans', 'alach', 'Ġtwo', 'female', 'Ġbroaden', 'mate', 'were', 'ĠErin', 'treatment', 'aken', 'Cro', 'uni', 'ĠAscension', 'Ġfaults', 'Ġstick', 'Ġentertaining', 'Direct', 'Ġeman', 'ĠCoverage', 'trained', 'Ġextracted', 'ĠKurd', 'verages', 'ĠVietnam', '416', 'ĠClifford', 'ĠMLS', 'ĠChaff', 'ĠBE', 'ouched', 'iform', 'cos', 'Ġ420', 'ĠLomb', 'Ġblocks', 'Ġmargin', 'raine', 'Ġdividing', 'ĠFront', '_-', 'ocaly', 'Later', 'ĠNamed', 'Ġservings', 'Ġlip', 'Ġlinguistic', 'ACC', 'Ġtire', 'ĠDPS', 'ĠModified', 'Ġpercentage', 'MAP', 'Ġclubhouse', 'uman', 'Ġwiped', 'esthesia', 'Ġprompted', 'ergic', 'Ġadvent', 'Ġenactment', 'portion', 'regation', 'Ġvaluable', 'Ġstarved', 'ĠKashmir', 'Ġclones', 'Sac', 'ĠCodec', 'Ġrubbish', 'ĠSakuya', 'ĠUttar', 'Ford', 'orescence', 'ĠExample', 'ĠStern', 'rator', 'braska', 'Ġorchestra', 'ĠAngels', 'ĠâĿ', 'Ġmini', 'dule', 'ĠColo', 'ovich', 'ERG', 'Ġbraking', 'ĠTBA', 'worthiness', 'Ġliable', 'Ġproperties', 'bang', 'Ġaltering', 'ience', 'arry', 'ĠSnowden', 'Ġflexibility', 'Ġbosses', 'izen', 'Ġseizing', 'ĠPhysical', 'Ġmiss', 'again', 'Ġleaflets', 'buffer', 'Ġderogatory', 'Ġcessation', 'ĠWestminster', 'Ġtomat', 'ĠSax', 'ĠMalfoy', 'Ġdilemma', 'Eat', 'Ġneedle', 'Ġbiom', 'Ġdrops', 'ĠCh', 'Ġjur', 'Many', 'ĠRome', 'widget', 'Ġob', 'alt', 'Ġintra', 'Unit', 'driver', 'Ġsoaked', '1990', 'stal', 'ĠSilicon', 'ĠFuel', 'Ġfoil', 'Ġrobotics', 'ĠDharma', 'band', 'ĠWeekly', 'ĠCisco', 'Ġinstruct', 'ĠSel', 'rived', 'ĠVolcano', 'ĠKurt', 'Jen', 'Ġdiced', 'Ġappalling', 'Ġscreenshot', 'Ġobservers', 'town', 'Ġlimbs', 'berries', 'ĠIslam', 'vag', 'Ġnominating', 'ubric', 'They', 'ĠAllaah', 'uitive', 'ĠNorth', 'gor', 'ĠAm', 'ĠBlue', 'Ġexercise', 'oday', 'Ġdoctor', 'Ġtrem', 'Ġrainy', 'fol', 'ĠConrad', 'Ġperfected', 'ihara', 'Ġ89', 'pload', '184', 'Ġdefences', 'ĠObj', 'Ġalerted', 'Ġhomosexual', 'ĊÂł', 'Ġhabitual', 'Â®,', 'Ġflags', 'Ġopposes', 'Impro', 'Wednesday', 'Hack', 'Ġindispensable', 'Ġunlaw', 'Sullivan', 'ourke', 'Ġtion', 'Ġweighs', 'ĠNegro', 'age', 'ji', 'Los', 'eries', 'Ġtrusts', 'controller', 'ĠRepublican', 'plant', 'Ġparted', 'ĠLean', 'Ġsne', 'Ġenvision', 'Ġoutdoor', 'Ġmilitant', 'Ġsensor', 'ĠShap', 'Ġvoyage', 'ĠManaging', 'ĠIntroduction', 'Ġinco', 'Ġsaga', 'e', 'apolog', 'Ġperspect', 'Ġdefining', 'Ġlimestone', 'Ġtabs', 'Ġformulations', 'ĠWays', 'MD', 'ĠMuhammad', 'ĠWyoming', 'sav', 'ells', 'Ġego', 'Ġdegrading', 'ĠSIM', 'Ġrobbing', 'washer', 'ĠCookies', 'Ġlighter', 'ĠDevelop', 'Ġbinding', 'full', 'Ġrecap', '457', 'ĠLic', 'Ġgoddess', 'Ġimped', 'Ġintel', 'Ġfer', 'Ġskirm', 'ĠGib', 'Ġaversion', 'Ġintensive', 'wu', 'Ġscraping', 'ĠIPM', 'ĠTier', 'Ġeasing', 'Ġattending', 'hunter', 'cons', 'Ġpowder', 'Ġaccomplished', 'ĠHerz', 'Ġwatched', 'hett', 'Ġjuice', 'ĠHerman', 'Ġcubic', 'riors', 'luent', 'Ġregistration', 'deg', 'ĠNP', 'Ġclimb', 'ĠLob', 'Ġindependence', 'Ġbladder', 'build', 'Ġhalftime', 'Mount', 'ĠRazor', 'istas', 'ĠRidge', 'Ġplagued', 'Ġhugging', 'ĠWelch', 'Ġstrateg', 'ĠCald', 'AAA', 'ĠMISS', 'current', 'ĠAc', 'Ġwww', 'iners ...

# %%
#| hide
#| eval: false
tokenizer.get_vocab()
# Out:
# {'ĠPubMed': 32131,
#  'elvet': 32667,
#  'erential': 33369,
#  '41': 3901,
#  'scroll': 48728,
#  'Ġacquiring': 22488,
#  'XT': 25010,
#  'Laughs': 34610,
#  'Ġelectroly': 39450,
#  'Ġsaints': 31728,
#  'ĠLaw': 3854,
#  'steps': 20214,
#  '1996': 22288,
#  'Ġheck': 22574,
#  'ĠDot': 22875,
#  'ĠMate': 24787,
#  'ĠToken': 29130,
#  'Pri': 34487,
#  'grounds': 40520,
#  'ĠTrader': 41956,
#  '426': 42780,
#  'Ġbiologically': 44479,
#  'Ġpens': 29707,
#  'ube': 3266,
#  'onnaissance': 31539,
#  'ĠFixed': 10832,
#  'wage': 21482,
#  'liber': 33203,
#  'ĠPBS': 30051,
#  'Ġspheres': 34126,
#  'Vo': 42144,
#  'ĠAnd': 843,
#  'ĠDodgers': 23576,
#  'Ġworkouts': 27197,
#  'ĠNish': 48438,
#  'Ġheats': 37876,
#  'ĠLAT': 42355,
#  'ĠHO': 40115,
#  'Ġmor': 2146,
#  'ĠTrailer': 36923,
#  'Ġconce': 8571,
#  'ands': 1746,
#  'Only': 10049,
#  'Ġmil': 1465,
#  'ichick': 38448,
#  'Ġworkflow': 30798,
#  'Ġdefenders': 16355,
#  'ĠARE': 15986,
#  'retch': 22592,
#  'ĠBrass': 32309,
#  'Ġindu': 9318,
#  'ĠBrist': 23072,
#  'ĠLDL': 37654,
#  'ichen': 41437,
#  'ĠReconstruction': 45060,
#  'ĠMET': 31243,
#  'arkable': 45543,
#  '779': 40393,
#  '±': 109,
#  'Marg': 24428,
#  'uce': 7234,
#  'Ġnausea': 32122,
#  'Ġrubbed': 31862,
#  'rier': 5277,
#  'ĠViet': 8730,
#  'ĠConvention': 11680,
#  'ĠAfghanistan': 8037,
#  'Sunday': 21934,
#  'Ġmantra': 32628,
#  'Ġsilhouette': 41834,
#  'çīĪ': 48304,
#  'Ġgenerating': 15453,
#  'water': 7050,
#  'Ġ",': 33172,
#  'ĠSAS': 35516,
#  'ĠAlchemist': 36084,
#  'ĠRelative': 45344,
#  'Ġreused': 46823,
#  'Ġ337': 42294,
#  'priority': 49336,
#  'ĠCascade': 48788,
#  'Ġsymmetry': 40686,
#  'Ġovere': 43656,
#  'Ġcontingent': 25477,
#  'Ġseq': 33756,
#  'ĠKis': 30519,
#  'ÏĦ': 32830,
#  'Ġbatted': 45754,
#  'ĠFew': 20463,
#  'threat': 19971,
#  'Ġlayer': 7679,
#  'reys': 46703,
#  'XX': 8051,
#  'Ġrefining': 39634,
#  'tty': 42852,
#  'Nov': 20795,
#  'âĢ¦]': 21476,
#  'Ġadultery': 38713,
#  'ĠSon': 6295,
#  'Ġarr': 5240,
#  'Ġswitches': 18225,
#  'Ġcompetitors': 13861,
#  'Ġunob': 41511,
#  'Ġoceans': 23744,
#  'alach': 33786,
#  'Ġtwo': 734,
#  'female': 24724,
#  'Ġbroaden': 44870,
#  'mate': 9830,
#  'were': 22474,
#  'ĠErin': 28894,
#  'treatment': 42487,
#  'aken': 1685,
#  'Cro': 35403,
#  'uni': 35657,
#  'ĠAscension': 41416,
#  'Ġfaults': 31025,
#  'Ġstick': 4859,
#  'Ġentertaining': 17774,
#  'Direct': 13470,
#  'Ġeman': 31184,
#  'ĠCoverage': 33998,
#  'trained': 35311,
#  'Ġextracted': 21242,
#  'ĠKurd': 9778,
#  'verages': 23118,
#  'ĠVietnam': 10836,
#  '416': 35218,
#  'ĠClifford': 43159,
#  'ĠMLS': 13981,
#  'ĠChaff': 46279,
#  'ĠBE': 9348,
#  'ouched': 30075,
#  'iform': 6933,
#  'cos': 6966,
#  'Ġ420': 28262,
#  'ĠLomb': 28503,
#  'Ġblocks': 7021,
#  'Ġmargin': 10330,
#  'raine': 23440,
#  'Ġdividing': 27241,
#  'ĠFront': 8880,
#  '_-': 22955,
#  'ocaly': 12063,
#  'Later': 18602,
#  'ĠNamed': 34441,
#  'Ġservings': 43096,
#  'Ġlip': 10645,
#  'Ġlinguistic': 29929,
#  'ACC': 26861,
#  'Ġtire': 15867,
#  'ĠDPS': 25366,
#  'ĠModified': 40499,
#  'Ġpercentage': 5873,
#  'MAP': 33767,
#  'Ġclubhouse': 48018,
#  'uman': 3778,
#  'Ġwiped': 21122,
#  'esthesia': 34811,
#  'Ġprompted': 12053,
#  'ergic': 19793,
#  'Ġadvent': 19980,
#  'Ġenactment': 28547,
#  'portion': 16864,
#  'regation': 43068,
#  'Ġvaluable': 8119,
#  'Ġstarved': 47224,
#  'ĠKashmir': 24664,
#  'Ġclones': 32498,
#  'Sac': 38318,
#  'ĠCodec': 39298,
#  'Ġrubbish': 35022,
#  'ĠSakuya': 37545,
#  'ĠUttar': 44744,
#  'Ford': 37308,
#  'orescence': 48699,
#  'ĠExample': 17934,
#  'ĠStern': 22990,
#  'rator': 12392,
#  'braska': 17088,
#  'Ġorchestra': 40095,
#  'ĠAngels': 17654,
#  'ĠâĿ': 43074,
#  'Ġmini': 9927,
#  'dule': 5950,
#  'ĠColo': 41943,
#  'ovich': 18198,
#  'ERG': 49837,
#  'Ġbraking': 36682,
#  'ĠTBA': 48591,
#  'worthiness': 48756,
#  'Ġliable': 17583,
#  'Ġproperties': 6608,
#  'bang': 36668,
#  'Ġaltering': 29057,
#  'ience': 1240,
#  'arry': 6532,
#  'ĠSnowden': 15015,
#  'Ġflexibility': 13688,
#  'Ġbosses': 17317,
#  'izen': 33977,
#  'Ġseizing': 37054,
#  'ĠPhysical': 16331,
#  'Ġmiss': 2051,
#  'again': 17776,
#  'Ġleaflets': 48409,
#  'buffer': 22252,
#  'Ġderogatory': 44094,
#  'Ġcessation': 35120,
#  'ĠWestminster': 20353,
#  'Ġtomat': 23414,
#  'ĠSax': 29242,
#  'ĠMalfoy': 39157,
#  'Ġdilemma': 26566,
#  'Eat': 47659,
#  'Ġneedle': 17598,
#  'Ġbiom': 27488,
#  'Ġdrops': 10532,
#  'ĠCh': 609,
#  'Ġjur': 8174,
#  'Many': 7085,
#  'ĠRome': 10598,
#  'widget': 42655,
#  'Ġob': 909,
#  'alt': 2501,
#  'Ġintra': 23422,
#  'Unit': 26453,
#  'driver': 26230,
#  'Ġsoaked': 33657,
#  '1990': 19891,
#  'stal': 7757,
#  'ĠSilicon': 18210,
#  'ĠFuel': 25483,
#  'Ġfoil': 25501,
#  'Ġrobotics': 36359,
#  'ĠDharma': 46707,
#  'band': 3903,
#  'ĠWeekly': 18168,
#  'ĠCisco': 28289,
#  'Ġinstruct': 5048,
#  'ĠSel': 15300,
#  'rived': 36207,
#  'ĠVolcano': 48380,
#  'ĠKurt': 20642,
#  'Jen': 44875,
#  'Ġdiced': 48898,
#  'Ġappalling': 34130,
#  'Ġscreenshot': 22032,
#  'Ġobservers': 17984,
#  'town': 12735,
#  'Ġlimbs': 21755,
#  'berries': 20853,
#  'ĠIslam': 3449,
#  'vag': 29821,
#  'Ġnominating': 48833,
#  'ubric': 29812,
#  'They': 2990,
#  'ĠAllaah': 49086,
#  'uitive': 33740,
#  'ĠNorth': 2258,
#  'gor': 7053,
#  'ĠAm': 1703,
#  'ĠBlue': 4518,
#  'Ġexercise': 5517,
#  'oday': 4348,
#  'Ġdoctor': 6253,
#  'Ġtrem': 10023,
#  'Ġrainy': 37259,
#  'fol': 9062,
#  'ĠConrad': 39708,
#  'Ġperfected': 42155,
#  'ihara': 45902,
#  'Ġ89': 9919,
#  'pload': 7304,
#  '184': 22883,
#  'Ġdefences': 46942,
#  'ĠObj': 38764,
#  'Ġalerted': 28608,
#  'Ġhomosexual': 11479,
#  'ĊÂł': 44320,
#  'Ġhabitual': 46020,
#  'Â®,': 45088,
#  'Ġflags': 9701,
#  'Ġopposes': 28928,
#  'Impro': 23028,
#  'Wednesday': 27150,
#  'Hack': 32833,
#  'Ġindispensable': 35669,
#  'Ġunlaw': 16148,
#  'Sullivan': 47572,
#  'ourke': 49003,
#  'Ġtion': 34222,
#  'Ġweighs': 24034,
#  'ĠNegro': 27115,
#  'age': 496,
#  'ji': 7285,
#  'Los': 28903,
#  'eries': 10640,
#  'Ġtrusts': 31976,
#  'controller': 36500,
#  'ĠRepublican': 3415,
#  'plant': 15060,
#  'Ġparted': 37813,
#  'ĠLean': 45661,
#  'Ġsne': 10505,
#  'Ġenvision': 21786,
#  'Ġoutdoor': 15162,
#  'Ġmilitant': 18614,
#  'Ġsensor': 12694,
#  'ĠShap': 29198,
#  'Ġvoyage': 31505,
#  'ĠManaging': 37108,
#  'ĠIntroduction': 22395,
#  'Ġinco': 44237,
#  'Ġsaga': 26784,
#  'e': 68,
#  'apolog': 46407,
#  'Ġperspect': 6009,
#  'Ġdefining': 16215,
#  'Ġlimestone': 48520,
#  'Ġtabs': 22524,
#  'Ġformulations': 49971,
#  'ĠWays': 26658,
#  'MD': 12740,
#  'ĠMuhammad': 15870,
#  'ĠWyoming': 24533,
#  'sav': 39308,
#  'ells': 19187,
#  'Ġego': 19225,
#  'Ġdegrading': 40354,
#  'ĠSIM': 23749,
#  'Ġrobbing': 47162,
#  'washer': 45146,
#  'ĠCookies': 45305,
#  'Ġlighter': 14871,
#  'ĠDevelop': 6013,
#  'Ġbinding': 12765,
#  'full': 12853,
#  'Ġrecap': 26871,
#  '457': 33032,
#  'ĠLic': 10483,
#  'Ġgoddess': 22215,
#  'Ġimped': 26795,
#  'Ġintel': 33649,
#  'Ġfer': 11354,
#  'Ġskirm': 37238,
#  'ĠGib': 12488,
#  'Ġaversion': 41608,
#  'Ġintensive': 18590,
#  'wu': 43812,
#  'Ġscraping': 46743,
#  'ĠIPM': 50200,
#  'ĠTier': 15917,
#  'Ġeasing': 33672,
#  'Ġattending': 11969,
#  'hunter': 37488,
#  'cons': 5936,
#  'Ġpowder': 11913,
#  'Ġaccomplished': 13013,
#  'ĠHerz': 34321,
#  'Ġwatched': 7342,
#  'hett': 17442,
#  'Ġjuice': 13135,
#  'ĠHerman': 25028,
#  'Ġcubic': 27216,
#  'riors': 8657,
#  'luent': 28216,
#  'Ġregistration': 9352,
#  'deg': 13500,
#  'ĠNP': 28498,
#  'Ġclimb': 12080,
#  'ĠLob': 32684,
#  'Ġindependence': 10404,
#  'Ġbladder': 34918,
#  'build': 11249,
#  'Ġhalftime': 35185,
#  'Mount': 35452,
#  'ĠRazor': 36065,
#  'istas': 37503,
#  'ĠRidge': 20614,
#  'Ġplagued': 27909,
#  'Ġhugging': 46292,
#  'ĠWelch': 41524,
#  'Ġstrateg': 5352,
#  'ĠCald': 29182,
#  'AAA': 29697,
#  'ĠMISS': 49684,
#  'current': 14421,
#  'ĠAc': 4013,
#  'Ġwww': 7324,
#  'iners': 21257,
#  'ĠAj': 22028,
#  'Ġsecurity': 2324,
#  'âĪ': 24861,
#  'issan': 24112,
#  'Ġbasil': 37792,
#  'ĠPCs': 21869,
#  'Earn': 49725,
#  'ĠGleaming': 49339,
#  'ĠSoftware': 10442,
#  'Ġunimagin': 37656,
#  'Scotland': 47230,
#  'ĠVictorian': 24569,
#  'Ġbullish': 50079,
#  'ĠIn': 554,
#  'Ġsafeguard': 30925,
#  'Ġlex': 31191,
#  'Ġgenuine': 8768,
#  '148': 18294,
#  'ĠWorse': 36855,
#  'authorized': 19721,
#  'ĠGod': 1793,
#  'Ġarrival': 10325,
#  'opsy': 44522,
#  'ĠTribunal': 31189,
#  'Ġpowdered': 41642,
#  'FA': 7708,
#  '411': 42224,
#  'ĠMARK': 39641,
#  'ĠPieces': 44676,
#  'phrine': 47723,
#  'imp': 11011,
#  'Yan': 49664,
#  '                               ': 50257,
#  'Ġeducation': 3707,
#  'Ġoffering': 6011,
#  'Another': 6610,
#  'Ġtemp': 20218,
#  'ãĥĸ': 24001,
#  'aler': 36213,
#  'Ġnotoriety': 46283,
#  'Ġnegoti': 5578,
#  'âĢ¦."': 50248,
#  'umber': 4494,
#  'Ġdetermine': 5004,
#  'Ġanonym': 14571,
#  'ishy': 49785,
#  'Ġvirtues': 27494,
#  'Ġkit': 6220,
#  'groups': 24432,
#  'ARC': 25793,
#  'Ġdecl': 2377,
#  'ĠCuba': 14159,
#  'Ġspatial': 21739,
#  'inda': 22261,
#  'Ġforeground': 36282,
#  'Ġabdom': 20329,
#  'ĠMSG': 49064,
#  'iculture': 47428,
#  'issue': 21949,
#  'Ġdwell': 14046,
#  'Ġproportions': 23250,
#  'Ġguru': 35730,
#  'ortunate': 13651,
#  'Ġinciner': 48244,
#  'ĠGUN': 43794,
#  'cancer': 48870,
#  'ĠJones': 5437,
#  'Ġsol': 1540,
#  'Ġuploaded': 19144,
#  'Ġskipped': 26684,
#  'sequence': 43167,
#  'Princ': 42904,
#  'ĠFallout': 23886,
#  'Ġsuspected': 9885,
#  'ĠAber': 27700,
#  'Ġdiseng': 39402,
#  'Ġathleticism': 35159,
#  'Button': 21864,
#  'pering': 21255,
#  'Ġcocktails': 34281,
#  'deck': 35875,
#  'Ġtrio': 19886,
#  'Ġvisually': 22632,
#  'ĠHugh': 25464,
#  '513': 48645,
#  '153': 21395,
#  'Ġblues': 25570,
#  'ĠBern': 6206,
#  'Ġdisastrous': 20756,
#  'Notes': 16130,
#  'ĠDesk': 39246,
#  'Ġcalculations': 16765,
#  'ĠHobbit': 43877,
#  'Ġ2002': 6244,
#  'ĠCur': 4424,
#  'Ġbox': 3091,
#  'remlin': 17244,
#  'Ġdecaying': 49240,
#  'ĠHolding': 31703,
#  'lations': 49905,
#  'Ġpeoples': 14366,
#  'ounge': 20891,
#  '515': 45969,
#  'Ġmitochondrial': 32873,
#  'Ġphotographer': 16413,
#  'Ġoptimize': 27183,
#  'aunts': 43981,
#  'roller': 10646,
#  'Ġexcerpt': 20911,
#  'crafted': 39160,
#  'Server': 10697,
#  'Input': 20560,
#  'Ġaunt': 25949,
#  'Ġguiding': 26727,
#  'ĠWC': 28387,
#  'ĠDeutsche': 36763,
#  'ĠRibbon': 44664,
#  'ĠSen': 2311,
#  'Ġranked': 10307,
#  'ĠChen': 12555,
#  'Æ': 130,
#  'Ġinconsistent': 18326,
#  'force': 3174,
#  'Ġextremism': 25571,
#  '!),': 26290,
#  'oru': 27786,
#  'ĠHacker': 34399,
#  'æĦ': 35707,
#  'Ġstink': 48305,
#  'ĠSlightly': 49365,
#  'common': 11321,
#  'itle': 2578,
#  'Ġnumer': 5470,
#  'Ġdying': 9950,
#  'Ġvoluntarily': 22295,
#  'Ġclo': 28050,
#  'Ġtrunc': 40122,
#  'Beat': 34979,
#  'urch': 2575,
#  'Ġtightening': 36040,
#  'ĠMn': 36030,
#  'ĠSaturdays': 41703,
#  'Ġhandic': 29103,
#  'Ġyells': 42675,
#  'ge': 469,
#  'Ġnominated': 19332,
#  'Ġdevoid': 34065,
#  'list': 4868,
#  'Ġenriched': 35601,
#  'Ġwillingly': 30981,
#  'usions': 15880,
#  'Did': 11633,
#  'Ġangles': 18333,
#  'yeah': 43669,
#  'Ġhairy': 43873,
#  'Ġscourge': 50185,
#  'Ġwedding': 10614,
#  'Ut': 18274,
#  'Ġannotation': 23025,
#  'ĠRAND': 46920,
#  'ISS': 16744,
#  'Ġpreseason': 18913,
#  'ĠRohingya': 34016,
#  'ibaba': 37541,
#  'Ġshampoo': 47259,
#  'Ġardu': 50065,
#  'Ġran': 4966,
#  'Ġsty': 8944,
#  'Ġ};': 18083,
#  'ĠFarms': 39045,
#  'ĠAssociate': 22669,
#  'Ġmonop': 15848,
#  'htaking': 34148,
#  'Ġpur': 1308,
#  'filename': 34345,
#  'ned': 2817,
#  'opol': 39704,
#  'Ġphenomen': 7581,
#  'Ġmemory': 4088,
#  'ĠJenn': 9777,
#  'Ġwidened': 36405,
#  'ĠCities': 20830,
#  'tesque': 37422,
#  'ĠHeat': 12308,
#  'Ġultrasound': 37721,
#  'avery': 12447,
#  'ĠMoff': 41069,
#  'Learning': 41730,
#  'posing': 32927,
#  'ĠCharisma': 44859,
#  'Ġaccommodation': 19711,
#  'ĠTay': 25569,
#  'arty': 25494,
#  'ĠGems': 30196,
#  'Ġtease': 34691,
#  'Ġpay': 1414,
#  'Ġbacking': 12285,
#  'Ġpray': 12472,
#  'ĠSwedish': 14023,
#  'Ġdocs': 34165,
#  'Ġgrants': 11455,
#  'them': 18855,
#  'ĠHawks': 23445,
#  'UME': 38340,
#  'ĠGram': 20159,
#  'Ġfranchises': 28088,
#  'witch': 42248,
#  'Pakistan': 38485,
#  'Spons': 43522,
#  'aba': 15498,
#  'imer': 22723,
#  'zig': 38262,
#  'ĠBh': 16581,
#  'ĠChung': 43915,
#  ']}': 48999,
#  'ĠGAM': 49965,
#  'ĠJesuit': 50190,
#  'ĠIro': 47927,
#  'Ġcubes': 34896,
#  'Ġloop': 9052,
#  'Ġreim': 21123,
#  'node': 17440,
#  'Ren': 26764,
#  'Ġarchitectural': 27070,
#  'Ġcarcin': 28164,
#  'Ġpatriotism': 36994,
#  'Ġadversely': 34079,
#  'Ġcasing': 39731,
#  'BI': 3483,
#  'aniel': 6321,
#  'ORS': 20673,
#  'Ġmarrow': 44173,
#  'Ġschema': 32815,
#  'rypt': 6012,
#  'Ġdf': 47764,
#  'alions': 50022,
#  'Ġears': 11368,
#  'Ġmethod': 2446,
#  'estyle': 10992,
#  'Ġnor': 4249,
#  'ĠTW': 17306,
#  'Ġharmless': 23585,
#  'ascar': 37740,
#  'Ġreservoirs': 46637,
#  'Ġ138': 21503,
#  'Ġattempts': 6370,
#  'ĠFat': 12301,
#  'thens': 43895,
#  'opausal': 47637,
#  'Ġbrown': 7586,
#  'Ġplayoff': 13119,
#  'ĠLeon': 10592,
#  'ongo': 25162,
#  'Ġpoorer': 26647,
#  'Ġflashes': 29227,
#  'downs': 30371,
#  'Ġlistens': 35019,
#  'ĠEverybody': 23080,
#  'ktop': 16201,
#  'ĠTurk': 8484,
#  'Please': 5492,
#  'Ġnerve': 16384,
#  'ĠProm': 10335,
#  'closure': 17966,
#  'Ġpoker': 27101,
#  'Ġdanced': 39480,
#  'ĠTinker': 46316,
#  'Ġpoaching': 49879,
#  'LAB': 48780,
#  'ĠRowling': 41558,
#  'Ġcloaked': 45853,
#  'Ġdescendant': 45923,
#  'ĠBates': 35591,
#  'respond': 5546,
#  'Ġoverfl': 32876,
#  'Update': 10260,
#  'Answer': 33706,
#  'ĠKE': 47134,
#  'High': 11922,
#  'ĠSketch': 17001,
#  'WIND': 28929,
#  'Wik': 33010,
#  'Ġadjective': 43441,
#  'Ġhair': 4190,
#  'item': 9186,
#  'Ġinsomnia': 47104,
#  'GV': 37094,
#  'Ġbuyer': 17872,
#  'ĠNiagara': 44340,
#  'Ġliter': 4187,
#  'ĠCA': 7257,
#  'Ġflat': 6228,
#  'ĠNab': 36099,
#  'ĠFrieza': 48080,
#  'Ġexecuted': 10945,
#  'CON': 10943,
#  'Ġstriker': 19099,
#  'Ġcite': 21729,
#  'Ġpartial': 13027,
#  'ĠMidnight': 27960,
#  'Utah': 44350,
#  'Ġtownship': 42823,
#  'Ġ[&': 49082,
#  'ocked': 3543,
#  'ĠLook': 6803,
#  'ĠLyft': 38928,
#  'ĠBraz': 41414,
#  'outside': 43435,
#  'Ġships': 7937,
#  'ĠSc': 1446,
#  'Ġcmd': 23991,
#  'Ġherein': 24028,
#  'ĠGuardians': 19752,
#  'Ġsclerosis': 46225,
#  'Ġmisunder': 16782,
#  'gam': 28483,
#  'message': 20500,
#  'Jon': 18219,
#  'ĠSpells': 30656,
#  'Runner': 49493,
#  'Ġuser': 2836,
#  'ĠTide': 31105,
#  'Ġformatted': 39559,
#  'Ġbuzzing': 41719,
#  'ONDON': 47383,
#  'Thursday': 25381,
#  'Ġfoss': 10967,
#  'Ġfled': 11468,
#  'Ġprevent': 2948,
#  'Ġwhereby': 23482,
#  'ĠArchangel': 28811,
#  '575': 36189,
#  'chwitz': 36297,
#  'ela': 10304,
#  'ĠNaples': 49404,
#  'ĠIdle': 37130,
#  'ĠEnh': 15860,
#  'Ġbru': 18145,
#  'Ġencouraging': 12577,
#  'Ġduplication': 50124,
#  'sit': 48937,
#  'ĠUnt': 26970,
#  'Ġfuckin': 46733,
#  'ĠMeow': 42114,
#  'ĠMeeting': 22244,
#  'ĠDEF': 23449,
#  'oenix': 8538,
#  'Ġtranslation': 11059,
#  'ĠKeeper': 26335,
#  'Ġtopical': 39867,
#  'Ġexisted': 11196,
#  'ĠSweep': 42818,
#  'icist': 48187,
#  'ventional': 20405,
#  'Ġclause': 13444,
#  'Ġprogressed': 28775,
#  'Ġhighlights': 11330,
#  'Ġcrafts': 28229,
#  'Ġlearning': 4673,
#  'Americans': 17636,
#  'ĠKra': 21553,
#  'Ġfloor': 4314,
#  'Ġunequal': 37334,
#  'Christopher': 38025,
#  'Ġtheory': 4583,
#  'Ġpeas': 22589,
#  'Ġcrises': 25712,
#  'Ġbothering': 41656,
#  'enc': 12685,
#  'ronics': 20844,
#  'Ġglamorous': 46185,
#  'Äĵ': 27092,
#  'Ġsuffice': 34302,
#  'Ġunwitting': 38420,
#  'Îº': 43000,
#  'Ġdeems': 44426,
#  'hours': 24425,
#  'Ġtempered': 45735,
#  'oyer': 35301,
#  'ĠLena': 44131,
#  'Ġeyebrow': 38220,
#  'soon': 36194,
#  'Ġmischief': 38625,
#  'ĠGrammy': 42235,
#  '378': 30695,
#  '{\\': 31478,
#  'Ñĥ': 35072,
#  'Ġcond': 1779,
#  'Ġeviction': 38738,
#  'Ġresists': 47786,
#  'Ġtyres': 40498,
#  'Ġconvincing': 17101,
#  'cience': 4234,
#  'Ġrepayment': 36411,
#  'Ġfs': 43458,
#  'Ġpeak': 9103,
#  'ĠMt': 18632,
#  'ADRA': 40517,
#  'Ġrehab': 14321,
#  'Ġain': 18959,
#  'Ġmeet': 1826,
#  '712': 49517,
#  'Ġflawed': 19556,
#  'Ġserving': 7351,
#  'IGHT': 9947,
#  'Ġrealistic': 12653,
#  'Ġspokesman': 6523,
#  'struct': 7249,
#  'Ġnegotiated': 22368,
#  'Ġwre': 30154,
#  'EE': 6500,
#  '*****': 35625,
#  'Ġslid': 27803,
#  'Books': 30650,
#  'Ġdizz': 29527,
#  'Ġlawful': 20785,
#  'Ġminimum': 5288,
#  'Ġsports': 5701,
#  'Ġnonsense': 18149,
#  'ĠRaider': 31423,
#  'Ġabsurd': 12986,
#  'Non': 15419,
#  'Ġappropriated': 32316,
#  'wood': 3822,
#  'fet': 34045,
#  'Ġagendas': 37611,
#  'apply': 39014,
#  'Kelly': 34831,
#  'Ġdelinquent': 46026,
#  'Ġwig': 45678,
#  'oÄŁan': 48030,
#  'Ġ."': 22135,
#  'Research': 25104,
#  'ĠTuc': 33370,
#  'prising': 14619,
#  'Ġfossils': 34066,
#  'ĠFeeling': 39635,
#  'Obs': 31310,
#  'Ġconfir': 4322,
#  'watch': 8340,
#  'Ġunst': 15014,
#  'Ġsitu': 34074,
#  'Ġ410': 32921,
#  'cloud': 17721,
#  'oresc': 45166,
#  'Ġbloated': 45709,
#  'ĠLadies': 37401,
#  'orth': 1506,
#  'ander': 4066,
#  'ĠOften': 18023,
#  'ilation': 10520,
#  'Ġfru': 12658,
#  'Ġsnapping': 35733,
#  'âĢ¢âĢ¢âĢ¢âĢ¢': 39967,
#  'Ġopened': 4721,
#  'ĠEducation': 7868,
#  'ĠBelg': 10952,
#  'Ġ----': 13498,
#  'occ': 13966,
#  'loc': 17946,
#  'ĠDodge': 26048,
#  'Ġoperated': 12228,
#  'Ġdisappearing': 28867,
#  'getting': 37210,
#  'ĠBeet': 39040,
#  'Ġrover': 35761,
#  'Ġplat': 40315,
#  'Ġinterruption': 41728,
#  'Ġloading': 11046,
#  'Ġevolution': 6954,
#  'Ġmanifest': 10561,
#  'north': 43588,
#  'Ġexotic': 21036,
#  '////////////////': 27246,
#  'Ġmobilization': 46762,
#  'perature': 21069,
#  'Ġstaffers': 23033,
#  'ĠCombined': 32028,
#  'robat': 40655,
#  'Ġacquaintances': 45317,
#  'Ġtreacherous': 45365,
#  'ĠPeck': 48434,
#  'Ġrival': 8976,
#  'ĠWebsite': 15887,
#  'Ġdevices': 4410,
#  'Ġdownloaded': 15680,
#  'Ġjuvenile': 21904,
#  '390': 25964,
#  'Ġcrowdfunding': 33851,
#  'igans': 34090,
#  '588': 39118,
#  'ĠTransmission': 41653,
#  'untarily': 49605,
#  'repair': 49932,
#  'ĠOctober': 3267,
#  'Ġdemands': 8665,
#  'Ġheap': 24575,
#  'She': 3347,
#  'Ġbikini': 45810,
#  'ĠClosed': 30550,
#  'ĠAcqu': 24939,
#  'Ġrecalled': 12433,
#  'Ġappell': 24781,
#  'Ġwillful': 47860,
#  'Ġoffensive': 5859,
#  'NVIDIA': 38021,
#  'und': 917,
#  'Ġhostilities': 39082,
#  'Ġsuffers': 21046,
#  'ĠAngel': 3905,
#  '668': 35809,
#  'ĠFedora': 32245,
#  'cpu': 36166,
#  'Ġfeaturing': 9593,
#  'parse': 29572,
#  'ĠBust': 36988,
#  'istent': 7609,
#  'las': 21921,
#  'Ġsimulated': 28590,
#  'ĠResponsibility': 42988,
#  'Ġinsulin': 14588,
#  'ĠGarland': 35466,
#  'ĠCustoms': 23888,
#  'ĠStarter': 37460,
#  'iola': 30292,
#  'Ġrecipes': 14296,
#  'Ġcompare': 8996,
#  'Ġrecovering': 20222,
#  'ĠDoctor': 9356,
#  'Result': 23004,
#  'Ġtoast': 27805,
#  'discrimination': 42723,
#  'Victoria': 49898,
#  'Winged': 47418,
#  'ĠArtist': 18902,
#  'criptions': 24370,
#  'ĠGavin': 30857,
#  'riv': 15104,
#  'Ġtraces': 20675,
#  'Ġdynasty': 30968,
#  'ĠIncident': 32731,
#  'ĠInvestment': 20877,
#  'ĠTerms': 17637,
#  'Ġiv': 21628,
#  'Ġdawn': 17577,
#  'Like': 7594,
#  'Ġdetrimental': 29417,
#  'ocl': 38679,
#  'Ġliability': 12247,
#  'ĠMagnet': 32079,
#  'Ġsustain': 8080,
#  '303': 22572,
#  'Ġmarker': 18364,
#  'ĠTaxes': 42260,
#  'Ġintricate': 28746,
#  'Ġupbringing': 40678,
#  'ĠAmes': 46843,
#  'ĠStrength': 14646,
#  'Ġmagnesium': 33525,
#  'Ġgroups': 2628,
#  'ĠImperial': 11773,
#  'Ġpreparation': 11824,
#  'atible': 16873,
#  'Ġangrily': 34425,
#  'ĠCLASS': 42715,
#  'Ġdeft': 46208,
#  'Ġabortions': 19985,
#  'Elf': 46995,
#  'aj': 1228,
#  'ĠDri': 5809,
#  'Ġconfisc': 22735,
#  'led': 992,
#  'Ġadult': 4044,
#  'Ġoffend': 35117,
#  'ĠCommodore': 48808,
#  'Ġmonth': 1227,
#  'Ġboo': 22513,
#  'ĠThieves': 40392,
#  'Ġodor': 28192,
#  'Section': 16375,
#  'Ġdise': 3591,
#  'uph': 25689,
#  'agonal': 27923,
#  'Ġoutbreak': 17645,
#  'ĠFran': 12323,
#  'alty': 6017,
#  'Ġbits': 10340,
#  'ĠRay': 7760,
#  'liberal': 35739,
#  'ĠCRC': 45623,
#  'ĠStudents': 14882,
#  'ĠContinue': 10054,
#  'Invest': 19070,
#  'Ġtid': 29770,
#  'ĠUCLA': 21750,
#  'ĠShelby': 35053,
#  'Ġswallowing': 45590,
#  'Ġengagement': 12352,
#  'Ġoutraged': 27697,
#  'Ġexplanation': 7468,
#  'Ġdriveway': 33515,
#  'Ġmoney': 1637,
#  'fx': 21373,
#  'Ġtsp': 23053,
#  'Ġsettle': 12259,
#  'Ġcosts': 3484,
#  'Ġproof': 6617,
#  'Ġunequivocally': 47001,
#  'ĠWebs': 47736,
#  ...}

# %% [markdown]
# ## Logit Uploading and Flattening

# %%
#| hide
#| eval: false
first_token_distribution.topk(k=1, largest =True) #Returns the most probable token for that position
# Out:
# torch.return_types.topk(
# values=tensor([0.1579]),
# indices=tensor([1332]))

# %%
#| export

def topk_tuple( logit_vocab_tensor, largest, tokenizer_fn):
    "Run topk for a token"
    #token_position_dict = list( tokenizer.get_vocab().keys() )
    topk = logit_vocab_tensor.topk( k=1 , largest=largest ) #TODO K number of elements can be extended
    #print(topk.indices)
    return ( tokenizer_fn.decode(topk.indices), topk.values.item() )

def min_max_logits( logit_vocab_sample_tensor, tokenizer_fn ):
    "Compute min_max for a sample"
    max_cases = []
    min_cases = []
    for logit_vocab_tensor in logit_vocab_sample_tensor:
        max_cases.append( topk_tuple( logit_vocab_tensor = logit_vocab_tensor, largest = True, tokenizer_fn = tokenizer_fn) ) #TST Max Logit
        min_cases.append( topk_tuple( logit_vocab_tensor = logit_vocab_tensor, largest = False, tokenizer_fn = tokenizer_fn) ) #TST Min Logit
    return max_cases, min_cases

def actual_logit( 
                 logit_vocab_sample_tensor, 
                 tokenized_prompt, 
                 tokenizer_fn,
                 ):
    "Compute actual logits for a sample"
    actual_logits_prompt = []
    for token_pos, id_token in enumerate( tokenized_prompt[1:] ): #Eliminate the first token prediction since we do not use it
        actual_logits_prompt.append(
            (   tokenizer_fn.decode( int(id_token) ), #retrieving the name of the token with the id
                logit_vocab_sample_tensor[token_pos][int(id_token)].item()      ) #retrieving the logit given the position in the sequence and the position in the vocab
            )
    return actual_logits_prompt

# %%
#| hide
#| eval: false
max_case,min_case = min_max_logits(
    logit_vocab_sample_tensor = [ soft( torch.from_numpy(token) ) for token in out[:4]],
    tokenizer_fn= tokenizer
    ) #Sentence Level minmax (reduced to 3 tokens)
print(max_case)
print(min_case)
# Out:
# [(' test', 0.15791159868240356), ('_', 0.410830557346344), ('test', 0.05332261323928833), ('_', 0.609906017780304)]
# [('ヘラ', 4.97558140521992e-11), ('��', 7.214983938281833e-22), (' DevOnline', 2.6005836363079656e-15), ('��', 2.25670669779587e-23)]

# %%
#| hide
#| eval: false
sample_id
# Out:
# 0

# %%
#| hide
#| eval: false
actual_cases = actual_logit(
    logit_vocab_sample_tensor = [ soft( torch.from_numpy(token) ) for token in out] , #Out is a complete sequence
    tokenized_prompt = tf_input_ids[ sample_id ],
    tokenizer_fn = tokenizer
    )

# %%
#| hide
#| eval: false
actual_cases
# Out:
# [(' run', 0.012154975906014442),
#  ('_', 0.410830557346344),
#  ('python', 0.0014204250182956457),
#  ('_', 0.609906017780304),
#  ('tests', 0.06661944091320038),
#  ('(', 0.7821821570396423),
#  ('test', 0.05372804030776024),
#  ('_', 0.6518159508705139),
#  ('modules', 0.00809108093380928),
#  (',', 0.5366635918617249),
#  (' parallel', 0.008699917234480381),
#  ('ism', 0.023772072046995163),
#  (',', 0.3085222840309143),
#  (' with', 0.0006042752647772431),
#  ('_', 0.9571990370750427),
#  ('co', 0.17824891209602356),
#  ('verage', 0.9994751811027527),
#  ('=', 0.20326749980449677),
#  ('False', 0.8346660137176514),
#  ('):', 0.6203358173370361),
#  ('\n', 0.9075515866279602),
#  ('    ', 0.9226301908493042),
#  ('set', 0.00017469270096626133),
#  ('_', 0.901804506778717),
#  ('title', 0.0003461785090621561),
#  ('_', 0.1248159408569336),
#  ('and', 0.3271429240703583),
#  ('_', 0.9998694658279419),
#  ('block', 5.6533168390160426e-05),
#  ('("', 0.1712595373392105),
#  ('Running', 0.7192416191101074),
#  (' Py', 0.02002798579633236),
#  ('Sp', 0.017194559797644615),
#  ('ark', 0.9875836968421936),
#  (' tests', 0.5716789960861206),
#  ('",', 0.06420852243900299),
#  (' "', 0.3755214512348175),
#  ('BL', 0.0018841450801119208),
#  ('OCK', 0.40665072202682495),
#  ('_', 0.27155837416648865),
#  ('P', 0.006074616685509682),
#  ('Y', 0.5325988531112671),
#  ('SP', 0.4186383783817291),
#  ('ARK', 0.9988372921943665),
#  ('_', 0.4234749972820282),
#  ('UN', 0.004412772133946419),
#  ('IT', 0.6010870337486267),
#  ('_', 0.7120538353919983),
#  ('T', 0.9638797640800476),
#  ('ES', 0.41946572065353394),
#  ('TS', 0.9989637136459351),
#  ('")', 0.854527473449707),
#  ('\n\n', 0.32751572132110596),
#  ('    ', 0.9976453185081482),
#  ('if', 0.20631179213523865),
#  (' with', 0.5567722916603088),
#  ('_', 0.9999775886535645),
#  ('co', 0.9993358254432678),
#  ('verage', 1.0),
#  (':', 0.9313502311706543),
#  ('\n', 0.9900240302085876),
#  ('        ', 0.9396889805793762),
#  ('#', 0.16480496525764465),
#  (' Coverage', 0.033816657960414886),
#  (' makes', 0.0020433603785932064),
#  (' the', 0.02393646538257599),
#  (' Py', 0.0008442807011306286),
#  ('Sp', 0.9376157522201538),
#  ('ark', 0.9999797344207764),
#  (' tests', 0.5182045102119446),
#  (' fl', 0.020419979467988014),
#  ('aky', 0.7889365553855896),
#  (' due', 0.0046976529993116856),
#  (' to', 0.9948140382766724),
#  (' heavy', 0.0006855822866782546),
#  (' parallel', 0.023363668471574783),
#  ('ism', 0.9179014563560486),
#  ('.', 0.5860520005226135),
#  ('\n', 0.5976241827011108),
#  ('        ', 0.9996104836463928),
#  ('#', 0.6145738363265991),
#  (' When', 0.0024158607702702284),
#  (' we', 0.03482063487172127),
#  (' run', 0.47437986731529236),
#  (' Py', 0.042132534086704254),
#  ('Sp', 0.9898202419281006),
#  ('ark', 0.9999700784683228),
#  (' tests', 0.4664868414402008),
#  (' with', 0.3518993854522705),
#  (' coverage', 0.8008250594139099),
#  (',', 0.8066103458404541),
#  (' it', 0.03763744980096817),
#  (' uses', 0.010837441310286522),
#  (' 4', 0.011001262813806534),
#  (' for', 0.0002774284512270242),
#  (' now', 0.0003982607740908861),
#  (' as', 0.006422845646739006),
#  ('\n', 0.060820117592811584),
#  ('        ', 0.9998550415039062),
#  ('#', 0.9987983703613281),
#  (' workaround', 0.0027105712797492743),
#  ('.', 0.4305095076560974),
#  ('\n', 0.5714341402053833),
#  ('        ', 0.9998487234115601),
#  ('par', 0.26654648780822754),
#  ('allel', 0.9997089505195618),
#  ('ism', 0.9992953538894653),
#  (' =', 0.9768186807632446),
#  (' 4', 0.6052932739257812),
#  ('\n', 0.2868134677410126),
#  ('        ', 0.4504205286502838),
#  ('script', 0.00010209866741206497),
#  (' =', 0.3333069980144501),
#  (' "', 0.4645431637763977),
#  ('run', 0.14429593086242676),
#  ('-', 0.268466979265213),
#  ('tests', 0.5181867480278015),
#  ('-', 0.1579265296459198),
#  ('with', 0.45603883266448975),
#  ('-', 0.9959533214569092),
#  ('co', 0.9595904350280762),
#  ('verage', 0.9990662932395935),
#  ('"', 0.11244233697652817),
#  ('\n', 0.8871405720710754),
#  ('    ', 0.590243935585022),
#  ('else', 0.9773226976394653),
#  (':', 0.9998352527618408),
#  ('\n', 0.9992645382881165),
#  ('        ', 0.9996192455291748),
#  ('script', 0.9714469909667969),
#  (' =', 0.9991825222969055),
#  (' "', 0.9909460544586182),
#  ('run', 0.9224036335945129),
#  ('-', 0.9902861714363098),
#  ('tests', 0.8412129878997803),
#  ('"', 0.7347617149353027),
#  ('\n', 0.25727275013923645),
#  ('    ', 0.9355828762054443),
#  ('command', 0.05221595615148544),
#  (' =', 0.9277175664901733),
#  (' [', 0.18093013763427734),
#  ('os', 0.03355985879898071),
#  ('.', 0.9995858073234558),
#  ('path', 0.951594889163971),
#  ('.', 0.9999853372573853),
#  ('join', 0.951219379901886),
#  ('(', 0.9050180912017822),
#  ('SP', 0.5149253010749817),
#  ('ARK', 0.9945376515388489),
#  ('_', 0.9987622499465942),
#  ('HOME', 0.9236522912979126),
#  (',', 0.9938594698905945),
#  (' "', 0.8592039942741394),
#  ('python', 0.4680761396884918),
#  ('",', 0.3389425575733185),
#  (' script', 0.25357329845428467),
#  (')]', 0.3868650197982788),
#  ('\n', 0.8844740986824036),
#  ('    ', 0.9997252821922302),
#  ('if', 0.3389066159725189),
#  (' test', 0.3440922200679779),
#  ('_', 0.9974974989891052),
#  ('modules', 0.4807172417640686),
#  ('!=', 0.001781704369932413),
#  (' [', 0.011951136402785778),
#  ('modules', 2.4125304207700538e-06),
#  ('.', 0.6168030500411987),
#  ('root', 0.0039037142414599657),
#  (']:', 0.12880004942417145),
#  ('\n', 0.9953912496566772),
#  ('        ', 0.9996658563613892),
#  ('command', 0.8468525409698486),
#  ('.', 0.29801440238952637),
#  ('append', 0.43673402070999146),
#  ('("', 0.8544721007347107),
#  ('--', 0.8392220139503479),
#  ('modules', 0.15069273114204407),
#  ('=', 0.23095889389514923),
#  ('%', 0.9938814640045166),
#  ('s', 0.9987726807594299),
#  ('"', 0.9848906397819519),
#  (' %', 0.9985275268554688),
#  (" '", 0.03180563077330589),
#  (",'", 0.991769552230835),
#  ('.', 0.9999946355819702),
#  ('join', 0.9999850988388062),
#  ('(', 0.9962971806526184),
#  ('m', 8.908088784664869e-05),
#  ('.', 0.6066561341285706),
#  ('name', 0.32773181796073914),
#  (' for', 0.964455246925354),
#  (' m', 0.9994319081306458),
#  (' in', 0.9988783001899719),
#  (' test', 0.995806097984314),
#  ('_', 0.9999569654464722),
#  ('modules', 0.9998925924301147),
#  ('))', 0.9833889603614807),
#  ('\n', 0.7927408218383789),
#  ('    ', 0.9592067003250122),
#  ('command', 0.5946348309516907),
#  ('.', 0.9916211366653442),
#  ('append', 0.1496095210313797),
#  ('("', 0.9629164934158325),
#  ('--', 0.9295786619186401),
#  ('par', 0.008465561084449291),
#  ('allel', 0.9997345805168152),
#  ('ism', 0.9981468915939331),
#  ('=', 0.9939568042755127),
#  ('%', 0.997634768486023),
#  ('i', 0.0038517778739333153),
#  ('"', 0.9981120824813843),
#  (' %', 0.9998906850814819),
#  (' parallel', 0.993407130241394),
#  ('ism', 0.9999830722808838),
#  (')', 0.9988492727279663),
#  ('\n', 0.7230940461158752),
#  ('    ', 0.9986100196838379),
#  ('run', 0.009415927343070507),
#  ('_', 0.9677429795265198),
#  ('cmd', 0.040061626583337784),
#  ('(', 0.591596245765686),
#  ('command', 0.9308438897132874),
#  (')', 0.608421802520752),
#  ('\n\n', 0.7464021444320679)]

# %% [markdown]
# # Logits Execution

# %%
#| hide
#| eval: false
len(filtered_prompts_ids)
#params['numpy_files_logits_path'] +'/' + f'logits_tensor[{sample_id}]_batch[{sample_id}]_model[{CODEMODEL}].npy'
# Out:
# 50971

# %%
#| export

def batching_logits( size ):

    max_logit_token_prompt = []
    min_logit_token_prompt = []
    actual_logit_token_prompt = []
    
    soft = torch.nn.Softmax( dim = 0 )                          #Flattening normalization
    
    for file in range( size ):
        out = np.load(params['numpy_files_logits_path']+'/'+ f'logits_tensor[{file}]_batch[{file}]_model[{CODEMODEL}].npy')
        next_tokens_distribution = [ soft( torch.from_numpy(token) ) for token in out]  #Flattening normalization
        
        max_cases,min_cases = min_max_logits(
            logit_vocab_sample_tensor = next_tokens_distribution,
            tokenizer_fn= tokenizer
            )

        actual_cases = actual_logit(
            logit_vocab_sample_tensor = next_tokens_distribution,
            #sample_position = file,
            tokenized_prompt = tf_input_ids[ file ],
            tokenizer_fn = tokenizer
            )
        
        max_logit_token_prompt.append( max_cases )
        min_logit_token_prompt.append( min_cases )
        actual_logit_token_prompt.append( actual_cases )
        
        logging.info(file)
    return max_logit_token_prompt,min_logit_token_prompt,actual_logit_token_prompt

# %%
#| hide
#| eval: false
#max_logit_token_prompt,min_logit_token_prompt,actual_logit_token_prompt = batching_logits( size = 2 )
max_logit_token_prompt, min_logit_token_prompt, actual_logit_token_prompt = batching_logits(
    size = len(filtered_prompts_ids)
    ) #<---WARNING TIME Consuming

# %%
#| hide
#| eval: false
dataframe_to_save = data_pd[data_pd['m_name']==params['codemodel']].copy()

# %%
#| hide
#| eval: false
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 815536   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c17  \
#
#                                                      code ast_errors
# 815536  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 815536             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 815536           120          154

# %%
#| hide
#| eval: false
dataframe_to_save['max_prob'] = max_logit_token_prompt
dataframe_to_save['min_prob'] = min_logit_token_prompt
dataframe_to_save['actual_prob'] = actual_logit_token_prompt

# %%
#| hide
#| eval: false
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 815536   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c17  \
#
#                                                      code ast_errors
# 815536  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 815536             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 815536           120          154  \
#
#                                                  max_prob
# 815536  [( test, 0.15791159868240356), (_, 0.410830557...  \
#
#                                                  min_prob
# 815536  [(ヘラ, 4.97558140521992e-11), (��, 7.2149839382...  \
#
#                                               actual_prob
# 815536  [( run, 0.012154975906014442), (_, 0.410830557...

# %%
#| hide
#| eval: false
dataframe_to_save.shape
# Out:
# (50971, 15)

# %%
#| hide
#| eval: false
params['outputs']
# Out:
# '../data/ds_raw_logits/out_astevalverticalfiltered_c17.csv'

# %%
#| hide
#| eval: false
## Saving CheckPoint
dataframe_to_save.to_csv( params['outputs']  )

# %%
#| hide
#| eval: false
dataframe_to_save = pd.read_csv( 
                      params['outputs'] , 
                      index_col=0
            )

# %%
#| hide
#| eval: false
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 815536   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c17  \
#
#                                                      code ast_errors
# 815536  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 815536             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 815536           120          154  \
#
#                                                  max_prob
# 815536  [(' test', 0.15791159868240356), ('_', 0.41083...  \
#
#                                                  min_prob
# 815536  [('ヘラ', 4.97558140521992e-11), ('��', 7.214983...  \
#
#                                               actual_prob
# 815536  [(' run', 0.012154975906014442), ('_', 0.41083...

# %%
#| hide
#| eval: false
dataframe_to_save.shape
# Out:
# (50971, 15)

# %% [markdown]
# ## Loss Retrieval

# %%
#| export

def batching_loss( size ):
    output_loss = []
    for current_batch in range(size):
        out = np.load(params['numpy_files_logits_path']+'/'+f'loss_batch[{current_batch}]_model[{CODEMODEL}].npy') 
        output_loss.append( out.item() ) #.item() for numpy library
        logging.info(current_batch)
    return output_loss

# %%
#| hide
#| eval: false
output_loss = batching_loss(size = dataframe_to_save.shape[0] ) #[WAENING!] Takes Time

# %%
#| hide
#| eval: false
dataframe_to_save['loss'] = output_loss
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 815536   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c17  \
#
#                                                      code ast_errors
# 815536  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 815536             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 815536           120          154  \
#
#                                                  max_prob
# 815536  [(' test', 0.15791159868240356), ('_', 0.41083...  \
#
#                                                  min_prob
# 815536  [('ヘラ', 4.97558140521992e-11), ('��', 7.214983...  \
#
#                                               actual_prob      loss
# 815536  [(' run', 0.012154975906014442), ('_', 0.41083...  1.509103

# %%
#| hide
#| eval: false
## Saving CheckPoint 2
dataframe_to_save.to_csv( params['outputs']  )

# %%
#| hide
#| eval: false
dataframe_to_save = pd.read_csv( 
                      params['outputs'] , 
                      index_col=0
            )

# %%
#| hide
#| eval: false
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 815536   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c17  \
#
#                                                      code ast_errors
# 815536  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 815536             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 815536           120          154  \
#
#                                                  max_prob
# 815536  [(' test', 0.15791159868240356), ('_', 0.41083...  \
#
#                                                  min_prob
# 815536  [('ヘラ', 4.97558140521992e-11), ('��', 7.214983...  \
#
#                                               actual_prob      loss
# 815536  [(' run', 0.012154975906014442), ('_', 0.41083...  1.509103

# %% [markdown]
# # Bootstrapping Analysis

# %% [markdown]
# ## Combining all datasets

# %%
#| export

models = ['c1','c2','c3','c5','c6','c9','c10','c11','c14','c15','c16','c17']

# %%
#| export

new_columns = {
    'c1':('gpt-3','125M'),
    'c2':('gpt-3','1.3B'),
    'c3':('gpt-3','2.7B'),
    'c5':('codegen-nl','350M'),
    'c6':('codegen-nl','2B'),
    'c9':('multi-lang','110M'),
    'c10':('multi-lang','350M'),
    'c11':('multi-lang','2B'),
    'c14':('mono-lang','110M'),
    'c15':('mono-lang','1.5B'),
    'c16':('mono-lang','350M'),
    'c17':('mono-lang','2B')
}

# %%
#| hide
#| eval: false
pd_combined_models = pd.read_csv( '/workspaces/CodeSyntaxConcept/data/ds_processed_logits_global/out_astevalverticalfiltered_c1.csv'  , index_col=0)

# %%
#| hide
#| eval: false
pd_combined_models.shape
# Out:
# (174, 6)

# %%
#| hide
#| eval: false
new_columns['c1']
# Out:
# ('gpt-3', '125M')

# %%
#| hide
#| eval: false
pd_combined_models['id'] = new_columns['c1'][0] + " [" + new_columns['c1'][1] + "]"
pd_combined_models['type_model'] = new_columns['c1'][0]
pd_combined_models['size_model'] = new_columns['c1'][1]

# %%
#| hide
#| eval: false
pd_combined_models.head(1)
# Out:
#    ast_element node_type                                concept_median_prob  \
# 0  with_clause    parent  [0.3349215416126299, 0.48713837044152364, 0.98...
#
#                                     concept_min_prob  \
# 0  [0.11321202570206879, 0.2244944909784513, 0.96...
#
#                                     concept_max_prob                    model  \
# 0  [0.6549162715673447, 0.6862596067098471, 0.996...  EleutherAI/gpt-neo-125m
#
#              id type_model size_model
# 0  gpt-3 [125M]      gpt-3       125M

# %%
#| hide
#| eval: false
for m in models[1:]:
    pd_temp = pd_combined_models.copy()
    pd_combined_models = pd.read_csv( f'/workspaces/CodeSyntaxConcept/data/ds_processed_logits_global/out_astevalverticalfiltered_{m}.csv'  , index_col=0)
    
    pd_combined_models['id'] = new_columns[m][0] + " [" + new_columns[m][1] + "]"
    pd_combined_models['type_model'] = new_columns[m][0]
    pd_combined_models['size_model'] = new_columns[m][1]
    
    pd_combined_models = pd.concat( [pd_temp,pd_combined_models], ignore_index=True ) #vertical concatenation
    print(f"completed-{m}")
# Out:
# completed-c2
# completed-c3
# completed-c5
# completed-c6
# completed-c9
# completed-c10
# completed-c11
# completed-c14
# completed-c15
# completed-c16
# completed-c17

# %%
#| hide
#| eval: false
set(pd_combined_models.model.values)
# Out:
# {'EleutherAI/gpt-neo-1.3B',
#  'EleutherAI/gpt-neo-125m',
#  'EleutherAI/gpt-neo-2.7B',
#  'Salesforce/codegen-2B-mono',
#  'Salesforce/codegen-2B-multi',
#  'Salesforce/codegen-2B-nl',
#  'Salesforce/codegen-350M-mono',
#  'Salesforce/codegen-350M-multi',
#  'Salesforce/codegen-350M-nl',
#  'codeparrot/codeparrot',
#  'codeparrot/codeparrot-small',
#  'codeparrot/codeparrot-small-multi'}

# %%
#| hide
#| eval: false
pd_combined_models.to_csv('/workspaces/CodeSyntaxConcept/data/ds_processed_logits_global/out_astevalverticalfiltered_global.csv')

# %%
#| hide
#| eval: false
pd_combined_models = pd.read_csv( '/workspaces/CodeSyntaxConcept/data/ds_processed_logits_global/out_astevalverticalfiltered_global.csv'  , index_col=0)

# %%
#| hide
#| eval: false
pd_combined_models.shape
# Out:
# (2088, 9)

# %% [markdown]
# ## Median Bootstrapping

# %%
#| hide
#| eval: false
filtered_concepts_local = [
    'for_statement', #Iterative
    'while_statement', #Iterative
    'return_statement', #Ending
    ']', #Ending
    ')', #Ending
    'if_statement', #Decision
    'comparison_operator', #Boolean
    'boolean_operator', #Boolean
    'for_in_clause', #Funct
    'if_clause', #Funct
    'list_comprehension', #Funct
    'lambda',#Funct
    'identifier', #NL
    'string', #NL
]

# %%
#| hide
#| eval: false
filtered_concepts_global = [
    'for_statement', #Iterative
    'while_statement', #Iterative
    'return_statement', #Ending
    ']', #Ending
    ')', #Ending
    '}', #Ending
    ':', #Ending
    'if_statement', #Decision
    'elif',  #Decision
    'else',  #Decision
    'comparison_operator', #Operator
    'boolean_operator', #Operator
    'binary_operator', #Operator
    'unary_operator', #Operator
    'for_in_clause', #Funct
    'if_clause', #Funct
    'list_comprehension', #Funct
    'lambda',#Funct
    'identifier', #NL
    'string', #NL
    'comment', #NL
    'tuple', #Data
    'dictionary', #Data
    'list', #Data
    'set', #Data
    'try_statement', #Exceptions
    'except', #Exceptions
    'raise', #Exceptions
    'finally', #Exceptions
    'assert_statement', #Testing
    'integer', #types
    'float'#types
]

# %%
#| hide
#| eval: false
#https://datagy.io/filter-pandas/
pd_combined_models_filtered_global = pd_combined_models[pd_combined_models['ast_element'].isin( filtered_concepts_global )].copy()

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global.shape
# Out:
# (384, 9)

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global.head(1)
# Out:
#   ast_element node_type                                concept_median_prob  \
# 4           ]      leaf  [0.5011640191078186, 0.4131472706794739, 0.199...
#
#                                     concept_min_prob  \
# 4  [0.5011640191078186, 0.4131472706794739, 0.199...
#
#                                     concept_max_prob                    model  \
# 4  [0.5011640191078186, 0.4131472706794739, 0.199...  EleutherAI/gpt-neo-125m
#
#              id type_model size_model
# 4  gpt-3 [125M]      gpt-3       125M

# %%
#| export

def bootstrapping( np_data, np_func, size ):
    """Create a bootstrap sample given data and a function
    For instance, a bootstrap sample of means, or mediands. 
    The bootstrap replicates are a long as the original size
    we can choose any observation more than once (resampling with replacement:np.random.choice)
    """
    
    #Cleaning NaNs
    #np_data_clean = np_data[ np.logical_not( np.isnan(np_data) ) ] 
    
    #The size of the bootstrap replicate is as big as size
    #Creating the boostrap replicates as long as the orignal data size
    #This strategy might work as imputation 
    bootstrap_repl = [ np_func( np.random.choice( np_data, size=len(np_data) ) ) for i in range( size ) ]
    
    #logging.info("Covariate: " + cov) #Empirical Mean
    #logging.info("Empirical Mean: " + str(np.mean(np_data_clean))) #Empirical Mean
    #logging.info("Bootstrapped Mean: " + str( np.mean(bootstrap_repl) ) ) #Bootstrapped Mean
    
    return np.array( bootstrap_repl )

# %%
#| export

#see https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
def confidence_intervals_v2(data, confidence=0.95):
    dist = NormalDist.from_samples(data)
    z = NormalDist().inv_cdf((1 + confidence) / 2.)
    h = dist.stdev * z / ((len(data) - 1) ** .5)
    return dist.mean - h, dist.mean + h, h

#test_confidence = confidence_intervals_v2(data = test_boots, confidence=0.95)

# %%
#| export

def standard_error(bootstrapped_data):
    return np.std( bootstrapped_data )

# %%
#| hide
#| eval: false
# [WARNING] Bootstrapping Takes Time
pd_combined_models_filtered_global['median_bootstrap'] = pd_combined_models_filtered_global.apply(
        lambda row :
                np.median(
                        bootstrapping( 
                                np_data = eval(row.concept_median_prob),
                                np_func = np.median,
                                size = 500
                        )
                ) ,axis=1
    )

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global.head(2)
# Out:
#    ast_element node_type                                concept_median_prob  \
# 4            ]      leaf  [0.5011640191078186, 0.4131472706794739, 0.199...
# 20           }      leaf  [0.054765164852142334, 0.2852576673030853, 0.1...
#
#                                      concept_min_prob  \
# 4   [0.5011640191078186, 0.4131472706794739, 0.199...
# 20  [0.054765164852142334, 0.2852576673030853, 0.1...
#
#                                      concept_max_prob  \
# 4   [0.5011640191078186, 0.4131472706794739, 0.199...
# 20  [0.054765164852142334, 0.2852576673030853, 0.1...
#
#                       model            id type_model size_model  \
# 4   EleutherAI/gpt-neo-125m  gpt-3 [125M]      gpt-3       125M
# 20  EleutherAI/gpt-neo-125m  gpt-3 [125M]      gpt-3       125M
#
#     median_bootstrap
# 4           0.519970
# 20          0.407857

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global.to_csv('/workspaces/CodeSyntaxConcept/data/ds_processed_logits_global/out_astevalverticalfiltered_global_filtered_bts.csv')

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global['median_standard_error'] = pd_combined_models_filtered_global.apply(
        lambda row :
                standard_error(
                        bootstrapping( 
                                np_data = eval(row.concept_median_prob),
                                np_func = np.median,
                                size = 500
                        )
                ) ,axis=1
    )

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global.head(2)
# Out:
#    ast_element node_type                                concept_median_prob  \
# 4            ]      leaf  [0.5011640191078186, 0.4131472706794739, 0.199...
# 20           }      leaf  [0.054765164852142334, 0.2852576673030853, 0.1...
#
#                                      concept_min_prob  \
# 4   [0.5011640191078186, 0.4131472706794739, 0.199...
# 20  [0.054765164852142334, 0.2852576673030853, 0.1...
#
#                                      concept_max_prob  \
# 4   [0.5011640191078186, 0.4131472706794739, 0.199...
# 20  [0.054765164852142334, 0.2852576673030853, 0.1...
#
#                       model            id type_model size_model  \
# 4   EleutherAI/gpt-neo-125m  gpt-3 [125M]      gpt-3       125M
# 20  EleutherAI/gpt-neo-125m  gpt-3 [125M]      gpt-3       125M
#
#     median_bootstrap  median_standard_error
# 4           0.519970               0.002649
# 20          0.407857               0.004083

# %%
#| hide
#| eval: false
pd_combined_models_filtered_global.to_csv('/workspaces/CodeSyntaxConcept/data/ds_processed_logits_global/out_astevalverticalfiltered_global_filtered_bts.csv')

# %% [markdown]
# ## Local Combination

# %%
#| hide
#| eval: false
pd_combined_models_local = pd.read_csv( '/workspaces/CodeSyntaxConcept/data/ds_processed_logits_local/out_astevalverticalfiltered_c1.csv'  , index_col=0)

# %%
#| hide
#| eval: false
confounders = [ 'size', 'ast_levels', 'complexity', 'n_ast_nodes']
performance = [
               'for_statement', 
               'while_statement', 
               'return_statement',
               ']', 
               ')', 
               'if_statement', 
               'comparison_operator', 
               'boolean_operator',
               'for_in_clause', 
               'if_clause', 
               'list_comprehension', 
               'lambda',
               'identifier', 
               'string', 
               ]
outcome = ['loss']

# %%
#| hide
#| eval: false
pd_combined_models_local = pd_combined_models_local[confounders+performance+outcome].copy() #Filtering

# %%
#| hide
#| eval: false
pd_combined_models_local.head(1)
# Out:
#    size  ast_levels  complexity  n_ast_nodes  for_statement  while_statement  \
# 0   280          13           7          154            0.0              0.0
#
#    return_statement         ]         )  if_statement  ...  for_in_clause  \
# 0               0.0  0.457156  0.423305      0.587624  ...       0.722651
#
#    if_clause  list_comprehension  lambda  identifier    string     loss  \
# 0        0.0                 0.0     0.0    0.382276  0.390246  1.79292
#
#              id  type_model size_model
# 0  gpt-3 [125M]       gpt-3       125M
#
# [1 rows x 22 columns]

# %%
#| hide
#| eval: false
pd_combined_models_local['id'] = new_columns['c1'][0] + " [" + new_columns['c1'][1] + "]"
pd_combined_models_local['type_model'] = new_columns['c1'][0]
pd_combined_models_local['size_model'] = new_columns['c1'][1]

# %%
#| hide
#| eval: false
pd_combined_models_local.shape
# Out:
# (50971, 22)

# %%
#| hide
#| eval: false
for m in models[1:]:
    pd_temp = pd_combined_models_local.copy()
    pd_combined_models_local = pd.read_csv( f'/workspaces/CodeSyntaxConcept/data/ds_processed_logits_local/out_astevalverticalfiltered_{m}.csv'  , index_col=0)
    pd_combined_models_local = pd_combined_models_local[confounders+performance+outcome].copy() #Filtering
    
    pd_combined_models_local['id'] = new_columns[m][0] + " [" + new_columns[m][1] + "]"
    pd_combined_models_local['type_model'] = new_columns[m][0]
    pd_combined_models_local['size_model'] = new_columns[m][1]
    
    pd_combined_models_local = pd.concat( [pd_temp,pd_combined_models_local], ignore_index=True ) #vertical concatenation
    print(f"completed-{m}")
# Out:
# completed-c2
# completed-c3
# completed-c5
# completed-c6
# completed-c9
# completed-c10
# completed-c11
# completed-c14
# completed-c15
# completed-c16
# completed-c17

# %%
#| hide
#| eval: false
pd_combined_models_local.shape
# Out:
# (611652, 22)

# %%
#| hide
#| eval: false
pd_combined_models_local.to_csv('/workspaces/CodeSyntaxConcept/data/ds_processed_logits_local/out_astevalverticalfiltered_local.csv')
