# %%
import pandas as pd
import os
import time
import numpy as np
import torch
import gc

# %%
import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
logging.basicConfig(
    filename="logger_data_engineering_copy.txt",
    filemode='a',
    format='%(asctime)s : %(levelname)s : %(message)s', 
    level=logging.INFO
    )

# %%
import seaborn as sns
from scipy import stats
from statistics import NormalDist
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Engineering

# %%
def c_eleuther( returnModel = False, model_type =  'EleutherAI/gpt-neo-125m'):
    ''' Eleuther and Salesforce and Parrot uses the same importation'''
    from transformers import AutoTokenizer, AutoModelForCausalLM
    tokenizer = AutoTokenizer.from_pretrained(model_type)
    logging.info("Tokenizer Loaded")
    if returnModel:
        model = AutoModelForCausalLM.from_pretrained(model_type)
        logging.info("Model Loaded")
    else:
        model = []
    
    logging.info(model_type)
    return tokenizer, model
    
    

def init_model_args( current_case = 'c1', returnModel = False ): 
    
    code_models = {
        'c1':('EleutherAI/gpt-neo-125m', ), # Basic (on Pile) GPT-3/J
        'c2':('EleutherAI/gpt-neo-1.3B', ),
        'c3':('EleutherAI/gpt-neo-2.7B', ),
        'c4':('EleutherAI/gpt-j-6b', ),
        'c5':('Salesforce/codegen-350M-nl', ), #Basic (on Pile) codegen
        'c6':('Salesforce/codegen-2B-nl', ),
        'c7':('Salesforce/codegen-6B-nl', ),
        'c8':('Salesforce/codegen-16B-nl', ),
        'c9':('codeparrot/codeparrot-small-multi', ), #multi-Language
        'c10':('Salesforce/codegen-350M-multi', ),
        'c11':('Salesforce/codegen-2B-multi', ),
        'c12':('Salesforce/codegen-6B-multi', ),
        'c13':('Salesforce/codegen-16B-multi', ),
        'c14':('codeparrot/codeparrot-small', ), #mono-Language
        'c15':('codeparrot/codeparrot', ),
        'c16':('Salesforce/codegen-350M-mono', ),
        'c17':('Salesforce/codegen-2B-mono', ),
        'c18':('Salesforce/codegen-6B-mono', ),
        'c19':('Salesforce/codegen-16B-mono', ),
    }
    
    model_type = code_models[current_case][0]
    tokenizer, model =  c_eleuther( returnModel = returnModel,  model_type = model_type ) 
    
    
    return model_type, tokenizer, model

# %% [markdown]
# ## Init Parameters

# %%
# [WARNING] Hyperparameters changes, please tune them up
CODEMODEL =  'c5'
params = {
    'codemodel' : CODEMODEL,
    'numpy_files_logits_path': f'../datax/np_files_logits/{CODEMODEL}',
    'testbeds_path' : '../datax/testbeds/AstEvalVerticalFiltered.json',
    'outputs' : f'../data/ds_raw_logits/out_astevalverticalfiltered_{CODEMODEL}.csv'
}

# %%
params['outputs']
# Out:
# '../data/ds_raw_logits/out_astevalverticalfiltered_c5.csv'

# %%
#Uploading Model UnderAnalisys
name, tokenizer, model = init_model_args(
    current_case = params['codemodel'], 
    returnModel = False #[WARNING!] Check the parameters before calling it. 
    )
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/240 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]

# %%
#Testing data loads
data_pd = pd.read_json( params['testbeds_path'] )
data_pd.head(1)
# Out:
#    size                                                ids m_name
# 0   280  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...     c1  \
#
#                                                 code ast_errors  n_ast_errors
# 0  def run_python_tests(test_modules, parallelism...         []             0  \
#
#    ast_levels  n_whitespaces_  complexity  nloc  token_counts  n_ast_nodes
# 0          13              67           7    15           120          154

# %% [markdown]
# # Softmax Normalization and Data Engineering

# %%
filtered_prompts_ids = data_pd[data_pd['m_name']==params['codemodel']]['ids'].values

# %%
tf_input_ids = [torch.tensor(  input_ids, dtype = torch.int) for input_ids in filtered_prompts_ids ]

# %% [markdown]
# ### Testing Tokenizer

# %%
#Testung Sample to validate minmax functions
sample_id = 0
data_pd[data_pd['m_name']==params['codemodel']].iloc[sample_id]
# Out:
# size                                                            280
# ids               [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...
# m_name                                                           c5
# code              def run_python_tests(test_modules, parallelism...
# ast_errors                                                       []
# n_ast_errors                                                      0
# ast_levels                                                       13
# n_whitespaces_                                                   67
# complexity                                                        7
# nloc                                                             15
# token_counts                                                    120
# n_ast_nodes                                                     154
# Name: 203884, dtype: object

# %%
tf_input_ids[sample_id]
# Out:
# tensor([ 4299,  1057,    62, 29412,    62, 41989,     7,  9288,    62, 18170,
#            11, 10730,  1042,    11,   351,    62,  1073,  1857,    28, 25101,
#          2599,   198,   220,   220,   220,   900,    62,  7839,    62,   392,
#            62,  9967,  7203, 28768,  9485,  4561,   668,  5254,  1600,   366,
#          9148, 11290,    62,    47,    56,  4303, 14175,    62,  4944,  2043,
#            62,    51,  1546,  4694,  4943,   628,   220,   220,   220,   611,
#           351,    62,  1073,  1857,    25,   198,   220,   220,   220,   220,
#           220,   220,   220,  1303, 33998,  1838,   262,  9485,  4561,   668,
#          5254,   781, 15492,  2233,   284,  4334, 10730,  1042,    13,   198,
#           220,   220,   220,   220,   220,   220,   220,  1303,  1649,   356,
#          1057,  9485,  4561,   668,  5254,   351,  5197,    11,   340,  3544,
#           604,   329,   783,   355,   198,   220,   220,   220,   220,   220,
#           220,   220,  1303, 46513,    13,   198,   220,   220,   220,   220,
#           220,   220,   220, 10730,  1042,   796,   604,   198,   220,   220,
#           220,   220,   220,   220,   220,  4226,   796,   366,  5143,    12,
#         41989,    12,  4480,    12,  1073,  1857,     1,   198,   220,   220,
#           220,  2073,    25,   198,   220,   220,   220,   220,   220,   220,
#           220,  4226,   796,   366,  5143,    12, 41989,     1,   198,   220,
#           220,   220,  3141,   796,   685,   418,    13,  6978,    13, 22179,
#             7,  4303, 14175,    62, 39069,    11,   366, 29412,  1600,  4226,
#         15437,   198,   220,   220,   220,   611,  1332,    62, 18170, 14512,
#           685, 18170,    13, 15763,  5974,   198,   220,   220,   220,   220,
#           220,   220,   220,  3141,    13, 33295,  7203,   438, 18170,    28,
#             4,    82,     1,  4064,   705,  4032,    13, 22179,     7,    76,
#            13,  3672,   329,   285,   287,  1332,    62, 18170,  4008,   198,
#           220,   220,   220,  3141,    13, 33295,  7203,   438,  1845, 29363,
#          1042,    28,     4,    72,     1,  4064, 10730,  1042,     8,   198,
#           220,   220,   220,  1057,    62, 28758,     7, 21812,     8,   628],
#        dtype=torch.int32)

# %%
# Loading Logits From Files
out= np.load( params['numpy_files_logits_path'] +'/' + f'logits_tensor[{sample_id}]_batch[{sample_id}]_model[{CODEMODEL}].npy' )
soft = torch.nn.Softmax( dim = 0 ) #Flattening normalization
first_token_distribution = soft( torch.from_numpy(out[0]) ) #Flattening normalization for fist token
assert round(first_token_distribution.sum().item()) == 1.0

# %%
first_token_distribution[0]
# Out:
# tensor(0.0009)

# %%
tokenizer.decode([7881])
# Out:
# ' register'

# %%
tokenizer.vocab.keys()
# Out:
# dict_keys(['Ġhomicide', 'Ġapart', 'Reg', 'Do', 'bot', 'Ġmerge', 'Ġlining', 'Ġsimplest', 'Ġbillionaires', 'ĠWilliamson', 'increasing', 'ĠJon', 'mm', 'ĠDefin', 'Ġboss', 'ĠWii', 'lay', 'ĠKirin', 'ĠSomebody', 'Ġindistinguishable', 'ĠTechnical', 'ĠAtari', '+.', 'Ġovercl', 'ĠLaos', 'diff', 'ĠTrinidad', 'adel', '143', 'õ', 'ĠEnter', 'ĠAmbro', 'ma', 'Ġvalued', 'Ġleases', 'Ġambassadors', 'ãģķ', 'ĠYour', 'ĠSin', 'Db', 'ĠMonica', 'forest', 'jew', 'Ġiso', 'Repe', 'outed', 'Ġfright', 'ĠKatie', 'ĠThey', 'Ġmetabolism', 'Ġdragons', 'Ġtitanium', 'Ġcontributions', 'ĠJosh', 'Ġ05', 'Ġgym', 'Ġmasked', 'ĠThou', 'resources', 'ivas', 'Ġdesktop', 'Ġvibr', 'Ġmembr', 'Ġprophet', 'ãģ¯', 'ooked', 'Ġ++', 'ĠAcqu', 'Ġscen', 'ĠACTION', 'Ġ387', 'Ġbatch', 'OIL', 'angler', '****', 'Ġdreaded', 'Ġstorylines', 'RED', 'pmwiki', '226', 'brew', 'ĠCitadel', 'wark', 'Compat', 'ãĥ', 'ĠCommunications', 'quire', 'Ġscholarly', 'Ġstringent', 'ayson', 'Ġrubbish', 'onics', 'ĠPrepare', 'GAME', 'Ġseamless', 'Ġdistricts', 'ORPG', 'ĠRecipe', 'Ġgenetic', 'Ġtricked', 'clinical', 'Ġanime', 'sd', 'Grid', 'Ġunintended', 'Ġspoof', 'GUI', 'Ġculminating', 'Ġitiner', 'Static', 'Ġmemories', 'ĠSeven', 'itt', 'ĠCrest', 'Ġchefs', 'Ġreadiness', 'Ġmil', 'ĠAlternatively', 'Ġquota', 'Ġpurposefully', 'ĠDetroit', 'psc', 'ĠName', 'recorded', 'Ġachievement', 'ĠAddress', 'Ġrhet', 'Review', 'Ġintens', 'Ġgun', 'imedia', 'awei', 'Ġgoodness', 'Ġpoker', '255', 'ĠGST', 'AUT', 'oline', 'Ġflyer', 'Ġ())', 'ĠMoff', 'Amid', 'Ġhoped', 'ESSION', 'Ġimpressions', 'ĠAbu', 'Ġpartition', 'PAT
pronounce', 'Ġclen', 'Ġdigs', 'Ġdigest', 'Ġbount', 'ĠKatz', 'Ġignore', 'ĠAbsolute', 'Ġjeans', 'Ġambitions', 'ĠRolls', 'Ġexpands', 'endment', 'Ġterminate', 'Ġnascent', 'Ġlanded', 'Ġencrypted', 'Ġpane', 'ĠNil', 'Nitrome', 'Ġmattered', 'Ġhostages', 'feature', 'ĠALEC', '=#', '=-=-=-=-=-=-=-=-', 'Pie', 'arte', 'Ġ<-', 'Ġelder', 'Ġturbulence', 'Ġtw', 'Ġillegitimate', 'Ġcandid', 'Ġenriched', 'Ġglow', 'Ġarbitrary', 'ĠOss', 'Ġcalibrated',  ...

# %%
tokenizer.get_vocab()
# Out:
# {'Ġhomicide': 19625,
#  'Ġapart': 5475,
#  'Reg': 8081,
#  'Do': 5211,
#  'bot': 13645,
#  'Ġmerge': 20121,
#  'Ġlining': 20883,
#  'Ġsimplest': 24043,
#  'Ġbillionaires': 34740,
#  'ĠWilliamson': 34974,
#  'increasing': 42647,
#  'ĠJon': 5966,
#  'mm': 3020,
#  'ĠDefin': 29589,
#  'Ġboss': 6478,
#  'ĠWii': 16591,
#  'lay': 10724,
#  'ĠKirin': 40262,
#  'ĠSomebody': 43141,
#  'Ġindistinguishable': 43649,
#  'ĠTechnical': 20671,
#  'ĠAtari': 35884,
#  '+.': 27613,
#  'Ġovercl': 40397,
#  'ĠLaos': 45919,
#  'diff': 26069,
#  'ĠTrinidad': 48269,
#  'adel': 6959,
#  '143': 21139,
#  'õ': 177,
#  'ĠEnter': 6062,
#  'ĠAmbro': 43233,
#  'ma': 2611,
#  'Ġvalued': 17560,
#  'Ġleases': 38522,
#  'Ġambassadors': 41702,
#  'ãģķ': 43357,
#  'ĠYour': 3406,
#  'ĠSin': 10884,
#  'Db': 43832,
#  'ĠMonica': 23240,
#  'forest': 29623,
#  'jew': 47483,
#  'Ġiso': 47279,
#  'Repe': 47541,
#  'outed': 18534,
#  'Ġfright': 12773,
#  'ĠKatie': 24721,
#  'ĠThey': 1119,
#  'Ġmetabolism': 20211,
#  'Ġdragons': 20308,
#  'Ġtitanium': 41284,
#  'Ġcontributions': 9284,
#  'ĠJosh': 8518,
#  'Ġ05': 8870,
#  'Ġgym': 11550,
#  'Ġmasked': 29229,
#  'ĠThou': 34048,
#  'resources': 37540,
#  'ivas': 38630,
#  'Ġdesktop': 11364,
#  'Ġvibr': 12611,
#  'Ġmembr': 19890,
#  'Ġprophet': 22298,
#  'ãģ¯': 31676,
#  'ooked': 46288,
#  'Ġ++': 19969,
#  'ĠAcqu': 24939,
#  'Ġscen': 4408,
#  'ĠACTION': 40282,
#  'Ġ387': 49689,
#  'Ġbatch': 15458,
#  'OIL': 49713,
#  'angler': 49910,
#  '****': 2466,
#  'Ġdreaded': 39229,
#  'Ġstorylines': 44880,
#  'RED': 22083,
#  'pmwiki': 45321,
#  '226': 24909,
#  'brew': 11269,
#  'ĠCitadel': 32266,
#  'wark': 48542,
#  'Compat': 40073,
#  'ãĥ': 1209,
#  'ĠCommunications': 14620,
#  'quire': 29782,
#  'Ġscholarly': 31950,
#  'Ġstringent': 32791,
#  'ayson': 34907,
#  'Ġrubbish': 35022,
#  'onics': 38530,
#  'ĠPrepare': 43426,
#  'GAME': 47109,
#  'Ġseamless': 32354,
#  'Ġdistricts': 12815,
#  'ORPG': 49665,
#  'ĠRecipe': 26694,
#  'Ġgenetic': 8513,
#  'Ġtricked': 42608,
#  'clinical': 47367,
#  'Ġanime': 11984,
#  'sd': 21282,
#  'Grid': 41339,
#  'Ġunintended': 30261,
#  'Ġspoof': 42078,
#  'GUI': 40156,
#  'Ġculminating': 43896,
#  'Ġitiner': 45142,
#  'Static': 45442,
#  'Ġmemories': 9846,
#  'ĠSeven': 13723,
#  'itt': 715,
#  'ĠCrest': 40072,
#  'Ġchefs': 36236,
#  'Ġreadiness': 30618,
#  'Ġmil': 1465,
#  'ĠAlternatively': 25929,
#  'Ġquota': 32539,
#  'Ġpurposefully': 45136,
#  'ĠDetroit': 8488,
#  'psc': 27566,
#  'ĠName': 6530,
#  'recorded': 47398,
#  'Ġachievement': 13293,
#  'ĠAddress': 17917,
#  'Ġrhet': 11388,
#  'Review': 14832,
#  'Ġintens': 17509,
#  'Ġgun': 2485,
#  'imedia': 20626,
#  'awei': 38247,
#  'Ġgoodness': 20437,
#  'Ġpoker': 27101,
#  '255': 13381,
#  'ĠGST': 31802,
#  'AUT': 39371,
#  'oline': 14453,
#  'Ġflyer': 42464,
#  'Ġ())': 32865,
#  'ĠMoff': 41069,
#  'Amid': 43541,
#  'Ġhoped': 10719,
#  'ESSION': 47621,
#  'Ġimpressions': 25885,
#  'ĠAbu': 13098,
#  'Ġpartition': 18398,
#  'PATH': 34219,
#  'Ġemanating': 49085,
#  'makes': 49123,
#  'Ġthin': 7888,
#  'Ġpatriarchy': 41932,
#  'Ġoverlay': 33345,
#  'Ġevaluating': 22232,
#  'ĠElectronics': 27828,
#  'ĠEVERY': 27222,
#  'ĠYorker': 27980,
#  'ĠAHL': 35297,
#  'ĠEater': 40366,
#  'Ġjob': 1693,
#  'ĠOut': 3806,
#  'Ġaccept': 2453,
#  'ĠBrazilian': 17036,
#  'Ġinitiatives': 15446,
#  'Ġpardon': 27322,
#  'ĠKitty': 21168,
#  'ĠDP': 27704,
#  'Ġoverlapping': 32997,
#  'Ġinjecting': 41750,
#  'being': 11873,
#  'ĠRail': 12950,
#  'ĠPHP': 19599,
#  'Ġnationwide': 13673,
#  'Ġbrake': 20439,
#  'ĠRIGHT': 33621,
#  'Other': 6395,
#  'ĠBarbarian': 38946,
#  'ĠShinra': 47981,
#  'ĠRedmond': 49420,
#  'pled': 10137,
#  'Ġintimate': 16584,
#  'ĠAn': 1052,
#  'Vers': 34947,
#  'Mod': 5841,
#  'ability': 1799,
#  'ĠRory': 37178,
#  'Ġmadness': 23208,
#  'icit': 3628,
#  'EEK': 33823,
#  'Ġsubdued': 38759,
#  'Ġsidelined': 39632,
#  'Ġcellphone': 26346,
#  'pro': 1676,
#  'ĠVag': 37203,
#  'ĠDuterte': 25763,
#  'ĠFein': 45711,
#  'Ġpartying': 49901,
#  'lightly': 30945,
#  'Ġgazed': 50255,
#  'ĠThermal': 41590,
#  'ĠPACK': 47035,
#  'Ġsay': 910,
#  'low': 9319,
#  'call': 13345,
#  'Ġlubric': 33211,
#  'ĠHa': 9398,
#  'ĠIr': 5686,
#  'Ġreputable': 40300,
#  'Ġwitnessing': 31121,
#  'ĠDrift': 39819,
#  'Ġproves': 17021,
#  'Ġspeaker': 10834,
#  'Prop': 24331,
#  'innamon': 21920,
#  'udos': 42418,
#  'Ġprinces': 42676,
#  'Ġcommunications': 8062,
#  'God': 13482,
#  'hook': 25480,
#  '1967': 42830,
#  'Ġsubscribe': 12383,
#  'han': 7637,
#  'Ġ245': 29637,
#  'Ub': 36609,
#  'Ġgrounds': 9384,
#  'opsy': 44522,
#  'Ġriders': 13750,
#  'Ġwagon': 31860,
#  'urat': 39928,
#  'ĠCanucks': 31252,
#  'Ġundergrad': 43485,
#  'Ġhope': 2911,
#  'Ġformat': 5794,
#  'ĠInsert': 35835,
#  'otics': 23891,
#  '||||': 42210,
#  'Ġdaughter': 4957,
#  'SPEC': 48451,
#  'Ġassay': 40575,
#  'ĠAsked': 26220,
#  'nine': 30888,
#  'Ġdictated': 34756,
#  'terday': 6432,
#  'ĠAub': 19723,
#  'ĠCast': 5833,
#  'Ġadversely': 34079,
#  '511': 41647,
#  'inline': 45145,
#  'Ġtactical': 16106,
#  'seek': 36163,
#  'affiliated': 46818,
#  '978': 32196,
#  'idal': 11624,
#  'ampires': 27933,
#  'ĠOlson': 31530,
#  'Ġunn': 41231,
#  'uminum': 13074,
#  'Ġdeceased': 20117,
#  'Ġchanged': 3421,
#  'Company': 39154,
#  'ĠMalk': 41980,
#  'Ġlinear': 14174,
#  'ipal': 8521,
#  'holm': 22981,
#  'ĠSupporting': 44188,
#  'ĠSv': 44343,
#  'ĠHenri': 44485,
#  'Ġreelection': 36630,
#  'ĠLe': 1004,
#  'ĠLauderdale': 45577,
#  'anders': 45070,
#  'ĠBrilliant': 45891,
#  'ilar': 1794,
#  'Ġaccount': 1848,
#  'ĠCommun': 4440,
#  'ĠGEN': 24700,
#  'ĠPirate': 17418,
#  'Ġmasculine': 27543,
#  'Ġoft': 28639,
#  'Ġvenues': 22276,
#  'Ġevidenced': 30204,
#  'Eventually': 28724,
#  'ĠUd': 35774,
#  'Ġspinach': 39129,
#  'ĠMiner': 29295,
#  'Actually': 26417,
#  'ĠFight': 10480,
#  'chel': 29232,
#  'ĠTrog': 35791,
#  'Ġimperialist': 40061,
#  'ĠMarx': 10487,
#  'ĠHick': 42441,
#  'Ġcuriously': 43211,
#  'Ġtrusting': 33914,
#  'ignore': 46430,
#  'ĠRahman': 46611,
#  'Ġapologizing': 47401,
#  'ĠRagnar': 32797,
#  'aiman': 47840,
#  'hus': 7537,
#  'Ġscreaming': 14788,
#  'ick': 624,
#  'ĠKurdish': 14845,
#  'Ġ+=': 15853,
#  'Ġassociates': 20093,
#  'Ġcomplement': 16829,
#  'ĠThrones': 20902,
#  'cious': 4680,
#  'Ġbunker': 36892,
#  'onial': 30752,
#  'Ġthirds': 41188,
#  'Ġsulph': 45558,
#  'Fish': 39428,
#  'Ġ333': 23460,
#  'abbit': 14229,
#  'ĠMartha': 27243,
#  'Ġmassive': 4858,
#  'Ġcone': 27763,
#  'ORTS': 33002,
#  'Ġdystop': 39227,
#  'highly': 47444,
#  'Ġsupermarkets': 40875,
#  'Ġstiff': 15175,
#  'Ġresembles': 22960,
#  'Ġsewer': 34327,
#  'ĠBeen': 36844,
#  'Ġgunned': 49474,
#  'ĠHeist': 50157,
#  'ĠGraphic': 43029,
#  'ĠOrche': 30369,
#  'Ġcharg': 2609,
#  'Ġcivic': 23265,
#  'realDonaldTrump': 28024,
#  'Tracker': 35694,
#  'ĠERA': 18802,
#  'ĠSuzanne': 45587,
#  'ĠIC': 12460,
#  'ãĤ¢': 11839,
#  'tower': 36170,
#  'Ġeverything': 2279,
#  'ĠBrad': 8114,
#  'Ġpronounce': 28942,
#  'Ġclen': 38566,
#  'Ġdigs': 46561,
#  'Ġdigest': 16274,
#  'Ġbount': 49937,
#  'ĠKatz': 36290,
#  'Ġignore': 8856,
#  'ĠAbsolute': 36532,
#  'Ġjeans': 21029,
#  'Ġambitions': 22455,
#  'ĠRolls': 40074,
#  'Ġexpands': 27513,
#  'endment': 5904,
#  'Ġterminate': 23654,
#  'Ġnascent': 45419,
#  'Ġlanded': 11406,
#  'Ġencrypted': 19365,
#  'Ġpane': 37218,
#  'ĠNil': 29213,
#  'Nitrome': 42066,
#  'Ġmattered': 33343,
#  'Ġhostages': 31331,
#  'feature': 30053,
#  'ĠALEC': 44946,
#  '=#': 46249,
#  '=-=-=-=-=-=-=-=-': 46402,
#  'Pie': 48223,
#  'arte': 32074,
#  'Ġ<-': 24293,
#  'Ġelder': 10550,
#  'Ġturbulence': 47741,
#  'Ġtw': 665,
#  'Ġillegitimate': 41368,
#  'Ġcandid': 2960,
#  'Ġenriched': 35601,
#  'Ġglow': 19634,
#  'Ġarbitrary': 14977,
#  'ĠOss': 45397,
#  'Ġcalibrated': 48050,
#  'Ġhorm': 12241,
#  'Ġabundantly': 49244,
#  'ĠTarant': 43693,
#  'Ġdrilled': 34936,
#  'Ġencountered': 12956,
#  'solid': 39390,
#  'Ġinformation': 1321,
#  'Ġbrightly': 35254,
#  'cribed': 32968,
#  'Ġgrossly': 40316,
#  'Ġcloak': 24117,
#  'Ġchecked': 10667,
#  'âĸĢ': 44033,
#  'rev': 18218,
#  'Ġvivid': 21002,
#  'atically': 4142,
#  'Ġhailed': 27052,
#  'Ġdirection': 4571,
#  'ĠSept': 2362,
#  'ĠLyn': 10350,
#  'ĠLam': 10923,
#  'Ġmanageable': 36426,
#  'ĠPLAN': 45650,
#  'Ġ"\'': 24018,
#  'Inc': 25517,
#  'angle': 9248,
#  '2018': 7908,
#  'Ġhumiliated': 42659,
#  'when': 12518,
#  'Ġinauguration': 23166,
#  'set': 2617,
#  'Ġpunk': 22782,
#  '548': 49934,
#  'ĠDetection': 46254,
#  'otypes': 13567,
#  'Ġvoluntary': 16171,
#  'STATE': 44724,
#  'Ġcreek': 39459,
#  'von': 26982,
#  'Toy': 48236,
#  'Ġcreatures': 8109,
#  'ral': 1373,
#  'Ġperipher': 18375,
#  'Scene': 36542,
#  'ĠÙĪ': 42092,
#  'oultry': 30056,
#  'Ġviral': 14416,
#  'quickShipAvailable': 39753,
#  'MD': 12740,
#  'Ġservings': 43096,
#  'ãĥ¼ãĥ³': 31708,
#  'Ġlocally': 15726,
#  'rawler': 39464,
#  'Ġreflect': 4079,
#  'iced': 3711,
#  'ĠIR': 14826,
#  'Ġscaven': 35998,
#  'Ġ1964': 17575,
#  'ĠDota': 30710,
#  'Ġintolerance': 31545,
#  'platform': 24254,
#  'Ġuntold': 47872,
#  'year': 1941,
#  'ĠVampire': 21463,
#  'Ġhomeland': 23184,
#  'Arc': 24021,
#  '~': 93,
#  'ĠDeity': 15081,
#  'sc': 1416,
#  'essel': 7878,
#  'Ġcf': 30218,
#  'Ġdashboard': 30415,
#  'unknown': 34680,
#  'Drug': 37943,
#  'ĠKaplan': 37105,
#  'rawdownload': 30905,
#  'ĠSharia': 38627,
#  'tracks': 46074,
#  'ĠFord': 8092,
#  'Mr': 5246,
#  'ench': 24421,
#  'Hig': 36124,
#  'rane': 14579,
#  'Ġstimuli': 25973,
#  'Ġstack': 8931,
#  'ĠVi': 16049,
#  'Ġburns': 20246,
#  'Ġlbs': 15785,
#  'Ġtoilet': 16146,
#  'Ġconsequences': 6948,
#  'ĠTF': 24958,
#  'Ġgalaxies': 27982,
#  'Ġservant': 18807,
#  'Ġcorrobor': 30220,
#  'ĠCrunch': 38531,
#  'onyms': 43612,
#  'xual': 5541,
#  'Ġnut': 6701,
#  'ĠWD': 48963,
#  'ĠSue': 26089,
#  'Ġransomware': 49134,
#  'major': 22478,
#  'ĠWiley': 43424,
#  'ĠRoyale': 49982,
#  'ĠMX': 26135,
#  'Ġ%%': 43313,
#  'Ġgeological': 41917,
#  'Ġextensions': 18366,
#  'Ġdonate': 16565,
#  'OCK': 11290,
#  'ĠShane': 24379,
#  'ĠSnyder': 22543,
#  'Ġneoc': 29938,
#  'ĠIMP': 30023,
#  'ĠLebanese': 28076,
#  'Ġrecord': 1700,
#  'ĠLong': 5882,
#  'Ġnature': 3450,
#  'Mrs': 27034,
#  'Shock': 31646,
#  'Ġformulas': 32126,
#  'Ġtabl': 36148,
#  'Ġdisclosed': 16404,
#  'Ġparasites': 36643,
#  'aires': 17693,
#  'Ġcondom': 33791,
#  'Ġupstairs': 26148,
#  'Ġdiscontin': 19936,
#  'Ġsemif': 32948,
#  'Ġdeadlines': 36773,
#  'Ġflair': 37457,
#  'Ġsimpl': 7106,
#  'Ġvisitor': 21493,
#  'Ġintroduce': 10400,
#  'Ġaerospace': 40439,
#  'PLIC': 31484,
#  'Ġcheap': 7026,
#  'Ġdistressed': 36233,
#  'Ġvascular': 39495,
#  'ombat': 41628,
#  'Dialog': 44204,
#  'Ġformulated': 34391,
#  'Ġadditions': 19885,
#  'Ġmoan': 44567,
#  'ĠTony': 8832,
#  'Whoever': 47896,
#  'Vector': 38469,
#  'Ġexhibitions': 48130,
#  'Ġfocusing': 10759,
#  'Ġsprint': 18553,
#  'necessary': 49986,
#  'Decl': 37835,
#  'SAN': 36753,
#  'ĠToxic': 29274,
#  'HO': 32298,
#  'Âº': 36165,
#  'Ġcigar': 24518,
#  'ĠPhelps': 40587,
#  'ĠNow': 2735,
#  'ĠHad': 11161,
#  'ĠSoldier': 20104,
#  'Ġwithdrawal': 15220,
#  'ines': 1127,
#  'Ġammunition': 14271,
#  'Initial': 24243,
#  'Professor': 25031,
#  'mir': 10793,
#  'letcher': 29257,
#  'anky': 39556,
#  'ol': 349,
#  'ographies': 41480,
#  '048': 47202,
#  'ĠStamford': 47604,
#  'Ġ352': 44063,
#  'leness': 48795,
#  'ĠFacilities': 48939,
#  'ĠConsumers': 45103,
#  'ults': 8376,
#  'inka': 48955,
#  'ĠFramework': 25161,
#  'ĠNur': 49281,
#  'ĠParadise': 20494,
#  'Ġgravity': 13522,
#  'MOD': 33365,
#  'getting': 37210,
#  'forward': 11813,
#  'pointer': 29536,
#  'ĠLoop': 26304,
#  'Ġaffect': 2689,
#  'Ġmonitored': 20738,
#  'dogs': 22242,
#  'ĠExpress': 10604,
#  'Ġdrafts': 30247,
#  'Stand': 15480,
#  'IFE': 29150,
#  'ĠCycl': 28007,
#  'spection': 31308,
#  'Ġdelightful': 32327,
#  '49': 2920,
#  'Ġsentiment': 15598,
#  'Ġsurgeon': 23923,
#  'Ġstone': 7815,
#  'localhost': 36750,
#  'anted': 4126,
#  'Ġintervening': 37294,
#  'ĠTri': 7563,
#  'ĠPatterson': 27042,
#  'Ī': 230,
#  'Ġclassification': 17923,
#  'Ġinsign': 24191,
#  'ĠHiro': 25940,
#  'ĠCarly': 35982,
#  'Ġboring': 14262,
#  'Ġhus': 4791,
#  'ĠInstead': 5455,
#  'ĠSeveral': 12168,
#  'Socket': 39105,
#  'Mir': 27453,
#  'rollers': 36667,
#  'ÃŃn': 39588,
#  'ĠRowling': 41558,
#  'Ġmirrored': 40070,
#  'Ġprofessionals': 11153,
#  'conference': 41124,
#  'ĠCoh': 47222,
#  'ĠScale': 21589,
#  'ĠDaylight': 47743,
#  'ĠTemper': 48125,
#  'ĠWisconsin': 9279,
#  'Ġpreferential': 47136,
#  'Ġflagship': 21336,
#  'Ġusability': 42863,
#  'ĠCBI': 47970,
#  'grain': 48270,
#  'Ġeyeing': 48847,
#  "'d": 1549,
#  'OM': 2662,
#  'ĠFood': 7318,
#  'Ġelectrical': 12278,
#  'Ġpots': 32195,
#  'ĠPsy': 18773,
#  'Ġshred': 21163,
#  'ĠADD': 27841,
#  'ĠInform': 45255,
#  'Ġcaul': 46087,
#  'vis': 4703,
#  'ĠHaas': 50090,
#  'incinn': 15020,
#  'Ġattainment': 40375,
#  'Ġdolphins': 36798,
#  'Ġtypew': 49938,
#  'ĠShed': 49340,
#  'ĠMicha': 38844,
#  'Where': 8496,
#  'Lib': 25835,
#  'ĠAo': 27378,
#  'lib': 8019,
#  'ĠALSO': 35912,
#  'ĠGospel': 23244,
#  'Ġcontainer': 9290,
#  'ĠTim': 5045,
#  'string': 8841,
#  'Contact': 17829,
#  'Ø±': 26897,
#  'ĠStructure': 32522,
#  'ĠShiite': 31445,
#  'Ġbaseline': 14805,
#  'Ġmeat': 6174,
#  'ĠAustin': 9533,
#  'few': 32146,
#  'ãĤ©': 37662,
#  'Ġgained': 8618,
#  'Ġcollaboration': 12438,
#  'thia': 31079,
#  'ĠShowdown': 46645,
#  'Ġpir': 12276,
#  'Ġ{': 1391,
#  'Ġunsub': 32793,
#  'Ġsediment': 33408,
#  '140': 15187,
#  'ĠNash': 13950,
#  'Ren': 26764,
#  'ĠBlaster': 33406,
#  'Ġresiding': 35173,
#  'cerned': 49990,
#  'Ġmicrowave': 27000,
#  'ĠIniti': 16204,
#  'Ġcoincidence': 21083,
#  'Ġsignatures': 17239,
#  'Ġclinic': 15760,
#  'Ġapartments': 19592,
#  'kit': 15813,
#  'Ġbreaching': 46837,
#  'Ġflushed': 44869,
#  'dm': 36020,
#  'apter': 3429,
#  'Ġelbow': 22662,
#  'ĠACA': 27628,
#  'ĠBrighton': 33193,
#  'Individual': 35392,
#  'Ġdifferential': 22577,
#  'ĠDw': 19113,
#  'Ġdripping': 37472,
#  'Ġiv': 21628,
#  'zbek': 40413,
#  'ĠAtmospheric': 41516,
#  'Ġdifferently': 10338,
#  'Ġconsumed': 13529,
#  'Ġdisappearing': 28867,
#  '443': 34938,
#  'oidal': 47502,
#  'ĠNag': 15196,
#  'Crypt': 23919,
#  'plementation': 32851,
#  'ison': 1653,
#  'omi': 12753,
#  'ginx': 42822,
#  'ĠPoly': 12280,
#  'Ġcampaigned': 32853,
#  'ertain': 1425,
#  'Ġvideot': 35026,
#  'Could': 23722,
#  'story': 13571,
#  'ĠCrowley': 35332,
#  'Ġwaitress': 44511,
#  'Ġsweeps': 46778,
#  'Ġ(=': 46121,
#  'please': 29688,
#  'Ġinsects': 19435,
#  'Ġmodes': 12881,
#  'Ġdiction': 48589,
#  'Ġsimulac': 48911,
#  'Ġenabling': 15882,
#  'ifle': 8316,
#  'Ġheap': 24575,
#  'jas': 28121,
#  'Ġtransient': 32361,
#  'Ġtied': 8165,
#  'Ġprank': 33401,
#  'ĠEzek': 45875,
#  'Ġuranium': 22010,
#  'gn': 4593,
#  'ĠCop': 6955,
#  'Ġpython': 21015,
#  'issan': 24112,
#  'Ġreliance': 24126,
#  'Ġaren': 3588,
#  'iral': 21093,
#  'eous': 15303,
#  'Ġfled': 11468,
#  'VO': 29516,
#  'ome': 462,
#  'ĠSil': 4243,
#  'Examples': 27730,
#  'Ġclich': 35478,
#  'ĠCore': 7231,
#  'ĠETH': 35920,
#  'Sounds': 40825,
#  'enges': 34120,
#  'Ġrivals': 14987,
#  'ĠProduction': 19174,
#  'Ġchairman': 8900,
#  'ĠRam': 7431,
#  'ĠBudget': 15401,
#  'ĠConfig': 17056,
#  'gie': 22699,
#  'ordon': 9999,
#  'Ġquarters': 13620,
#  'omic': 10179,
#  '103': 15197,
#  'information': 17018,
#  'ĠTory': 19037,
#  'ĠAge': 7129,
#  'ĠAlz': 21535,
#  ')': 8,
#  'olic': 4160,
#  'ĠPlot': 28114,
#  'Ġunlawful': 18236,
#  'Entry': 30150,
#  'Ġspraying': 40170,
#  'Ġdevils': 42466,
#  'uary': 2838,
#  'Ġappre': 5208,
#  'Ġfundamentally': 17640,
#  'Ġideas': 4213,
#  'CRE': 43387,
#  'Ġ399': 43927,
#  'ports': 3742,
#  'ARD': 9795,
#  'ĠBoe': 12415,
#  'park': 20928,
#  'Ġsymbol': 6194,
#  'joice': 41026,
#  'Ġmedically': 35031,
#  'Ġspecified': 7368,
#  'Ġcircumference': 38447,
#  'ĠStarted': 31026,
#  'ĠCisco': 28289,
#  'Ġscares': 44462,
#  'Ġtrophies': 21732,
#  'Ġscrape': 42778,
#  'ĠSammy': 44067,
#  'Ġ379': 45937,
#  'rupulous': 46272,
#  'Ġtanker': 46335,
#  'Ġ432': 46393,
#  'ĠPrelude': 46897,
#  'Ġdiligent': 47334,
#  'Ġshameless': 41564,
#  'ĠNE': 10635,
#  'ĠRabbi': 31807,
#  'Ġslander': 47397,
#  'len': 11925,
#  '=-=-': 16822,
#  'ĠThur': 36975,
#  'roman': 47119,
#  'Ġvisualize': 38350,
#  'Theme': 47863,
#  'Ġobjectionable': 48540,
#  'Indiana': 49153,
#  'Ġdisrupted': 30067,
#  'ĠCoffee': 19443,
#  'ĠSAN': 37376,
#  'Ġbirds': 10087,
#  'Ġcopper': 15317,
#  'avage': 33757,
#  'Ġchin': 22531,
#  'Ġse': 384,
#  'ĠBritish': 3517,
#  'ĠSeed': 23262,
#  'Ġcents': 16059,
#  'ĠQuite': 29051,
#  'atalie': 30951,
#  'Roberts': 45487,
#  'Pattern': 47546,
#  'blow': 48619,
#  'ilantro': 48311,
#  'aquin': 48734,
#  'repair': 49932,
#  'ĠPHI': 48121,
#  'ĠAgriculture': 19717,
#  'Ġtoys': 14958,
#  'Ġoppressed': 25765,
#  'ĠPassword': 30275,
#  'Ġinputs': 17311,
#  '2200': 34294,
#  'euro': 44252,
#  'Ġspare': 13952,
#  'utf': 40477,
#  'Ġresume': 15294,
#  'ĠSunderland': 35706,
#  'ĠRecall': 44536,
#  'ĠRender': 46722,
#  'vill': 41082,
#  'Ġexce': 43748,
#  'Ġ}': 1782,
#  'Ġenclave': 49842,
#  '234': 24409,
#  'Ġ502': 47233,
#  'Ġresolving': 31038,
#  'answered': 31966,
#  'Ġbottle': 9294,
#  'ĠLtd': 12052,
#  'Ġjaw': 19218,
#  'Ġgrounded': 22804,
#  'Volume': 31715,
#  'Cu': 46141,
#  'PAR': 27082,
#  'ĠPROT': 48006,
#  'ĠSocial': 5483,
#  'Ġ&&': 11405,
#  'Ġtallest': 38760,
#  'Ġfrustration': 14285,
#  'Ġstop': 2245,
#  'Karl': 46063,
#  'Ġammo': 16778,
#  'ĠPopular': 22623,
#  'Ġparagraph': 7322,
#  'CD': 8610,
#  'ossus': 36533,
#  'Ġsequences': 16311,
#  'ĠMag': 2944,
#  'aic': 18452,
#  'pain': 35436,
#  'Ġobj': 26181,
#  'Ġsorcerer': 47063,
#  'itol': 11650,
#  'assert': 30493,
#  'papers': 40491,
#  'ĠLabrador': 45246,
#  'ĠAVG': 35224,
#  'ĠQuebec': 14778,
#  'illing': 4509,
#  'front': 8534,
#  'Ġpurchased': 8155,
#  'wid': 28029,
#  'ustom': 1824,
#  'Ġcollaps': 10777,
#  'ultz': 22150,
#  'etric': 19482,
#  'ĠVander': 26669,
#  'ĠFarming': 39831,
#  'Ġmarkup': 41485,
#  'chat': 17006,
#  'alking': 18998,
#  'veyard': 21563,
#  'folios': 45242,
#  'ĠHist': 5590,
#  'ĠYankees': 20082,
#  'Ġdelinqu': 32050,
#  'ERAL': 27130,
#  'Ġautobiography': 41795,
#  'naissance': 47090,
#  'Ġresolutions': 21811,
#  'Ġinterchangeable': 43615,
#  'ĠCol': 1623,
#  'Ġignored': 9514,
#  '776': 39509,
#  'Ġdizz': 29527,
#  'itable': 4674,
#  'Comb': 20575,
#  'ĠYou': 921,
#  'wm': 26377,
#  'Sol': 36949,
#  'Ġassess': 4659,
#  'Scient': 23010,
#  'Ġchildish': 39765,
#  'ĠOsiris': 40925,
#  'Ġ392': 48207,
#  'Ġlawyer': 6853,
#  'ĠMad': 4627,
#  'ĠAsh': 7844,
#  'Ġanimations': 22407,
#  'Ġinvolve': 6211,
#  'const': 9979,
#  'ĠGamb': 33330,
#  '});': 22133,
#  'uing': 4250,
#  'Gaming': 45509,
#  'Ġsupports': 6971,
#  'Ġwhisky': 39501,
#  'Ġcamera': 4676,
#  'Ġupbringing': 40678,
#  'ĠDisclosure': 41806,
#  'ĠBerman': 43859,
#  'Ġfascism': 31037,
#  'Public': 15202,
#  'berus': 39192,
#  'ĠTwice': 41217,
#  'Ġcrackdown': 22671,
#  'ĠLevi': 20196,
#  'Fox': 19399,
#  'ĠStockholm': 29679,
#  'ĠInterstate': 30739,
#  'uly': 2062,
#  'ĠNetworks': 27862,
#  'Ġmonstrous': 29100,
#  'ĠPurch': 34459,
#  'ĠKnock': 29061,
#  'Height': 23106,
#  'Ġarriving': 14820,
#  'folder': 43551,
#  'ĠVest': 39034,
#  'Ġoutsourcing': 44333,
#  'Ġsci': 20681,
#  'ĠCub': 7070,
#  'Ġevolve': 18101,
#  'Ġredirect': 18941,
#  'Ġunprepared': 45102,
#  'Ġrestruct': 27596,
#  'Ġstay': 2652,
#  'ist': 396,
#  'Ġremote': 6569,
#  'Ġprosper': 13983,
#  'Ġnewsletter': 13129,
#  'Ġsage': 35021,
#  'ĠattRot': 35207,
#  'Ġhalfway': 19487,
#  'Muslims': 36452,
#  'ohm': 34028,
#  'ĠMos': 5826,
#  'ĠCollins': 14006,
#  'Ġ[]': 17635,
#  'Ġ273': 38549,
#  'Ġrestrooms': 48537,
#  'Ġseparating': 27259,
#  'eon': 23277,
#  'ĠÃĹ': 13958,
#  'Ġoverse': 9125,
#  'istrates': 37909,
#  'section': 5458,
#  'Ġresponsible': 4497,
#  'ĠFranch': 41705,
#  'ĠRhythm': 45757,
#  'ĠRig': 24666,
#  'onymous': 6704,
#  'Ġpoem': 21247,
#  'aced': 2286,
#  'Ġmechanism': 9030,
#  'immers': 36904,
#  'leneck': 43163,
#  'Ġmanager': 4706,
#  'Ġrendering': 14837,
#  'eed': 2308,
#  'Ġface': 1986,
#  'Co': 7222,
#  'Ġbackup': 11559,
#  'uez': 14870,
#  'Crit': 18559,
#  'ACTION': 44710,
#  'đ': 205,
#  'Ġnearest': 16936,
#  'ĠFIRST': 31328,
#  'ĠTacoma': 45132,
#  'FUL': 46476,
#  'Ġmic': 12314,
#  '"><': 22039,
#  'speak': 47350,
#  'ĠPradesh': 25945,
#  'ĠVoices': 40440,
#  ...}

# %% [markdown]
# ## Logit Uploading and Flattening

# %%
first_token_distribution.topk(k=1, largest =True) #Returns the most probable token for that position
# Out:
# torch.return_types.topk(
# values=tensor([0.0654]),
# indices=tensor([62]))

# %%
def topk_tuple( logit_vocab_tensor, largest, tokenizer_fn):
    "Run topk for a token"
    #token_position_dict = list( tokenizer.get_vocab().keys() )
    topk = logit_vocab_tensor.topk( k=1 , largest=largest ) #TODO K number of elements can be extended
    #print(topk.indices)
    return ( tokenizer_fn.decode(topk.indices), topk.values.item() )

def min_max_logits( logit_vocab_sample_tensor, tokenizer_fn ):
    "Compute min_max for a sample"
    max_cases = []
    min_cases = []
    for logit_vocab_tensor in logit_vocab_sample_tensor:
        max_cases.append( topk_tuple( logit_vocab_tensor = logit_vocab_tensor, largest = True, tokenizer_fn = tokenizer_fn) ) #TST Max Logit
        min_cases.append( topk_tuple( logit_vocab_tensor = logit_vocab_tensor, largest = False, tokenizer_fn = tokenizer_fn) ) #TST Min Logit
    return max_cases, min_cases

def actual_logit( 
                 logit_vocab_sample_tensor, 
                 tokenized_prompt, 
                 tokenizer_fn,
                 ):
    "Compute actual logits for a sample"
    actual_logits_prompt = []
    for token_pos, id_token in enumerate( tokenized_prompt[1:] ): #Eliminate the first token prediction since we do not use it
        actual_logits_prompt.append(
            (   tokenizer_fn.decode( int(id_token) ), #retrieving the name of the token with the id
                logit_vocab_sample_tensor[token_pos][int(id_token)].item()      ) #retrieving the logit given the position in the sequence and the position in the vocab
            )
    return actual_logits_prompt

# %%
max_case,min_case = min_max_logits(
    logit_vocab_sample_tensor = [ soft( torch.from_numpy(token) ) for token in out[:4]],
    tokenizer_fn= tokenizer
    ) #Sentence Level minmax (reduced to 3 tokens)
print(max_case)
print(min_case)
# Out:
# [('_', 0.06537198275327682), ('_', 0.17509573698043823), ('test', 0.0670626237988472), ('_', 0.29162847995758057)]
# [('quickShipAvailable', 7.791013792229559e-14), ('channelAvailability', 1.3532363801457213e-16), ('�士', 4.875596454345654e-12), ('quickShipAvailable', 7.463312444530577e-25)]

# %%
sample_id
# Out:
# 0

# %%
out[0]
# Out:
# array([16.705246 , 16.441128 , 15.44639  , ..., -5.198506 , -5.215082 ,
#        -5.2114615], dtype=float32)

# %%
len(out[0])
# Out:
# 51200

# %%
actual_cases = actual_logit(
    logit_vocab_sample_tensor = [ soft( torch.from_numpy(token) ) for token in out] , #Out is a complete sequence
    tokenized_prompt = tf_input_ids[ sample_id ],
    tokenizer_fn = tokenizer
    )

# %%
actual_cases
# Out:
# [(' run', 2.0048053556820378e-05),
#  ('_', 0.17509573698043823),
#  ('python', 0.004026083275675774),
#  ('_', 0.29162847995758057),
#  ('tests', 0.06515749543905258),
#  ('(', 0.2737066149711609),
#  ('test', 0.04412486031651497),
#  ('_', 0.6183211803436279),
#  ('modules', 0.0008266911027021706),
#  (',', 0.33119067549705505),
#  (' parallel', 0.0005007521249353886),
#  ('ism', 0.13258478045463562),
#  (',', 0.19979333877563477),
#  (' with', 0.0006641774671152234),
#  ('_', 0.9744492769241333),
#  ('co', 0.0007279330748133361),
#  ('verage', 0.9097177982330322),
#  ('=', 0.28591224551200867),
#  ('False', 0.5996348261833191),
#  ('):', 0.41072025895118713),
#  ('\n', 0.9089254140853882),
#  (' ', 0.9474048018455505),
#  (' ', 0.9351903796195984),
#  (' ', 0.998816728591919),
#  (' set', 0.0008627278730273247),
#  ('_', 0.6558790802955627),
#  ('title', 0.00029944657580927014),
#  ('_', 0.01964067481458187),
#  ('and', 0.08589049428701401),
#  ('_', 0.9994111061096191),
#  ('block', 0.00022660034301225096),
#  ('("', 0.2782861888408661),
#  ('Running', 0.060263603925704956),
#  (' Py', 0.008667521178722382),
#  ('Sp', 0.0011556477984413505),
#  ('ark', 0.9619680047035217),
#  (' tests', 0.28459271788597107),
#  ('",', 0.021669955924153328),
#  (' "', 0.24181151390075684),
#  ('BL', 2.052249874395784e-05),
#  ('OCK', 0.9331997632980347),
#  ('_', 0.07264410704374313),
#  ('P', 0.014463153667747974),
#  ('Y', 0.9089885354042053),
#  ('SP', 0.8985719084739685),
#  ('ARK', 0.9991421699523926),
#  ('_', 0.7400787472724915),
#  ('UN', 0.000661360623780638),
#  ('IT', 0.3446662425994873),
#  ('_', 0.6420746445655823),
#  ('T', 0.8808584809303284),
#  ('ES', 0.6127126216888428),
#  ('TS', 0.9952226281166077),
#  ('")', 0.7130840420722961),
#  ('\n\n', 0.28542622923851013),
#  (' ', 0.9522556662559509),
#  (' ', 0.9935266971588135),
#  (' ', 0.9998776912689209),
#  (' if', 0.10042956471443176),
#  (' with', 0.18554800748825073),
#  ('_', 0.9999707937240601),
#  ('co', 0.9976403713226318),
#  ('verage', 0.9999958276748657),
#  (':', 0.858589231967926),
#  ('\n', 0.9912543892860413),
#  (' ', 0.99978107213974),
#  (' ', 0.9999973773956299),
#  (' ', 0.9999688863754272),
#  (' ', 0.9998698234558105),
#  (' ', 0.9998862743377686),
#  (' ', 0.8836393356323242),
#  (' ', 0.9993545413017273),
#  (' #', 0.07399798184633255),
#  (' Coverage', 0.0011056548682972789),
#  (' makes', 0.00037581604556180537),
#  (' the', 0.11728589981794357),
#  (' Py', 0.00195695785805583),
#  ('Sp', 0.8735028505325317),
#  ('ark', 0.999891996383667),
#  (' tests', 0.18474188446998596),
#  (' fl', 0.00034670677268877625),
#  ('aky', 0.6133647561073303),
#  (' due', 0.0033253105357289314),
#  (' to', 0.9930904507637024),
#  (' heavy', 0.00014040316455066204),
#  (' parallel', 0.03035769611597061),
#  ('ism', 0.5695173740386963),
#  ('.', 0.2903457581996918),
#  ('\n', 0.8590421080589294),
#  (' ', 0.9995425939559937),
#  (' ', 0.9999985694885254),
#  (' ', 0.9999507665634155),
#  (' ', 0.9994996786117554),
#  (' ', 0.9999864101409912),
#  (' ', 0.9997802376747131),
#  (' ', 0.9999669790267944),
#  (' #', 0.2924216091632843),
#  (' When', 0.007215016055852175),
#  (' we', 0.10297279804944992),
#  (' run', 0.2629421055316925),
#  (' Py', 0.022481415420770645),
#  ('Sp', 0.9023563861846924),
#  ('ark', 0.9998972415924072),
#  (' tests', 0.3306640684604645),
#  (' with', 0.22891248762607574),
#  (' coverage', 0.16593708097934723),
#  (',', 0.2859635055065155),
#  (' it', 0.0549396388232708),
#  (' uses', 0.008138145320117474),
#  (' 4', 0.005008147098124027),
#  (' for', 0.00039848650339990854),
#  (' now', 0.0014682762557640672),
#  (' as', 0.007111629471182823),
#  ('\n', 0.2368345558643341),
#  (' ', 0.999843955039978),
#  (' ', 0.999998927116394),
#  (' ', 0.9999426603317261),
#  (' ', 0.9999837875366211),
#  (' ', 0.9999886751174927),
#  (' ', 0.9999880790710449),
#  (' ', 0.9999815225601196),
#  (' #', 0.999725878238678),
#  (' workaround', 0.00021197866590227932),
#  ('.', 0.10343965888023376),
#  ('\n', 0.4580822288990021),
#  (' ', 0.9995124340057373),
#  (' ', 0.9999990463256836),
#  (' ', 0.9999727010726929),
#  (' ', 0.999049961566925),
#  (' ', 0.9999901056289673),
#  (' ', 0.9999350309371948),
#  (' ', 0.9999847412109375),
#  (' parallel', 0.013603131286799908),
#  ('ism', 0.9790756702423096),
#  (' =', 0.7093333601951599),
#  (' 4', 0.5207175612449646),
#  ('\n', 0.6668257713317871),
#  (' ', 0.989093542098999),
#  (' ', 0.9999878406524658),
#  (' ', 0.9999200105667114),
#  (' ', 0.5392265915870667),
#  (' ', 0.9976493716239929),
#  (' ', 0.9985100626945496),
#  (' ', 0.9999330043792725),
#  (' script', 0.0007418227032758296),
#  (' =', 0.46161243319511414),
#  (' "', 0.22250744700431824),
#  ('run', 0.029614310711622238),
#  ('-', 0.05179910734295845),
#  ('tests', 0.20214863121509552),
#  ('-', 0.2338748574256897),
#  ('with', 0.28844767808914185),
#  ('-', 0.9924101829528809),
#  ('co', 0.9867866039276123),
#  ('verage', 0.9997796416282654),
#  ('"', 0.15401937067508698),
#  ('\n', 0.7984771728515625),
#  (' ', 0.9985288381576538),
#  (' ', 0.9999911785125732),
#  (' ', 0.9999570846557617),
#  (' else', 0.5774872303009033),
#  (':', 0.9997805953025818),
#  ('\n', 0.9923058152198792),
#  (' ', 0.9999468326568604),
#  (' ', 0.9999997615814209),
#  (' ', 0.9999996423721313),
#  (' ', 0.9999397993087769),
#  (' ', 0.9999910593032837),
#  (' ', 0.9997574687004089),
#  (' ', 0.999921441078186),
#  (' script', 0.12906210124492645),
#  (' =', 0.9894986152648926),
#  (' "', 0.7892864346504211),
#  ('run', 0.894712507724762),
#  ('-', 0.9016845226287842),
#  ('tests', 0.9804990887641907),
#  ('"', 0.2499247044324875),
#  ('\n', 0.4847434163093567),
#  (' ', 0.9933972358703613),
#  (' ', 0.9999344348907471),
#  (' ', 0.9998723268508911),
#  (' command', 0.0025208727456629276),
#  (' =', 0.9195683598518372),
#  (' [', 0.11720060557126999),
#  ('os', 0.002515561645850539),
#  ('.', 0.9938929080963135),
#  ('path', 0.7518414258956909),
#  ('.', 0.9962900876998901),
#  ('join', 0.8156958818435669),
#  ('(', 0.8439310789108276),
#  ('SP', 0.002722002798691392),
#  ('ARK', 0.9951552152633667),
#  ('_', 0.9695430994033813),
#  ('HOME', 0.16048742830753326),
#  (',', 0.7792299389839172),
#  (' "', 0.4962667226791382),
#  ('python', 0.1755923628807068),
#  ('",', 0.22576572000980377),
#  (' script', 0.12167996168136597),
#  (')]', 0.3188196122646332),
#  ('\n', 0.5772005319595337),
#  (' ', 0.9971639513969421),
#  (' ', 0.9999890327453613),
#  (' ', 0.9999608993530273),
#  (' if', 0.16246181726455688),
#  (' test', 0.06112125143408775),
#  ('_', 0.9702765345573425),
#  ('modules', 0.3370877504348755),
#  ('!=', 0.029667580500245094),
#  (' [', 0.07397923618555069),
#  ('modules', 2.9033208193141036e-05),
#  ('.', 0.15042079985141754),
#  ('root', 0.0004993991460651159),
#  (']:', 0.1793089359998703),
#  ('\n', 0.9936773180961609),
#  (' ', 0.9999672174453735),
#  (' ', 0.9999998807907104),
#  (' ', 0.999994158744812),
#  (' ', 0.9999376535415649),
#  (' ', 0.9999867677688599),
#  (' ', 0.9992687106132507),
#  (' ', 0.9998188614845276),
#  (' command', 0.39161181449890137),
#  ('.', 0.22625380754470825),
#  ('append', 0.6156489849090576),
#  ('("', 0.5653290748596191),
#  ('--', 0.4157159924507141),
#  ('modules', 0.03479278087615967),
#  ('=', 0.3471037745475769),
#  ('%', 0.39564695954322815),
#  ('s', 0.9652942419052124),
#  ('"', 0.9487451314926147),
#  (' %', 0.9853686690330505),
#  (" '", 0.0006043726461939514),
#  (",'", 0.008019656874239445),
#  ('.', 0.9152953028678894),
#  ('join', 0.9966513514518738),
#  ('(', 0.7919304370880127),
#  ('m', 0.0021477355621755123),
#  ('.', 0.3875642418861389),
#  ('name', 0.010823752731084824),
#  (' for', 0.7696003913879395),
#  (' m', 0.995173990726471),
#  (' in', 0.9996045231819153),
#  (' test', 0.9182191491127014),
#  ('_', 0.9997128844261169),
#  ('modules', 0.9982708692550659),
#  ('))', 0.9400256872177124),
#  ('\n', 0.7363944053649902),
#  (' ', 0.9952431321144104),
#  (' ', 0.9999921321868896),
#  (' ', 0.9999362230300903),
#  (' command', 0.1469426453113556),
#  ('.', 0.7374089360237122),
#  ('append', 0.6862006187438965),
#  ('("', 0.7521504759788513),
#  ('--', 0.9279069304466248),
#  ('par', 0.1999601423740387),
#  ('allel', 0.9987395405769348),
#  ('ism', 0.9540461301803589),
#  ('=', 0.9713177680969238),
#  ('%', 0.9462725520133972),
#  ('i', 0.02358383499085903),
#  ('"', 0.9834680557250977),
#  (' %', 0.9969246983528137),
#  (' parallel', 0.876335084438324),
#  ('ism', 0.999750554561615),
#  (')', 0.9871156811714172),
#  ('\n', 0.8230745792388916),
#  (' ', 0.99814772605896),
#  (' ', 0.999992847442627),
#  (' ', 0.9999697208404541),
#  (' run', 0.014404785819351673),
#  ('_', 0.9419546127319336),
#  ('cmd', 0.0037632330786436796),
#  ('(', 0.18918177485466003),
#  ('command', 0.8185660243034363),
#  (')', 0.6913031935691833),
#  ('\n\n', 0.5233994722366333)]

# %% [markdown]
# # Logits Execution

# %%
len(filtered_prompts_ids)
#params['numpy_files_logits_path'] +'/' + f'logits_tensor[{sample_id}]_batch[{sample_id}]_model[{CODEMODEL}].npy'
# Out:
# 50971

# %%
def batching_logits( size = len(filtered_prompts_ids) ):

    max_logit_token_prompt = []
    min_logit_token_prompt = []
    actual_logit_token_prompt = []
    
    soft = torch.nn.Softmax( dim = 0 )                          #Flattening normalization
    
    for file in range( size ):
        out = np.load(params['numpy_files_logits_path']+'/'+ f'logits_tensor[{file}]_batch[{file}]_model[{CODEMODEL}].npy')
        next_tokens_distribution = [ soft( torch.from_numpy(token) ) for token in out]  #Flattening normalization
        
        max_cases,min_cases = min_max_logits(
            logit_vocab_sample_tensor = next_tokens_distribution,
            tokenizer_fn= tokenizer
            )

        actual_cases = actual_logit(
            logit_vocab_sample_tensor = next_tokens_distribution,
            #sample_position = file,
            tokenized_prompt = tf_input_ids[ file ],
            tokenizer_fn = tokenizer
            )
        
        max_logit_token_prompt.append( max_cases )
        min_logit_token_prompt.append( min_cases )
        actual_logit_token_prompt.append( actual_cases )
        
        logging.info(file)
    return max_logit_token_prompt,min_logit_token_prompt,actual_logit_token_prompt

# %%
#max_logit_token_prompt,min_logit_token_prompt,actual_logit_token_prompt = batching_logits( size = 2 )
max_logit_token_prompt, min_logit_token_prompt, actual_logit_token_prompt = batching_logits(
    #size = 2
    ) #<---WARNING TIME Consuming

# %%
dataframe_to_save = data_pd[data_pd['m_name']==params['codemodel']].copy()

# %%
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 458739   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c10  \
#
#                                                      code ast_errors
# 458739  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 458739             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 458739           120          154

# %%
dataframe_to_save['max_prob'] = max_logit_token_prompt
dataframe_to_save['min_prob'] = min_logit_token_prompt
dataframe_to_save['actual_prob'] = actual_logit_token_prompt

# %%
dataframe_to_save.head()
# Out:
#         size                                                ids m_name
# 458739   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c10  \
# 458740   122  [4299, 651, 62, 12286, 62, 29412, 62, 18558, 3...    c10
# 458741   167  [4299, 1332, 62, 293, 459, 7, 944, 2599, 198, ...    c10
# 458742   352  [4299, 1332, 62, 48369, 7, 944, 2599, 198, 502...    c10
# 458743   468  [4299, 1332, 62, 2502, 10724, 7, 944, 2599, 19...    c10
#
#                                                      code ast_errors
# 458739  def run_python_tests(test_modules, parallelism...         []  \
# 458740  def get_default_python_executables():\n    pyt...         []
# 458741  def test_least(self):\n        df = self.spark...         []
# 458742  def test_slice(self):\n        df = self.spark...         []
# 458743  def test_overlay(self):\n        from pyspark....         []
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 458739             0          13              67           7    15  \
# 458740             0          12              34           5    10
# 458741             0          21              34           1    12
# 458742             0          21              69           1    34
# 458743             0          21             117           2    39
#
#         token_counts  n_ast_nodes
# 458739           120          154  \
# 458740            62          109
# 458741           141          230
# 458742           293          453
# 458743           301          497
#
#                                                  max_prob
# 458739  [( __, 0.13518139719963074), ((, 0.50364696979...  \
# 458740  [( __, 0.13518139719963074), (_, 0.78407043218...
# 458741  [( __, 0.13518203794956207), (_, 0.85579311847...
# 458742  [( __, 0.13518159091472626), (_, 0.85579228401...
# 458743  [( __, 0.13518092036247253), (_, 0.85579180717...
#
#                                                  min_prob
# 458739  [( detainees, 1.8827131693932575e-12), (ヘラ, 2....  \
# 458740  [( detainees, 1.8827131693932575e-12), ( Schum...
# 458741  [( detainees, 1.8827005926480567e-12), ( Schum...
# 458742  [( detainees, 1.882705146297181e-12), ( Schume...
# 458743  [( detainees, 1.8827101336271745e-12), ( Schum...
#
#                                               actual_prob
# 458739  [( run, 0.0024231544230133295), (_, 0.20523256...
# 458740  [( get, 0.061549633741378784), (_, 0.784070432...
# 458741  [( test, 0.10771691799163818), (_, 0.855793118...
# 458742  [( test, 0.10771779716014862), (_, 0.855792284...
# 458743  [( test, 0.10771705955266953), (_, 0.855791807...

# %%
dataframe_to_save.shape
# Out:
# (50971, 15)

# %%
params['outputs']
# Out:
# '../data/ds_raw_logits/out_astevalverticalfiltered_c10.csv'

# %%
## Saving CheckPoint
dataframe_to_save.to_csv( params['outputs']  )

# %%
dataframe_to_save = pd.read_csv( 
                      params['outputs'] , 
                      index_col=0
            )

# %%
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 458739   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c10  \
#
#                                                      code ast_errors
# 458739  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 458739             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 458739           120          154  \
#
#                                                  max_prob
# 458739  [(' __', 0.13518139719963074), ('(', 0.5036469...  \
#
#                                                  min_prob
# 458739  [(' detainees', 1.8827131693932575e-12), ('ヘラ'...  \
#
#                                               actual_prob
# 458739  [(' run', 0.0024231544230133295), ('_', 0.2052...

# %%
dataframe_to_save.shape
# Out:
# (50971, 15)

# %% [markdown]
# ## Loss Retrieval

# %%
def batching_loss( size = dataframe_to_save.shape[0] ):
    output_loss = []
    for current_batch in range(size):
        out = np.load(params['numpy_files_logits_path']+'/'+f'loss_batch[{current_batch}]_model[{CODEMODEL}].npy') 
        output_loss.append( out.item() ) #.item() for numpy library
        logging.info(current_batch)
    return output_loss

# %%
output_loss = batching_loss() #[WAENING!] Takes Time

# %%
output_loss
# Out:
# [1.5280216932296753,
#  1.2751010656356812,
#  0.9239424467086792,
#  0.7154776453971863,
#  0.9453902244567871,
#  1.0772773027420044,
#  1.1250700950622559,
#  1.26653254032135,
#  1.1923243999481201,
#  1.7146557569503784,
#  0.7318271994590759,
#  1.8046993017196655,
#  1.8154938220977783,
#  1.4895942211151123,
#  1.0154716968536377,
#  2.042271614074707,
#  1.8382986783981323,
#  1.878869891166687,
#  1.3112800121307373,
#  1.8876640796661377,
#  1.825269103050232,
#  1.2773587703704834,
#  1.8080252408981323,
#  1.9672260284423828,
#  1.8743460178375244,
#  1.244260311126709,
#  1.2098442316055298,
#  1.6218855381011963,
#  1.2233152389526367,
#  1.9748269319534302,
#  1.0102487802505493,
#  1.5765427350997925,
#  0.5849907398223877,
#  0.8038361072540283,
#  1.83796226978302,
#  1.807596206665039,
#  0.8425083160400391,
#  1.0184342861175537,
#  0.969563364982605,
#  0.5329126715660095,
#  1.4955028295516968,
#  1.2476619482040405,
#  0.9788509011268616,
#  0.7473312616348267,
#  0.8349431753158569,
#  1.6885948181152344,
#  0.524868369102478,
#  0.8423246741294861,
#  1.4833266735076904,
#  0.8783121109008789,
#  1.5069756507873535,
#  1.0265332460403442,
#  0.9102308750152588,
#  0.8774529695510864,
#  1.4639060497283936,
#  1.7526415586471558,
#  1.911528468132019,
#  1.1341805458068848,
#  1.6451212167739868,
#  0.7847726345062256,
#  0.5243385434150696,
#  0.6352845430374146,
#  0.7355011701583862,
#  0.781952440738678,
#  0.5763269066810608,
#  0.7178235650062561,
#  1.4816062450408936,
#  0.991611659526825,
#  0.4818018972873688,
#  0.9871989488601685,
#  1.3767095804214478,
#  0.7786068916320801,
#  0.7312856912612915,
#  ...]

# %%
dataframe_to_save['loss'] = output_loss
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 458739   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c10  \
#
#                                                      code ast_errors
# 458739  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 458739             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 458739           120          154  \
#
#                                                  max_prob
# 458739  [(' __', 0.13518139719963074), ('(', 0.5036469...  \
#
#                                                  min_prob
# 458739  [(' detainees', 1.8827131693932575e-12), ('ヘラ'...  \
#
#                                               actual_prob      loss
# 458739  [(' run', 0.0024231544230133295), ('_', 0.2052...  1.528022

# %%
## Saving CheckPoint 2
dataframe_to_save.to_csv( params['outputs']  )

# %%
dataframe_to_save = pd.read_csv( 
                      params['outputs'] , 
                      index_col=0
            )

# %%
dataframe_to_save.head(1)
# Out:
#         size                                                ids m_name
# 458739   225  [4299, 1057, 62, 29412, 62, 41989, 7, 9288, 62...    c10  \
#
#                                                      code ast_errors
# 458739  def run_python_tests(test_modules, parallelism...         []  \
#
#         n_ast_errors  ast_levels  n_whitespaces_  complexity  nloc
# 458739             0          13              67           7    15  \
#
#         token_counts  n_ast_nodes
# 458739           120          154  \
#
#                                                  max_prob
# 458739  [(' __', 0.13518139719963074), ('(', 0.5036469...  \
#
#                                                  min_prob
# 458739  [(' detainees', 1.8827131693932575e-12), ('ヘラ'...  \
#
#                                               actual_prob      loss
# 458739  [(' run', 0.0024231544230133295), ('_', 0.2052...  1.528022

# %% [markdown]
# # Combining all datasets (last step)
