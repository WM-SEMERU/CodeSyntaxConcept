# %%
import pandas as pd
import os
import time
import numpy as np
import torch

# %%
import seaborn as sns
from scipy import stats
from statistics import NormalDist
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
#physical_devices = tf.config.list_physical_devices('CPU')
physical_devices = tf.config.list_physical_devices('GPU')
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
#device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Confirmatory Analysis
# >
# > Conformatory Experiments of Logits or Next Token Predictions @danaderp
# >

# %%
def params(): 
    return {
            'testbed' : '/workspaces/CausalCodeCapability/data/big_table/testbed_base_EleutherAI-gpt-neo-1.3B.csv',
            'hf_model' : 'EleutherAI/gpt-neo-1.3B' 
}

# %%
#pwd
parameters = params()
parameters['testbed']
# Out:
# '/workspaces/CausalCodeCapability/data/big_table/testbed_base_EleutherAI-gpt-neo-1.3B.csv'

# %% [markdown]
# # Data Upload

# %%
data_pd = pd.read_csv( 
                      parameters['testbed'] , 
                      index_col=0
            )

# %%
data_pd.head(1)
# Out:
#                                    whole_func_string  \
# 0  def gen_filter(name, op, value, is_or=False):\...
#
#                                         ast_concepts  \
# 0  [('def', 'def', 'function_definition'), ('gen_...
#
#                             model_tokenizer_concepts  \
# 0  [(4299, 'def', 'function_definition'), (2429, ...
#
#                                      model_input_ids  model_total_input_ids  \
# 0  [4299, 2429, 62, 24455, 7, 3672, 11, 1034, 11,...                    123
#
#                                        max_prob_case  \
# 0  [('module', tensor([0.3343], grad_fn=<TopkBack...
#
#                                        min_prob_case  \
# 0  [('ĠPremiership', tensor([8.5841e-14], grad_fn...
#
#                                     actual_prob_case
# 0  [('Ġgen', tensor(0.0002, grad_fn=<SelectBackwa...

# %%
data_pd.describe()
# Out:
#        model_total_input_ids
# count             100.000000
# mean              355.800000
# std               338.974776
# min                67.000000
# 25%               145.750000
# 50%               241.500000
# 75%               420.250000
# max              1675.000000

# %% [markdown]
# ## Statistical Analysis

# %%
type(list(data_pd.actual_prob_case.values[0]))
# Out:
# list

# %%
list(data_pd.actual_prob_case.values[0])
# Out:
# ['[',
#  '(',
#  "'",
#  'Ġ',
#  'g',
#  'e',
#  'n',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '0',
#  '0',
#  '2',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  '_',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '6',
#  '2',
#  '3',
#  '5',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'f',
#  'i',
#  'l',
#  't',
#  'e',
#  'r',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '0',
#  '0',
#  '9',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  '(',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '3',
#  '0',
#  '9',
#  '5',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'n',
#  'a',
#  'm',
#  'e',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '2',
#  '7',
#  '4',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '6',
#  '8',
#  '7',
#  '0',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ġ',
#  'o',
#  'p',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '0',
#  '2',
#  '2',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '5',
#  '9',
#  '3',
#  '6',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ġ',
#  'v',
#  'a',
#  'l',
#  'u',
#  'e',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '1',
#  '4',
#  '0',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  ',',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '4',
#  '4',
#  '8',
#  '3',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ġ',
#  'i',
#  's',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '1',
#  '0',
#  '8',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  '_',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '7',
#  '1',
#  '7',
#  '1',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'o',
#  'r',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '0',
#  '0',
#  '9',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  '=',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '0',
#  '4',
#  '7',
#  '4',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'F',
#  'a',
#  'l',
#  's',
#  'e',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '3',
#  '7',
#  '3',
#  '1',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  ')',
#  ':',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '6',
#  '1',
#  '3',
#  '9',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ċ',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '9',
#  '4',
#  '5',
#  '4',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ġ',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '9',
#  '5',
#  '8',
#  '8',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ġ',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '9',
#  '5',
#  '8',
#  '2',
#  ',',
#  ' ',
#  'g',
#  'r',
#  'a',
#  'd',
#  '_',
#  'f',
#  'n',
#  '=',
#  '<',
#  'S',
#  'e',
#  'l',
#  'e',
#  'c',
#  't',
#  'B',
#  'a',
#  'c',
#  'k',
#  'w',
#  'a',
#  'r',
#  'd',
#  '0',
#  '>',
#  ')',
#  ')',
#  ',',
#  ' ',
#  '(',
#  "'",
#  'Ġ',
#  "'",
#  ',',
#  ' ',
#  't',
#  'e',
#  'n',
#  's',
#  'o',
#  'r',
#  '(',
#  '0',
#  '.',
#  '9',
#  '9',
#  '8',
#  '3',
#  ',',
#  ' ',
#  'g',
#  'r',
#  ...]

# %%
data_pd.actual_prob_case.values[0][0]
# Out:
# '['

# %%
child_logits = {}
parent_logits = {}

for i,sequence in enumerate( data_pd.actual_prob_case.values ):
    #print(sequence)
    tok_tuple_list = eval( data_pd.model_tokenizer_concepts.values[i] )
    for j,label_tuple in enumerate( tok_tuple_list[1:] ): #Dropping first token
        if label_tuple[1] in set( child_logits.keys() ):
            #print('in',label_tuple,sequence[j])
            child_logits[label_tuple[1]].append( sequence[j][1] )
        else:
            #print('out',label_tuple,sequence[j])
            child_logits[label_tuple[1]] = []
            child_logits[label_tuple[1]].append( sequence[j][1] )
            
        ### PARENT
        if label_tuple[1] in set( parent_logits.keys() ):
            #print('in',label_tuple,sequence[j])
            parent_logits[label_tuple[2]].append( sequence[j][1] )
        else:
            #print('out',label_tuple,sequence[j])
            parent_logits[label_tuple[2]] = []
            parent_logits[label_tuple[2]].append( sequence[j][1] )

# %%
parent_logits['function_definition']
# Out:
# [tensor(4.9403e-07, grad_fn=<SelectBackward0>)]

# %%
parent_logits.keys()
# Out:
# dict_keys(['function_definition', 'parameters', 'default_parameter', 'ERROR', 'expression_statement', 'if_statement', 'comparison_operator', 'raise_statement', 'call', 'argument_list', 'attribute', 'assignment', 'binary_operator', 'return_statement', 'global_statement', 'block', 'try_statement', 'lambda', 'lambda_parameters', 'not_operator', 'boolean_operator', 'dictionary', 'subscript', 'elif_clause', 'pass_statement', 'finally_clause', 'for_statement', 'keyword_argument', 'pair', 'dictionary_comprehension', 'for_in_clause', 'pattern_list', 'if_clause', 'list_splat_pattern', 'augmented_assignment', 'parenthesized_expression', 'tuple', 'else_clause', 'list', 'slice', 'list_comprehension', 'except_clause', 'unary_operator', 'yield', 'import_from_statement', 'dotted_name', 'dictionary_splat_pattern', 'tuple_pattern', 'list_splat', 'dictionary_splat', 'with_statement', 'as_pattern', 'as_pattern_target', 'conditional_expression', 'concatenated_string', 'generator_expression', 'expression_list', 'typed_default_parameter', 'type', 'while_statement', 'import_statement', 'aliased_import', 'class_definition', 'continue_statement', 'set_comprehension', 'assert_statement'])

# %%
[ (elem,np.mean( [np_elem.detach().numpy() for np_elem in parent_logits[elem] ] )) for elem in parent_logits.keys()]
# Out:
# [('function_definition', 4.9402684e-07),
#  ('parameters', 0.45352417),
#  ('default_parameter', 0.49697953),
#  ('ERROR', 0.96551734),
#  ('expression_statement', 0.96332645),
#  ('if_statement', 0.35947895),
#  ('comparison_operator', 0.49701786),
#  ('raise_statement', 0.5022117),
#  ('call', 0.09397892),
#  ('argument_list', 0.9793428),
#  ('attribute', 0.55561125),
#  ('assignment', 0.9822823),
#  ('binary_operator', 0.93023354),
#  ('return_statement', 0.062402897),
#  ('global_statement', 0.12389463),
#  ('block', 0.04229165),
#  ('try_statement', 0.9985191),
#  ('lambda', 0.8635597),
#  ('lambda_parameters', 0.9691714),
#  ('not_operator', 0.99964225),
#  ('boolean_operator', 0.29123697),
#  ('dictionary', 0.7888982),
#  ('subscript', 0.95072013),
#  ('elif_clause', 0.5141071),
#  ('pass_statement', 0.15036604),
#  ('finally_clause', 0.99995124),
#  ('for_statement', 0.9405241),
#  ('keyword_argument', 0.9812852),
#  ('pair', 0.874644),
#  ('dictionary_comprehension', 0.6176669),
#  ('for_in_clause', 0.9983662),
#  ('pattern_list', 0.020958917),
#  ('if_clause', 0.92810094),
#  ('list_splat_pattern', 0.958132),
#  ('augmented_assignment', 0.88532346),
#  ('parenthesized_expression', 0.00022045395),
#  ('tuple', 0.9627924),
#  ('else_clause', 0.99981195),
#  ('list', 0.8863828),
#  ('slice', 0.7789184),
#  ('list_comprehension', 0.34050256),
#  ('except_clause', 0.9983449),
#  ('unary_operator', 0.5311829),
#  ('yield', 0.18598384),
#  ('import_from_statement', 0.63083607),
#  ('dotted_name', 0.0034150432),
#  ('dictionary_splat_pattern', 0.97653913),
#  ('tuple_pattern', 0.98452234),
#  ('list_splat', 0.99961394),
#  ('dictionary_splat', 0.999933),
#  ('with_statement', 0.9959376),
#  ('as_pattern', 0.7118545),
#  ('as_pattern_target', 0.53674644),
#  ('conditional_expression', 0.664256),
#  ('concatenated_string', 0.010697478),
#  ('generator_expression', 0.9641482),
#  ('expression_list', 0.99951947),
#  ('typed_default_parameter', 0.06675875),
#  ('type', 0.33685863),
#  ('while_statement', 0.53104115),
#  ('import_statement', 0.25598848),
#  ('aliased_import', 6.516675e-05),
#  ('class_definition', 0.995736),
#  ('continue_statement', 0.2695879),
#  ('set_comprehension', 0.8780694),
#  ('assert_statement', 0.0035690605)]

# %%
[ (elem,np.mean( [np_elem.detach().numpy() for np_elem in child_logits[elem] ] )) for elem in child_logits.keys()]
# Out:
# [('identifier', 0.5504931),
#  ('(', 0.6492624),
#  (',', 0.6478024),
#  ('=', 0.73198533),
#  ('false', 0.42686236),
#  (')', 0.62872636),
#  ('ERROR', 0.96551734),
#  ('string', 0.621419),
#  ('if', 0.2772697),
#  ('not', 0.22935918),
#  ('in', 0.82017523),
#  (':', 0.8133965),
#  ('raise', 0.5658),
#  ('+', 0.41851243),
#  ('return', 0.41479897),
#  ('global', 0.06456195),
#  ('.', 0.7721778),
#  ('float', 0.42957017),
#  ('*', 0.2961083),
#  ('none', 0.673475),
#  ('comment', 0.31376114),
#  ('try', 0.027253374),
#  ('true', 0.62086904),
#  ('lambda', 0.58812237),
#  ('or', 0.110503495),
#  ('}', 0.5254813),
#  ('[', 0.5780259),
#  ('elif', 0.55802226),
#  ('pass', 0.17900899),
#  ('finally', 0.07824747),
#  ('for', 0.45117524),
#  ('integer', 0.48820278),
#  ('-', 0.32622436),
#  ('{', 0.17415868),
#  ('%', 0.84188503),
#  (']', 0.6644342),
#  ('|=', 0.5004129),
#  ('&', 0.6276737),
#  ('is', 0.6191611),
#  ('else', 0.5030283),
#  ('<', 0.29024956),
#  ('and', 0.19557978),
#  ('>', 0.20081393),
#  ('except', 0.73677486),
#  ('==', 0.43423653),
#  ('def', 0.15680842),
#  ('yield', 0.18598384),
#  ('from', 0.104144454),
#  ('import', 0.3187116),
#  ('**', 0.48581296),
#  ('!=', 0.4089474),
#  ('//', 0.24634473),
#  ('/', 0.39543423),
#  ('-=', 8.3376e-05),
#  ('<=', 0.26362365),
#  ('with', 0.119025856),
#  ('as', 0.8170753),
#  ('*=', 0.51565903),
#  ('|', 0.30561292),
#  ('+=', 0.64744866),
#  ('<<', 0.9282999),
#  ('->', 0.96679837),
#  ('while', 0.6050708),
#  ('class', 0.041054636),
#  ('continue', 0.2689158),
#  ('assert', 0.0035690605)]

# %% [markdown]
# ## Bootstrapping

# %%
#export
def bootstrapping( np_data, np_func, size ):
    """Create a bootstrap sample given data and a function
    For instance, a bootstrap sample of means, or mediands. 
    The bootstrap replicates are a long as the original size
    we can choose any observation more than once (resampling with replacement:np.random.choice)
    """
    
    #Cleaning NaNs
    #np_data_clean = np_data[ np.logical_not( np.isnan(np_data) ) ] 
    
    #The size of the bootstrap replicate is as big as size
    #Creating the boostrap replicates as long as the orignal data size
    #This strategy might work as imputation 
    bootstrap_repl = [ np_func( np.random.choice( np_data, size=len(np_data) ) ) for i in range( size ) ]
    
    #logging.info("Covariate: " + cov) #Empirical Mean
    #logging.info("Empirical Mean: " + str(np.mean(np_data_clean))) #Empirical Mean
    #logging.info("Bootstrapped Mean: " + str( np.mean(bootstrap_repl) ) ) #Bootstrapped Mean
    
    return np.array( bootstrap_repl )

# %%
def dictionary_boots( dict_concepts, np_func = np.mean, size=500):
    np_dettached = lambda np_ccp: np.array([ np_elem.detach().numpy() for np_elem in np_ccp ]).flatten()
    return {ccp: bootstrapping(np_dettached( dict_concepts[ccp] ), np_func, size) for ccp in dict_concepts.keys()}

# %%
dict_test = dictionary_boots(
    dict_concepts = parent_logits
)

# %%
pd_test_bs = pd.DataFrame.from_dict( dict_test )

# %%
pd_test_bs.head()
# Out:
#    function_definition  parameters  default_parameter     ERROR  \
# 0         4.940268e-07    0.453524            0.49698  0.963887
# 1         4.940268e-07    0.453524            0.49698  0.964926
# 2         4.940268e-07    0.453524            0.49698  0.965100
# 3         4.940268e-07    0.453524            0.49698  0.966258
# 4         4.940268e-07    0.453524            0.49698  0.965908
#
#    expression_statement  if_statement  comparison_operator  raise_statement  \
# 0              0.963326      0.359479             0.497018         0.502212
# 1              0.963326      0.359479             0.497018         0.502212
# 2              0.963326      0.359479             0.497018         0.502212
# 3              0.963326      0.359479             0.497018         0.502212
# 4              0.963326      0.359479             0.497018         0.502212
#
#        call  argument_list  ...  expression_list  typed_default_parameter  \
# 0  0.093979       0.979343  ...         0.999519                 0.066759
# 1  0.093979       0.979343  ...         0.999519                 0.066759
# 2  0.093979       0.979343  ...         0.999519                 0.066759
# 3  0.093979       0.979343  ...         0.999519                 0.066759
# 4  0.093979       0.979343  ...         0.999519                 0.066759
#
#        type  while_statement  import_statement  aliased_import  \
# 0  0.336859         0.531041          0.255988        0.000065
# 1  0.336859         0.531041          0.255988        0.000065
# 2  0.336859         0.531041          0.255988        0.000065
# 3  0.336859         0.531041          0.255988        0.000065
# 4  0.336859         0.531041          0.255988        0.000065
#
#    class_definition  continue_statement  set_comprehension  assert_statement
# 0          0.995736            0.269588           0.878069          0.003569
# 1          0.995736            0.269588           0.878069          0.003569
# 2          0.995736            0.269588           0.878069          0.003569
# 3          0.995736            0.269588           0.878069          0.003569
# 4          0.995736            0.269588           0.878069          0.003569
#
# [5 rows x 66 columns]

# %%
pd_test_bs.describe()
# Out:
#        function_definition  parameters  default_parameter       ERROR  \
# count         5.000000e+02  500.000000          500.00000  500.000000
# mean          4.940268e-07    0.453524            0.49698    0.965559
# std           0.000000e+00    0.000000            0.00000    0.001098
# min           4.940268e-07    0.453524            0.49698    0.961945
# 25%           4.940268e-07    0.453524            0.49698    0.964908
# 50%           4.940268e-07    0.453524            0.49698    0.965573
# 75%           4.940268e-07    0.453524            0.49698    0.966248
# max           4.940268e-07    0.453524            0.49698    0.969271
#
#        expression_statement  if_statement  comparison_operator  \
# count            500.000000    500.000000           500.000000
# mean               0.963326      0.359479             0.497018
# std                0.000000      0.000000             0.000000
# min                0.963326      0.359479             0.497018
# 25%                0.963326      0.359479             0.497018
# 50%                0.963326      0.359479             0.497018
# 75%                0.963326      0.359479             0.497018
# max                0.963326      0.359479             0.497018
#
#        raise_statement        call  argument_list  ...  expression_list  \
# count       500.000000  500.000000     500.000000  ...       500.000000
# mean          0.502212    0.093979       0.979343  ...         0.999519
# std           0.000000    0.000000       0.000000  ...         0.000000
# min           0.502212    0.093979       0.979343  ...         0.999519
# 25%           0.502212    0.093979       0.979343  ...         0.999519
# 50%           0.502212    0.093979       0.979343  ...         0.999519
# 75%           0.502212    0.093979       0.979343  ...         0.999519
# max           0.502212    0.093979       0.979343  ...         0.999519
#
#        typed_default_parameter        type  while_statement  import_statement  \
# count               500.000000  500.000000       500.000000        500.000000
# mean                  0.066759    0.336859         0.531041          0.255989
# std                   0.000000    0.000000         0.000000          0.000000
# min                   0.066759    0.336859         0.531041          0.255988
# 25%                   0.066759    0.336859         0.531041          0.255988
# 50%                   0.066759    0.336859         0.531041          0.255988
# 75%                   0.066759    0.336859         0.531041          0.255988
# max                   0.066759    0.336859         0.531041          0.255988
#
#        aliased_import  class_definition  continue_statement  \
# count      500.000000        500.000000          500.000000
# mean         0.000065          0.995736            0.269588
# std          0.000000          0.000000            0.000000
# min          0.000065          0.995736            0.269588
# 25%          0.000065          0.995736            0.269588
# 50%          0.000065          0.995736            0.269588
# 75%          0.000065          0.995736            0.269588
# max          0.000065          0.995736            0.269588
#
#        set_comprehension  assert_statement
# count         500.000000        500.000000
# mean            0.878069          0.003569
# std             0.000000          0.000000
# min             0.878069          0.003569
# 25%             0.878069          0.003569
# 50%             0.878069          0.003569
# 75%             0.878069          0.003569
# max             0.878069          0.003569
#
# [8 rows x 66 columns]

# %%
sns.set_theme(style="darkgrid")
boxplot = pd_test_bs.boxplot()
plt.show()

# %%
sns.set_theme(style="darkgrid")
#ax = pd_test_bs.plot.kde()
pd_test_bs.plot.hist(
    bins=60, 
    alpha=0.4,
    figsize=(7,5)
)
plt.show()

# %%
assert len(dict_test['function_definition']) == len(dict_test['argument_list'])

# %%
#export
#We use normal distribution assuming the sample size is big enough (~more than 100 points)
def confidence_intervals_v1(np_data_bs, conf=0.95):
    """Confidence Intervals with Gaussian Distribution (n>=30)"""
    CI = stats.norm.interval(alpha=conf, loc = np.mean( np_data_bs ), scale = stats.sem(np_data_bs))
    return CI

# %%
#export
#see https://stackoverflow.com/questions/15033511/compute-a-confidence-interval-from-sample-data
def confidence_intervals_v2(data, confidence=0.95):
    dist = NormalDist.from_samples(data)
    z = NormalDist().inv_cdf((1 + confidence) / 2.)
    h = dist.stdev * z / ((len(data) - 1) ** .5)
    return dist.mean - h, dist.mean + h, h

# %%
dict_test_intervals = {k: confidence_intervals_v2(dict_test[k]) for k in dict_test.keys() }

# %%
dict_test_intervals
# Out:
# {'function_definition': (4.940268354403088e-07, 4.940268354403088e-07, 0.0),
#  'parameters': (0.4535241723060608, 0.4535241723060608, 0.0),
#  'default_parameter': (0.4969795346260071, 0.4969795346260071, 0.0),
#  'ERROR': (0.965463052576959, 0.9656556741533877, 9.631078821433487e-05),
#  'expression_statement': (0.9633264541625977, 0.9633264541625977, 0.0),
#  'if_statement': (0.3594789505004883, 0.3594789505004883, 0.0),
#  'comparison_operator': (0.49701786041259766, 0.49701786041259766, 0.0),
#  'raise_statement': (0.5022116899490356, 0.5022116899490356, 0.0),
#  'call': (0.09397891908884048, 0.09397891908884048, 0.0),
#  'argument_list': (0.9793428182601929, 0.9793428182601929, 0.0),
#  'attribute': (0.555611252784729, 0.555611252784729, 0.0),
#  'assignment': (0.982282280921936, 0.982282280921936, 0.0),
#  'binary_operator': (0.9302335381507874, 0.9302335381507874, 0.0),
#  'return_statement': (0.06240289658308029, 0.06240289658308029, 0.0),
#  'global_statement': (0.12389463186264038, 0.12389463186264038, 0.0),
#  'block': (0.04229164868593216, 0.04229164868593216, 0.0),
#  'try_statement': (0.9985191226005554, 0.9985191226005554, 0.0),
#  'lambda': (0.8635597229003906, 0.8635597229003906, 0.0),
#  'lambda_parameters': (0.969171404838562, 0.969171404838562, 0.0),
#  'not_operator': (0.9996422529220581, 0.9996422529220581, 0.0),
#  'boolean_operator': (0.2912369668483734, 0.2912369668483734, 0.0),
#  'dictionary': (0.788898229598999, 0.788898229598999, 0.0),
#  'subscript': (0.9507201313972473, 0.9507201313972473, 0.0),
#  'elif_clause': (0.5141071081161499, 0.5141071081161499, 0.0),
#  'pass_statement': (0.15036603808403015, 0.15036603808403015, 0.0),
#  'finally_clause': (0.9999512434005737, 0.9999512434005737, 0.0),
#  'for_statement': (0.9405241012573242, 0.9405241012573242, 0.0),
#  'keyword_argument': (0.9812852144241333, 0.9812852144241333, 0.0),
#  'pair': (0.8746439814567566, 0.8746439814567566, 0.0),
#  'dictionary_comprehension': (0.6176669001579285, 0.6176669001579285, 0.0),
#  'for_in_clause': (0.9983661770820618, 0.9983661770820618, 0.0),
#  'pattern_list': (0.0209589172154665, 0.0209589172154665, 0.0),
#  'if_clause': (0.9281009435653687, 0.9281009435653687, 0.0),
#  'list_splat_pattern': (0.9581320285797119, 0.9581320285797119, 0.0),
#  'augmented_assignment': (0.8853234648704529, 0.8853234648704529, 0.0),
#  'parenthesized_expression': (0.00022045394871383905,
#   0.00022045394871383905,
#   0.0),
#  'tuple': (0.9627923965454102, 0.9627923965454102, 0.0),
#  'else_clause': (0.9998119473457336, 0.9998119473457336, 0.0),
#  'list': (0.8863828182220459, 0.8863828182220459, 0.0),
#  'slice': (0.7789183855056763, 0.7789183855056763, 0.0),
#  'list_comprehension': (0.3405025601387024, 0.3405025601387024, 0.0),
#  'except_clause': (0.998344898223877, 0.998344898223877, 0.0),
#  'unary_operator': (0.5311828851699829, 0.5311828851699829, 0.0),
#  'yield': (0.1805492008702593, 0.20139773409797382, 0.010424266613857265),
#  'import_from_statement': (0.6308360695838928, 0.6308360695838928, 0.0),
#  'dotted_name': (0.003415043232962489, 0.003415043232962489, 0.0),
#  'dictionary_splat_pattern': (0.976539134979248, 0.976539134979248, 0.0),
#  'tuple_pattern': (0.9845223426818848, 0.9845223426818848, 0.0),
#  'list_splat': (0.9996139407157898, 0.9996139407157898, 0.0),
#  'dictionary_splat': (0.9999330043792725, 0.9999330043792725, 0.0),
#  'with_statement': (0.9959375858306885, 0.9959375858306885, 0.0),
#  'as_pattern': (0.7118545174598694, 0.7118545174598694, 0.0),
#  'as_pattern_target': (0.5367464423179626, 0.5367464423179626, 0.0),
#  'conditional_expression': (0.6642559766769409, 0.6642559766769409, 0.0),
#  'concatenated_string': (0.01069747842848301, 0.01069747842848301, 0.0),
#  'generator_expression': (0.964148223400116, 0.964148223400116, 0.0),
#  'expression_list': (0.9995194673538208, 0.9995194673538208, 0.0),
#  'typed_default_parameter': (0.06675875186920166, 0.06675875186920166, 0.0),
#  'type': (0.3368586301803589, 0.3368586301803589, 0.0),
#  'while_statement': (0.531041145324707, 0.531041145324707, 0.0),
#  'import_statement': (0.2559884786605835, 0.2559884786605835, 0.0),
#  'aliased_import': (6.516675057355314e-05, 6.516675057355314e-05, 0.0),
#  'class_definition': (0.9957360029220581, 0.9957360029220581, 0.0),
#  'continue_statement': (0.269587904214859, 0.269587904214859, 0.0),
#  'set_comprehension': (0.8780694007873535, 0.8780694007873535, 0.0),
#  'assert_statement': (0.0035690604709088802, 0.0035690604709088802, 0.0)}
