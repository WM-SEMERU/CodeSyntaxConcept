# %%
import pandas as pd
import os
import time
import numpy as np
import torch

# %%
import seaborn as sns
from scipy import stats
from statistics import NormalDist
import matplotlib.pyplot as plt

# %%
#export
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
#! pip install dowhy
from dowhy import CausalModel
import dowhy.datasets, dowhy.plotter

# %%
import tensorflow as tf
#physical_devices = tf.config.list_physical_devices('CPU')
physical_devices = tf.config.list_physical_devices('GPU')

# %%
#device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device

# %%
# %matplotlib inline

# %% [markdown]
# # Confirmatory Causal Analysis
# >
# > Conformatory Experiments of Logits or Next Token Predictions @danaderp
# >

# %% [markdown]
# ### Data Upload

# %%
pd_combined_models_local = pd.read_csv('/workspaces/CodeSyntaxConcept/data/ds_processed_logits_local/out_astevalverticalfiltered_local.csv', index_col=0)

# %%
pd_combined_models_local.shape

# %%
pd_combined_models_local.head(1)

# %%
confounders = [ 'size', 'ast_levels', 'complexity', 'n_ast_nodes']
performance = [
               'for_statement', 
               'while_statement', 
               'return_statement',
               ']', 
               ')', 
               'if_statement', 
               'comparison_operator', 
               'boolean_operator',
               'for_in_clause', 
               'if_clause', 
               'list_comprehension', 
               'lambda',
               'identifier', 
               'string', 
               ]
outcome = ['loss']
features = ['id', 'type_model', 'size_model' ]

# %%
list_model = set(pd_combined_models_local.id.values)
list_model

# %%
list_model = {'gpt-3 [125M]','mono-lang [2B]'} #Considering only edge cases

# %% [markdown]
# ## Descriptive Statistics

# %%
sns.set_theme(style="darkgrid")

# %%
pd_combined_models_local.groupby(['id']).describe() #.reset_index()

# %% [markdown]
# ## Correlation Analysis

# %%
def pearson(np_x, np_y):
    corr, p_val = stats.pearsonr(np_x, np_y)
    #logging.info( f"correlation:{corr} pval:{p_val}" )
    return corr

# %%
correlations_performance = { col: [ [model, 
                                pearson( pd_combined_models_local[pd_combined_models_local['id']==model][col].values, pd_combined_models_local[pd_combined_models_local['id']==model]['loss'].values ), 
                                pearson( pd_combined_models_local[pd_combined_models_local['id']==model][col].values, pd_combined_models_local[pd_combined_models_local['id']==model]['complexity'].values ),
                                pearson( pd_combined_models_local[pd_combined_models_local['id']==model][col].values, pd_combined_models_local[pd_combined_models_local['id']==model]['ast_levels'].values ),
                                pearson( pd_combined_models_local[pd_combined_models_local['id']==model][col].values, pd_combined_models_local[pd_combined_models_local['id']==model]['n_ast_nodes'].values ),     
                                pearson( pd_combined_models_local[pd_combined_models_local['id']==model][col].values, pd_combined_models_local[pd_combined_models_local['id']==model]['size'].values)] for model in list_model]  for col in performance }

# %%
correlations_performance

# %%
correlations_loss = { col: [ [model, 
                                pearson( pd_combined_models_local[pd_combined_models_local['id']==model][col].values, pd_combined_models_local[pd_combined_models_local['id']==model]['loss'].values )] for model in list_model]  for col in confounders }

# %%
correlations_loss

# %% [markdown]
# ## Causation Analysis

# %%
def causal_effect(
    df_data = pd_combined_models_local[pd_combined_models_local['id']=='gpt-3 [125M]'],
    treatment = ['for_statement'],
    outcome = ['loss'],
    common_causes = ["size"]
):
    '''
    Returns Causal Effect 
    placebo robust method
    random common cause variable
    '''
    # I. Create a causal model from the data and given graph.
    causal_model = CausalModel(
        data =  df_data, 
        treatment = treatment,
        outcome = outcome,
        common_causes = common_causes
        )
    # II. Identify causal effect and return target estimands
    identified_estimand = causal_model.identify_effect(proceed_when_unidentifiable=True)
    
    # III. Estimate the target estimand using a statistical method.
    propensity_strat_estimate = causal_model.estimate_effect(identified_estimand,
                                 method_name="backdoor.dowhy.linear_regression")
    
    # IV. Refute the obtained estimate using multiple robustness checks.
    refute_results = causal_model.refute_estimate(identified_estimand, propensity_strat_estimate,
                                       method_name="placebo_treatment_refuter")
    
    res_random=causal_model.refute_estimate(identified_estimand, propensity_strat_estimate, method_name="random_common_cause")

    
    return propensity_strat_estimate.value, refute_results.new_effect, res_random.new_effect

# %%
#TST
causal_eff, res_placebo, res_random = causal_effect()
#print(causal_eff, res_placebo, res_random )

# %%
causation_concepts = { col: [ [model, 
                                causal_effect( 
                                              df_data = pd_combined_models_local[pd_combined_models_local['id']==model], 
                                              treatment = [col], 
                                              outcome = outcome,
                                              common_causes = confounders #controlling all confounders
                                              ), \
                            ] for model in list_model]  for col in performance }
# Out:
# 2023-05-02 02:48:30,889 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:30,902 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:30,935 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:30,963 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,052 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,064 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,152 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,175 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,227 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,240 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,274 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,286 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,320 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,333 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,365 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,379 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,415 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,430 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,465 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,480 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,516 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,531 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,576 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,598 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,654 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,667 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,703 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,718 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,790 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,805 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,839 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,855 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,893 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,906 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,940 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:31,954 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:31,988 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,002 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,035 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,049 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,083 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,097 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,131 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,145 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,179 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,192 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,225 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,239 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,273 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,287 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,320 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:32,334 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:32,368 : INFO : Making use of Bootstrap as we have more than 100 examples.
#              Note: The greater the number of examples, the more accurate are the confidence estimates
# 2023-05-02 02:48:32,370 : INFO : Refutation over 100 simulated datasets, each with a random common cause added
# 2023-05-02 02:48:32,384 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,435 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,484 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,532 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,583 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,632 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,680 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,730 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,799 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,882 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:32,942 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,000 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,059 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,129 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,225 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,306 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,402 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,450 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,500 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,552 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,601 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,651 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,717 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,768 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,821 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,872 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,926 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:33,977 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,031 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,082 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,135 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,185 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,239 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,291 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,341 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,393 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,443 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,518 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,601 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,673 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,738 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,802 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,866 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,924 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:34,977 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,034 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,092 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,144 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,196 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,248 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,300 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,352 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,404 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,455 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,508 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,559 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,612 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,664 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,720 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,828 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,880 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,932 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:35,984 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,038 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,090 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,142 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,193 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,244 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,294 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,345 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,396 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,453 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,504 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,554 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,605 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,655 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,707 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,757 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,807 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,856 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,905 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:36,955 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,005 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,054 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,105 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,155 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,205 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,255 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,305 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,354 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,405 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,455 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,504 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,554 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,604 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,652 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,702 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,754 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,820 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,870 : INFO : b: loss~return_statement+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:37,909 : INFO : Making use of Bootstrap as we have more than 100 examples.
#              Note: The greater the number of examples, the more accurate are the confidence estimates
# 2023-05-02 02:48:37,946 : WARNING : Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# 2023-05-02 02:48:37,948 : INFO : Model to find the causal effect of treatment [']'] on outcome ['loss']
# 2023-05-02 02:48:37,952 : INFO : Causal effect can be identified.
# 2023-05-02 02:48:37,954 : INFO : Instrumental variables for treatment and outcome:[]
# 2023-05-02 02:48:37,955 : INFO : Frontdoor variables for treatment and outcome:[]
# 2023-05-02 02:48:37,956 : INFO : INFO: Using Linear Regression Estimator
# 2023-05-02 02:48:37,959 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:37,993 : INFO : Refutation over 100 simulated datasets of PlaceboType.DEFAULT treatment
# 2023-05-02 02:48:37,994 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,007 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,039 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,052 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,084 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,098 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,130 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,143 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,180 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,193 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,224 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,238 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,271 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,284 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,316 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,329 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,363 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,376 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,409 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,422 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,455 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,468 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,500 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,514 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,546 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,560 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,593 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,606 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,639 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,653 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,686 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,699 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,733 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,746 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,780 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,793 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,828 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,841 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,874 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,888 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,922 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,936 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:38,969 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:38,982 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,014 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,027 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,060 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,072 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,105 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,118 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,150 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,163 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,196 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,209 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,242 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,255 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,287 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,300 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,332 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,345 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,378 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,391 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,427 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,440 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,473 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,486 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,518 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,531 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,564 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,578 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,610 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,623 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,656 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,669 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,702 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,715 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,747 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,760 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,792 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,805 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,853 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,868 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,901 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,914 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,946 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:39,959 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:39,991 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,004 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,036 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,049 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,081 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,094 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,126 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,139 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,171 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,184 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,217 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,230 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,262 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,275 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,307 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,320 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,352 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,365 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,397 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,410 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,443 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,455 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,488 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,501 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,536 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,549 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,582 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,595 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,628 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,641 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,674 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,687 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,721 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,734 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,766 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,779 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,811 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,824 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,856 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,869 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,903 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,916 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,948 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:40,961 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:40,993 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,006 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,038 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,051 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,083 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,096 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,128 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,141 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,173 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,189 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,221 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,235 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,267 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,280 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,312 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,325 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,357 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,370 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,402 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,415 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,447 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,460 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,493 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,506 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,538 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,551 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,583 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,596 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,629 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,642 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,674 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,687 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,719 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,732 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,764 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,777 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,809 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,822 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,854 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,868 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,937 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:41,950 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:41,995 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,008 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,040 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,053 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,088 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,101 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,133 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,145 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,178 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,191 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,223 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,236 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,269 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,282 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,314 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,327 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,360 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,373 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,404 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,417 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,449 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,462 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,494 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,507 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,538 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,551 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,583 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:42,596 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:42,628 : INFO : Making use of Bootstrap as we have more than 100 examples.
#              Note: The greater the number of examples, the more accurate are the confidence estimates
# 2023-05-02 02:48:42,629 : INFO : Refutation over 100 simulated datasets, each with a random common cause added
# 2023-05-02 02:48:42,642 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,691 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,739 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,787 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,835 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,883 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,931 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:42,979 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,027 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,075 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,123 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,171 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,220 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,268 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,316 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,364 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,413 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,460 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,509 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,557 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,604 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,652 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,701 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,749 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,797 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,845 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,895 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,943 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:43,991 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,050 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,099 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,147 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,195 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,282 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,330 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,378 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,426 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,474 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,521 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,569 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,618 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,666 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,714 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,762 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,810 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,859 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,907 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:44,955 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,004 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,052 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,100 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,147 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,196 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,244 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,291 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,340 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,387 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,435 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,483 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,531 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,579 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,627 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,675 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,724 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,771 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,819 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,868 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,917 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:45,965 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,012 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,068 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,128 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,176 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,223 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,271 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,319 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,367 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,415 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,464 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,512 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,559 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,607 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,656 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,703 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,753 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,801 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,849 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,896 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,946 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:46,993 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,042 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,090 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,137 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,185 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,233 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,281 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,330 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,378 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,425 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,474 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity+w_random
# 2023-05-02 02:48:47,510 : INFO : Making use of Bootstrap as we have more than 100 examples.
#              Note: The greater the number of examples, the more accurate are the confidence estimates
# 2023-05-02 02:48:47,548 : WARNING : Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# 2023-05-02 02:48:47,549 : INFO : Model to find the causal effect of treatment [']'] on outcome ['loss']
# 2023-05-02 02:48:47,554 : INFO : Causal effect can be identified.
# 2023-05-02 02:48:47,556 : INFO : Instrumental variables for treatment and outcome:[]
# 2023-05-02 02:48:47,557 : INFO : Frontdoor variables for treatment and outcome:[]
# 2023-05-02 02:48:47,557 : INFO : INFO: Using Linear Regression Estimator
# 2023-05-02 02:48:47,561 : INFO : b: loss~]+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,593 : INFO : Refutation over 100 simulated datasets of PlaceboType.DEFAULT treatment
# 2023-05-02 02:48:47,595 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,607 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,640 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,653 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,685 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,698 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,731 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,744 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,777 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,790 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,822 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,835 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,869 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,881 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,915 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,928 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:47,961 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:47,974 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,006 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,019 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,052 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,065 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,100 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,113 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,152 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,165 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,198 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,210 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,243 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,256 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,290 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,303 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,336 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,349 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,419 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,431 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,472 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,485 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,523 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,535 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# 2023-05-02 02:48:48,568 : INFO : Using a Normal Distribution with Mean:0 and Variance:0
# 2023-05-02 02:48:48,580 : INFO : b: loss~placebo+n_ast_nodes+size+ast_levels+complexity
# ...
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>                                               ), \
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>                             ] for model in list_model]  for col in performance }
#
# /workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb Cell 28 in 2
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> causation_concepts = { col: [ [model,
# ----> <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>                                 causal_effect(
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>                                               df_data = pd_combined_models_local[pd_combined_models_local['id']==model],
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>                                               treatment = [col],
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>                                               outcome = outcome,
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>                                               common_causes = confounders #controlling all confounders
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>                                               ), \
#       <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>                             ] for model in list_model]  for col in performance }
#
# /workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb Cell 28 in 3
#      <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> # IV. Refute the obtained estimate using multiple robustness checks.
#      <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> refute_results = causal_model.refute_estimate(identified_estimand, propensity_strat_estimate,
#      <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a>                                    method_name="placebo_treatment_refuter")
# ---> <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> res_random=causal_model.refute_estimate(identified_estimand, propensity_strat_estimate, method_name="random_common_cause")
#      <a href='vscode-notebook-cell://dev-container%2B7b22686f737450617468223a222f73637261746368312f64616e69656c72632f436f646553796e746178436f6e63657074222c2273657474696e6773223a7b22686f7374223a227373683a2f2f73656d6572752d5432227d7d/workspaces/CodeSyntaxConcept/experimental_notebooks/3_confirmatory_local_granularity_analysisV1.2.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> return propensity_strat_estimate.value, refute_results.new_effect, res_random.new_effect
#
# File /usr/local/lib/python3.8/dist-packages/dowhy/causal_model.py:417, in CausalModel.refute_estimate(self, estimand, estimate, method_name, show_progress_bar, **kwargs)
#     414     refuter_class = causal_refuters.get_class_object(method_name)
#     416 refuter = refuter_class(self._data, identified_estimand=estimand, estimate=estimate, **kwargs)
# --> 417 res = refuter.refute_estimate(show_progress_bar)
#     418 return res
#
# File /usr/local/lib/python3.8/dist-packages/dowhy/causal_refuters/random_common_cause.py:45, in RandomCommonCause.refute_estimate(self, show_progress_bar)
#      44 def refute_estimate(self, show_progress_bar=False):
# ---> 45     refute = refute_random_common_cause(
#      46         self._data,
#      47         self._target_estimand,
#      48         self._estimate,
#      49         self._num_simulations,
#      50         self._random_state,
#      51         show_progress_bar,
#      52         self._n_jobs,
#      53         self._verbose,
#      54     )
#      55     refute.add_refuter(self)
#      56     return refute
#
# File /usr/local/lib/python3.8/dist-packages/dowhy/causal_refuters/random_common_cause.py:120, in refute_random_common_cause(data, target_estimand, estimate, num_simulations, random_state, show_progress_bar, n_jobs, verbose, **_)
#     117     random_state = np.random.RandomState(seed=random_state)
#     119 # Run refutation in parallel
# --> 120 sample_estimates = Parallel(n_jobs=n_jobs, verbose=verbose)(
#     121     delayed(_refute_once)(data, identified_estimand, estimate, random_state)
#     122     for _ in tqdm(
#     123         range(num_simulations),
#     124         colour=CausalRefuter.PROGRESS_BAR_COLOR,
#     125         disable=not show_progress_bar,
#     126         desc="Refuting Estimates: ",
#     127     )
#     128 )
#     129 sample_estimates = np.array(sample_estimates)
#     131 refute = CausalRefutation(
#     132     estimate.value, np.mean(sample_estimates), refutation_type="Refute: Add a random common cause"
#     133 )
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr/local/lib/python3.8/dist-packages/dowhy/causal_refuters/random_common_cause.py:78, in _refute_once(data, target_estimand, estimate, random_state)
#      70 new_estimator = estimate.estimator.get_new_estimator_object(target_estimand)
#      71 new_estimator.fit(
#      72     new_data,
#      73     target_estimand.treatment_variable,
#    (...)
#      76     **new_estimator._econml_fit_params if isinstance(new_estimator, Econml) else {},
#      77 )
# ---> 78 new_effect = new_estimator.estimate_effect(
#      79     control_value=estimate.control_value,
#      80     treatment_value=estimate.treatment_value,
#      81     target_units=estimate.estimator._target_units,
#      82 )
#      83 return new_effect.value
#
# File /usr/local/lib/python3.8/dist-packages/dowhy/causal_estimators/regression_estimator.py:127, in RegressionEstimator.estimate_effect(self, data, treatment_value, control_value, target_units, need_conditional_estimates, **_)
#     124 self._control_value = control_value
#     125 # TODO make treatment_value and control value also as local parameters
#     126 # All treatments are set to the same constant value
# --> 127 effect_estimate = self._do(treatment_value, data) - self._do(control_value, data)
#     128 conditional_effect_estimates = None
#     129 if need_conditional_estimates:
#
# File /usr/local/lib/python3.8/dist-packages/dowhy/causal_estimators/regression_estimator.py:210, in RegressionEstimator._do(self, treatment_val, data_df)
#     202 # Then, use pandas to ensure that the dummies are assigned correctly for a categorical treatment
#     203 interventional_treatment_2d = pd.concat(
#     204     [
#     205         self._treatment.copy(),
#    (...)
#     208     axis=0,
#     209 ).astype(self._treatment.dtypes, copy=False)
# --> 210 interventional_treatment_2d = pd.get_dummies(interventional_treatment_2d, drop_first=True)
#     211 interventional_treatment_2d = interventional_treatment_2d[self._treatment.shape[0] :]
#     213 new_features = self._build_features(treatment_values=interventional_treatment_2d, data_df=data_df)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/encoding.py:202, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     192         dummy = _get_dummies_1d(
#     193             col[1],
#     194             prefix=pre,
#    (...)
#     199             dtype=dtype,
#     200         )
#     201         with_dummies.append(dummy)
# --> 202     result = concat(with_dummies, axis=1)
#     203 else:
#     204     result = _get_dummies_1d(
#     205         data,
#     206         prefix,
#    (...)
#     211         dtype=dtype,
#     212     )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/concat.py:614, in _Concatenator.get_result(self)
#     611         if not new_labels.equals(obj_labels):
#     612             indexers[ax] = obj_labels.get_indexer(new_labels)
# --> 614     mgrs_indexers.append((obj._mgr, indexers))
#     616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#     619 if not self.copy:
#
# KeyboardInterrupt:

# %%
causation_concepts

# %% [markdown]
# ### Visual Correlations

# %%
#Check here: https://seaborn.pydata.org/generated/seaborn.pairplot.html
g = sns.pairplot(data=pd_processed_logits)
g.map_upper(sns.scatterplot,marker=".")
g.map_lower(sns.kdeplot,levels=3,color=".2")
g.map_diag(sns.histplot)

# %%
sns.set_style("darkgrid")
pd_processed_logits[pd_processed_logits['model']=='125M'].plot.scatter(
    x = 'function_definition',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
sns.set_style("darkgrid")
pd_processed_logits[pd_processed_logits['model']=='1.3B'].plot.scatter(
    x = 'function_definition',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='2.7B'].plot.scatter(
    x = 'function_definition',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='125M'].plot.scatter(
    y = 'function_definition',
    x = 'size',
    c = 'loss', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='1.3B'].plot.scatter(
    y = 'function_definition',
    x = 'size',
    c = 'loss', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='2.7B'].plot.scatter(
    y = 'function_definition',
    x = 'size',
    c = 'loss', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
#Check here for more plots: https://seaborn.pydata.org/tutorial/regression.html
#g = sns.relplot(data=data['df'], x="v0", y="y")
pd_processed_logits[pd_processed_logits['model']=='125M'].plot.scatter(
    x = 'expression_statement',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='1.3B'].plot.scatter(
    x = 'expression_statement',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='2.7B'].plot.scatter(
    x = 'expression_statement',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
pd_processed_logits[pd_processed_logits['model']=='2.7B'].plot.scatter(
    x = 'expression_statement',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %% [markdown]
# ## Causal Analysis (implementation)

# %%
# Testing Block
def causal_data( ):
    data = dowhy.datasets.linear_dataset(
        beta=2,
        num_common_causes=20,
        num_instruments=0,
        num_samples=10000,
        treatment_is_binary=False,
        stddev_treatment_noise = 10 )
    
    return data

# %%
pd_processed_logits[pd_processed_logits['model']=='125M'].head(1)

# %%
def causal_effect(
    df_data = pd_processed_logits[pd_processed_logits['model']=='125M'],
    treatment = ['attribute'],
    outcome = ['loss'],
    common_causes = ["size"]
):
    '''
    Returns Causal Effect and placebo robust method
    '''
    # I. Create a causal model from the data and given graph.
    causal_model = CausalModel(
        data =  df_data, 
        treatment = treatment,
        outcome = outcome,
        common_causes = common_causes
        )
    # II. Identify causal effect and return target estimands
    identified_estimand = causal_model.identify_effect(proceed_when_unidentifiable=True)
    
    # III. Estimate the target estimand using a statistical method.
    propensity_strat_estimate = causal_model.estimate_effect(identified_estimand,
                                 method_name="backdoor.dowhy.linear_regression")
    
    # IV. Refute the obtained estimate using multiple robustness checks.
    refute_results = causal_model.refute_estimate(identified_estimand, propensity_strat_estimate,
                                       method_name="placebo_treatment_refuter")
    
    res_random=causal_model.refute_estimate(identified_estimand, propensity_strat_estimate, method_name="random_common_cause")

    
    return propensity_strat_estimate.value, refute_results.new_effect, res_random.new_effect

# %%
# I. Create a causal model from the data and given graph.
causal_model = CausalModel(
    data =  pd_processed_logits[pd_processed_logits['model']=='125M'], #data["df"],
    treatment = ['attribute'],
    outcome = ['loss'],
    common_causes = ["size"]
    #instruments=data["instrument_names"]
    )

# %%
# II. Identify causal effect and return target estimands
identified_estimand = causal_model.identify_effect(proceed_when_unidentifiable=True)
logging.info(identified_estimand)

# %%
# III. Estimate the target estimand using a statistical method.
propensity_strat_estimate = causal_model.estimate_effect(identified_estimand,
                                 method_name="backdoor.dowhy.linear_regression")

print(propensity_strat_estimate)

# %%
propensity_strat_estimate.value

# %%
dowhy.plotter.plot_causal_effect(
    propensity_strat_estimate, 
    pd_processed_logits[pd_processed_logits['model']=='125M']['attribute'], 
    pd_processed_logits[pd_processed_logits['model']=='125M']['loss']
    )

# %%
sns.set_style("darkgrid")
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
plt.rcParams.update({'font.size': 22})


pd_processed_logits[pd_processed_logits['model']=='125M'].plot.scatter(
    x = 'attribute',
    y = 'loss',
    c = 'size', #Common Causes
    s = 1,
    cmap="magma" #cmap="viridis" plasma
)

# %%
# IV. Refute the obtained estimate using multiple robustness checks.
refute_results = causal_model.refute_estimate(identified_estimand, propensity_strat_estimate,
                                       method_name="placebo_treatment_refuter")
print(refute_results)

# %%
refute_results.new_effect
